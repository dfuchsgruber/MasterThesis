# %%
import matplotlib.pyplot as plt
import numpy as np
import seml
import pandas as pd
import json
from collections import defaultdict, Counter
from functools import reduce
import seaborn as sns
from scipy.stats import binned_statistic
from matplotlib.lines import Line2D

# %%
# %cd ../..
# Out:
# /nfs/homedirs/fuchsgru/MastersThesis

# %%
import data.constants as dc

# %%
collection_name = 'week18_lipschitz_son'
collection = seml.database.get_collection(collection_name)

# %%
by_status = defaultdict(set)
for r in collection.find():
    by_status[r['status']].add(r['config']['data']['dataset'])

# %%
by_status
# Out:
# defaultdict(set,
#             {'COMPLETED': {'amazon_photo', 'citeseer', 'cora_full'},
#              'FAILED': {'cora_full'},
#              'KILLED': {'cora_full'},
#              'RUNNING': {'cora_full'},
#              'PENDING': {'amazon_photo', 'citeseer', 'cora_full'}})

# %%
collection_name = 'week18_lipschitz_son'
collection = seml.database.get_collection(collection_name)
experiments = [{'config' : r['config'], 'result' : r['result'], 'id' : r['_id']} for r in collection.find() if r['status'] in ('COMPLETED',)]
for ex in experiments:
    # print(ex['result'].keys())
    ex['metrics'] = ex['result']['results']

# %%
experiments_killed = [r for r in collection.find() if r['status'] in ('KILLED',)]

# %%
[ex['fail_trace'] for ex in experiments_killed]
# Out:
# [["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840492.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840492.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840492.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840492.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840493.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840493.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840493.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840493.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840494.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840494.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840494.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840494.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840495.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840495.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840495.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840495.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840506.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840506.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840506.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840506.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840507.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840507.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840507.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu'), 'input_projection.linear.bias': device(type='cpu'), 'input_projection.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.weight': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840507.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840509.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840509.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840509.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n'],
#  ["cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   "cpu {'conv.bias': device(type='cpu'), 'conv.lin.linear.bias': device(type='cpu'), 'conv.lin.linear.parametrizations.weight.original': device(type='cpu')}\n",
#   '\n',
#   'slurmstepd: error: Detected 4 oom-kill event(s) in step 6840509.batch cgroup. Some of your processes may have been killed by the cgroup out-of-memory handler.\n']]

# %%
set(e['config']['data']['dataset'] for e in experiments_killed)
# Out:
# {'cora_full'}

# %%
keys = set()
for ex in experiments:
    keys |= set(ex['metrics'].keys())

list(keys)
# Out:
# ['accuracy_id_val_val',
#  'misclassification_aucpr_gpc-full-mode:max-relative:True:no_loc_fit-95conf_test',
#  'ood_auroc_gpc-diag-mode:weighted-relative:True:no_loc_fit-95conf_test',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:True:no_ber_fit-95conf_val',
#  'misclassification_auroc_max-score_ber-no-edges_val',
#  'misclassification_aucpr_max-score_loc_test',
#  'misclassification_auroc_feature-distance_normal_fit-95conf_val',
#  'ood_auroc_max-score_loc_test',
#  'accuracy_normal-test_normal-no-edges_test',
#  'ood_auroc_max-score_ber_test',
#  'misclassification_auroc_gpc-diag-mode:max-relative:False:no_normal_fit-mask_val',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'ood_auroc_gpc-iso-mode:weighted-relative:False:no_ber_fit-mask_val',
#  'ood_auroc_feature-distance_loc_fit-mask_test',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:True:no_loc_fit-mask_test',
#  'misclassification_auroc_gpc-iso-mode:max-relative:False:no_normal_fit-mask_val',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:False:no_loc_fit-95conf_val',
#  'misclassification_auroc_gpc-eye-mode:max-relative:False:no_loc_fit-mask_val',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'accuracy_ood_ber-val_ber_val',
#  'ood_auroc_max-score_loc_val',
#  'ood_aucpr_gpc-full-mode:weighted-relative:False:no_loc_fit-mask_test',
#  'ood_auroc_gpc-full-mode:weighted-relative:True:no_ber_fit-95conf_val',
#  'misclassification_auroc_gpc-iso-mode:max-relative:True:no_ber_fit-mask_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:True:no_normal_fit-mask_val',
#  'empirical_lipschitz_val_slope_min_perturbation_no-edges_val',
#  'ood_auroc_gpc-full-mode:max-relative:True:no_ber_fit-mask_test',
#  'ood_auroc_gpc-iso-mode:max-relative:True:no_ber_fit-mask_val',
#  'ood_aucpr_gpc-diag-mode:max-relative:False:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:True:no_ber_fit-95conf_test',
#  'ood_aucpr_max-score_loc-no-edges_val',
#  'misclassification_auroc_gpc-diag-mode:max-relative:False:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:True:no_ber_fit-95conf_test',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:True:no_ber_fit-mask_test',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:True:no_ber_fit-95conf_val',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:False:no_normal_fit-mask_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:True:no_loc_fit-mask_test',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'accuracy_id_normal-test_normal_test',
#  'misclassification_auroc_gpc-full-mode:max-relative:True:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-diag-mode:max-relative:True:no_ber_fit-95conf_test',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:False:no_normal_fit-mask_test',
#  'misclassification_auroc_gpc-eye-mode:max-relative:False:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:True:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:True:no_ber_fit-95conf_val',
#  'misclassification_auroc_max-score_loc-no-edges_val',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'ood_auroc_total-predictive-entropy_normal_val',
#  'accuracy_ood-test_loc-no-edges_test',
#  'misclassification_aucpr_total-predictive-entropy_loc-no-edges_test',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:True:no_ber_fit-95conf_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:False:no_loc_fit-mask_test',
#  'ood_auroc_gpc-diag-mode:weighted-relative:True:no_normal_fit-mask_val',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:False:no_ber_fit-mask_val',
#  'ood_auroc_gpc-iso-mode:weighted-relative:True:no_loc_fit-mask_val',
#  'ood_auroc_total-predictive-entropy_loc_test',
#  'misclassification_auroc_feature-distance_ber_fit-mask_test',
#  'ood_auroc_gpc-diag-mode:max-relative:False:no_ber_fit-mask_val',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'ood_auroc_gpc-iso-mode:weighted-relative:False:no_ber_fit-95conf_val',
#  'ood_auroc_logit-energy_normal-no-edges_val',
#  'empirical_lipschitz_val_slope_max_perturbation_no-edges_val',
#  'ood_aucpr_gpc-diag-mode:max-relative:True:no_loc_fit-95conf_test',
#  'ood_aucpr_logit-energy_normal_val',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:True:no_normal_fit-95conf_val',
#  'ood_aucpr_gpc-full-mode:weighted-relative:True:no_ber_fit-95conf_val',
#  'ood_aucpr_gpc-eye-mode:max-relative:False:no_ber_fit-95conf_val',
#  'ood_aucpr_logit-energy_loc_val',
#  'ood_auroc_gpc-eye-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:True:no_loc_fit-mask_val',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:True:no_normal_fit-mask_test',
#  'ood_auroc_gpc-full-mode:max-relative:True:no_normal_fit-95conf_test',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:True:no_loc_fit-95conf_val',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:True:no_ber_fit-mask_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:True:no_loc_fit-mask_val',
#  'ood_aucpr_gpc-full-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'misclassification_auroc_gpc-eye-mode:max-relative:False:no_loc_fit-95conf_test',
#  'misclassification_auroc_max-score_loc_val',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:False:no_ber_fit-95conf_val',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'ood_auroc_gpc-diag-mode:weighted-relative:True:no_normal_fit-mask_test',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:True:no_loc_fit-mask_test',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:False:no_ber_fit-95conf_val',
#  'ood_auroc_gpc-diag-mode:weighted-relative:False:no_normal_fit-mask_val',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:False:no_ber_fit-95conf_test',
#  'ood_auroc_gpc-iso-mode:weighted-relative:True:no_loc_fit-mask_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:True:no_ber_fit-mask_val',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:True:no_loc_fit-95conf_test',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:False:no_normal_fit-95conf_test',
#  'ood_aucpr_gpc-eye-mode:max-relative:True:no_ber_fit-mask_val',
#  'ood_auroc_feature-distance_ber_fit-95conf_val',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:False:no_normal_fit-mask_test',
#  'misclassification_auroc_gpc-diag-mode:max-relative:True:no_ber_fit-95conf_val',
#  'misclassification_aucpr_total-predictive-entropy_normal-no-edges_test',
#  'misclassification_auroc_max-score_loc-no-edges_test',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:True:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-full-mode:max-relative:True:no_ber_fit-95conf_val',
#  'misclassification_aucpr_gpc-full-mode:max-relative:False:no_loc_fit-mask_val',
#  'ood_auroc_gpc-iso-mode:max-relative:False:no_ber_fit-mask_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:False:no_loc_fit-95conf_val',
#  'misclassification_auroc_gpc-iso-mode:max-relative:True:no_normal_fit-95conf_test',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:True:no_normal_fit-95conf_val',
#  'misclassification_aucpr_total-predictive-entropy_loc-no-edges_val',
#  'misclassification_auroc_gpc-full-mode:max-relative:False:no_loc_fit-mask_val',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:False:no_loc_fit-95conf_val',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:False:no_loc_fit-95conf_val',
#  'ood_auroc_gpc-iso-mode:weighted-relative:True:no_normal_fit-95conf_val',
#  'ood_aucpr_gpc-eye-mode:max-relative:True:no_ber_fit-95conf_test',
#  'ood_auroc_gpc-diag-mode:max-relative:True:no_ber_fit-95conf_val',
#  'ood_auroc_gpc-iso-mode:max-relative:True:no_ber_fit-95conf_test',
#  'ood_aucpr_gpc-full-mode:max-relative:True:no_normal_fit-95conf_test',
#  'ood_auroc_gpc-full-mode:max-relative:True:no_loc_fit-mask_val',
#  'ood_auroc_feature-distance_normal_fit-95conf_val',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:True:no_loc_fit-mask_val',
#  'ood_aucpr_gpc-eye-mode:max-relative:True:no_loc_fit-mask_val',
#  'misclassification_aucpr_logit-energy_ber-no-edges_val',
#  'ood_auroc_total-predictive-entropy_normal-no-edges_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:False:no_loc_fit-95conf_val',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:True:no_loc_fit-95conf_val',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:False:no_normal_fit-mask_test',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'ece_val_val',
#  'ood_auroc_logit-energy_loc-no-edges_val',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:False:no_loc_fit-95conf_val',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:False:no_loc_fit-mask_test',
#  'ood_auroc_gpc-diag-mode:max-relative:True:no_normal_fit-mask_test',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:False:no_loc_fit-95conf_val',
#  'ood_aucpr_gpc-diag-mode:max-relative:True:no_normal_fit-95conf_val',
#  'misclassification_aucpr_logit-energy_ber_test',
#  'accuracy_ood_test_no-edges_test',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:True:no_normal_fit-95conf_test',
#  'accuracy_ood_normal-test_normal-no-edges_test',
#  'misclassification_auroc_gpc-iso-mode:max-relative:True:no_normal_fit-mask_val',
#  'ood_auroc_gpc-diag-mode:weighted-relative:True:no_normal_fit-95conf_val',
#  'misclassification_aucpr_max-score_loc_val',
#  'misclassification_auroc_gpc-full-mode:max-relative:True:no_loc_fit-mask_val',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:True:no_ber_fit-95conf_val',
#  'ood_auroc_gpc-iso-mode:max-relative:True:no_ber_fit-95conf_val',
#  'ood_aucpr_gpc-diag-mode:max-relative:True:no_loc_fit-mask_val',
#  'misclassification_auroc_gpc-iso-mode:max-relative:True:no_loc_fit-95conf_test',
#  'ood_aucpr_gpc-full-mode:max-relative:True:no_loc_fit-95conf_val',
#  'ood_aucpr_max-score_ber_test',
#  'ood_aucpr_gpc-iso-mode:max-relative:True:no_loc_fit-mask_val',
#  'ood_aucpr_gpc-eye-mode:max-relative:True:no_normal_fit-mask_test',
#  'ood_auroc_gpc-iso-mode:max-relative:True:no_loc_fit-95conf_val',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:True:no_loc_fit-95conf_test',
#  'accuracy_ber-test_ber_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:True:no_loc_fit-mask_test',
#  'misclassification_auroc_gpc-diag-mode:max-relative:True:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:True:no_normal_fit-95conf_val',
#  'ood_auroc_gpc-eye-mode:weighted-relative:False:no_ber_fit-95conf_val',
#  'empirical_lipschitz_val_slope_mean_perturbation_noise_val',
#  'misclassification_auroc_logit-energy_normal_val',
#  'ood_auroc_gpc-eye-mode:max-relative:True:no_normal_fit-95conf_test',
#  'accuracy_ood_ber-val_ber-no-edges_val',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:True:no_ber_fit-mask_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:False:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'ood_aucpr_gpc-full-mode:max-relative:True:no_normal_fit-mask_val',
#  'ood_aucpr_gpc-diag-mode:max-relative:False:no_normal_fit-95conf_val',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:True:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:True:no_loc_fit-mask_test',
#  'misclassification_auroc_logit-energy_ber_test',
#  'ood_auroc_logit-energy_loc_test',
#  'ood_auroc_gpc-full-mode:weighted-relative:True:no_normal_fit-mask_test',
#  'misclassification_aucpr_logit-energy_loc-no-edges_val',
#  'misclassification_auroc_feature-distance_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:False:no_ber_fit-mask_val',
#  'misclassification_auroc_logit-energy_ber-no-edges_val',
#  'ood_auroc_total-predictive-entropy_loc-no-edges_test',
#  'ood_auroc_gpc-eye-mode:max-relative:False:no_loc_fit-95conf_val',
#  'ood_auroc_gpc-full-mode:max-relative:False:no_loc_fit-95conf_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:True:no_loc_fit-mask_test',
#  'accuracy_val_no-edges_val',
#  'misclassification_aucpr_gpc-full-mode:max-relative:True:no_ber_fit-mask_val',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'ood_auroc_gpc-iso-mode:weighted-relative:True:no_normal_fit-95conf_test',
#  'ood_auroc_gpc-diag-mode:max-relative:False:no_loc_fit-mask_val',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:False:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:True:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:True:no_normal_fit-mask_test',
#  'ood_auroc_gpc-eye-mode:weighted-relative:False:no_loc_fit-mask_test',
#  'ood_auroc_gpc-diag-mode:max-relative:False:no_ber_fit-95conf_test',
#  'ood_auroc_gpc-eye-mode:max-relative:True:no_ber_fit-mask_val',
#  'ood_auroc_gpc-diag-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'misclassification_auroc_gpc-iso-mode:max-relative:False:no_loc_fit-95conf_test',
#  'ood_aucpr_gpc-diag-mode:max-relative:False:no_loc_fit-mask_val',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:False:no_loc_fit-95conf_val',
#  'ood_aucpr_logit-energy_normal-no-edges_test',
#  'misclassification_auroc_gpc-eye-mode:max-relative:False:no_ber_fit-95conf_val',
#  'ood_aucpr_gpc-full-mode:max-relative:False:no_normal_fit-95conf_test',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'ood_auroc_max-score_ber-no-edges_test',
#  'ood_auroc_gpc-full-mode:max-relative:True:no_normal_fit-mask_test',
#  'ood_auroc_gpc-diag-mode:weighted-relative:True:no_loc_fit-mask_test',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'misclassification_auroc_total-predictive-entropy_ber-no-edges_test',
#  'misclassification_auroc_gpc-full-mode:max-relative:True:no_loc_fit-mask_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:True:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:True:no_ber_fit-95conf_val',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:False:no_normal_fit-mask_test',
#  'ood_aucpr_total-predictive-entropy_ber-no-edges_test',
#  'ood_aucpr_gpc-eye-mode:max-relative:False:no_loc_fit-95conf_val',
#  'misclassification_auroc_gpc-diag-mode:max-relative:True:no_loc_fit-mask_test',
#  'ood_aucpr_gpc-diag-mode:max-relative:False:no_ber_fit-mask_test',
#  'ood_auroc_gpc-diag-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:True:no_loc_fit-95conf_val',
#  'accuracy_id_ood-val_loc_val',
#  'ood_auroc_gpc-diag-mode:weighted-relative:False:no_loc_fit-95conf_val',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:True:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-iso-mode:max-relative:True:no_normal_fit-mask_test',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:False:no_normal_fit-mask_val',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:False:no_normal_fit-mask_test',
#  'misclassification_auroc_total-predictive-entropy_loc-no-edges_test',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:True:no_normal_fit-95conf_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:False:no_loc_fit-mask_test',
#  'ood_auroc_gpc-iso-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'misclassification_aucpr_total-predictive-entropy_loc_val',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'ood_auroc_gpc-diag-mode:max-relative:False:no_ber_fit-95conf_val',
#  'misclassification_auroc_logit-energy_normal_test',
#  'misclassification_auroc_gpc-full-mode:max-relative:False:no_normal_fit-95conf_val',
#  'ood_aucpr_logit-energy_ber-no-edges_test',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:True:no_loc_fit-95conf_test',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:True:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-full-mode:max-relative:True:no_normal_fit-95conf_test',
#  'ood_auroc_logit-energy_normal_test',
#  'ood_aucpr_gpc-full-mode:max-relative:False:no_loc_fit-95conf_test',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:False:no_ber_fit-mask_val',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:False:no_ber_fit-95conf_val',
#  'ood_auroc_gpc-diag-mode:max-relative:False:no_normal_fit-mask_val',
#  'ood_auroc_gpc-iso-mode:weighted-relative:True:no_loc_fit-95conf_val',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'ood_auroc_gpc-full-mode:max-relative:False:no_ber_fit-mask_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'accuracy_id_test_no-edges_test',
#  'ood_aucpr_gpc-iso-mode:max-relative:True:no_normal_fit-mask_val',
#  'ood_auroc_gpc-eye-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'misclassification_auroc_gpc-iso-mode:max-relative:False:no_ber_fit-95conf_val',
#  'ood_auroc_gpc-full-mode:max-relative:False:no_normal_fit-mask_test',
#  'misclassification_auroc_gpc-full-mode:max-relative:False:no_normal_fit-mask_val',
#  'ood_aucpr_gpc-eye-mode:max-relative:True:no_normal_fit-95conf_test',
#  'misclassification_aucpr_logit-energy_ber_val',
#  'misclassification_auroc_gpc-eye-mode:max-relative:False:no_normal_fit-mask_val',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:True:no_loc_fit-95conf_val',
#  'ood_auroc_gpc-iso-mode:max-relative:False:no_normal_fit-95conf_val',
#  'ece_test_no-edges_test',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:False:no_loc_fit-mask_test',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:True:no_ber_fit-mask_val',
#  'ood_auroc_gpc-diag-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:True:no_loc_fit-95conf_test',
#  'misclassification_aucpr_gpc-full-mode:max-relative:False:no_ber_fit-95conf_test',
#  'ood_aucpr_total-predictive-entropy_loc-no-edges_val',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:False:no_normal_fit-mask_val',
#  'ood_aucpr_gpc-full-mode:max-relative:False:no_loc_fit-95conf_val',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:True:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:True:no_normal_fit-mask_val',
#  'misclassification_auroc_feature-distance_ber_fit-95conf_test',
#  'ood_aucpr_total-predictive-entropy_loc-no-edges_test',
#  'misclassification_aucpr_gpc-full-mode:max-relative:True:no_normal_fit-95conf_val',
#  'misclassification_aucpr_logit-energy_normal_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:True:no_ber_fit-95conf_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:True:no_normal_fit-mask_val',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:False:no_ber_fit-95conf_val',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:True:no_loc_fit-95conf_test',
#  'ood_auroc_gpc-iso-mode:weighted-relative:True:no_ber_fit-mask_val',
#  'ood_aucpr_gpc-full-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'ood_aucpr_gpc-iso-mode:max-relative:False:no_normal_fit-mask_test',
#  'ood_auroc_gpc-eye-mode:max-relative:True:no_ber_fit-95conf_val',
#  'ood_aucpr_gpc-iso-mode:max-relative:False:no_loc_fit-mask_val',
#  'misclassification_auroc_gpc-diag-mode:max-relative:False:no_ber_fit-95conf_val',
#  'misclassification_aucpr_gpc-full-mode:max-relative:True:no_ber_fit-95conf_val',
#  'misclassification_auroc_gpc-diag-mode:max-relative:True:no_ber_fit-mask_val',
#  'ood_aucpr_gpc-full-mode:max-relative:True:no_loc_fit-mask_val',
#  'accuracy_test_no-edges_test',
#  'ood_auroc_gpc-eye-mode:max-relative:True:no_normal_fit-mask_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:True:no_ber_fit-95conf_test',
#  'ood_auroc_gpc-eye-mode:max-relative:True:no_ber_fit-95conf_test',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:True:no_normal_fit-95conf_val',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:False:no_ber_fit-mask_val',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:True:no_normal_fit-95conf_val',
#  'ood_auroc_gpc-eye-mode:max-relative:True:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:True:no_loc_fit-95conf_test',
#  'ood_auroc_gpc-eye-mode:max-relative:True:no_loc_fit-95conf_test',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:True:no_ber_fit-mask_val',
#  'ood_aucpr_gpc-full-mode:max-relative:False:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:False:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'ood_aucpr_gpc-diag-mode:max-relative:True:no_ber_fit-95conf_test',
#  'ood_auroc_gpc-diag-mode:weighted-relative:True:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:False:no_ber_fit-95conf_val',
#  'misclassification_auroc_total-predictive-entropy_ber_test',
#  'ood_auroc_feature-distance_normal_fit-95conf_test',
#  'ood_aucpr_gpc-full-mode:weighted-relative:False:no_ber_fit-95conf_val',
#  'misclassification_auroc_gpc-eye-mode:max-relative:True:no_normal_fit-95conf_test',
#  'ood_auroc_gpc-full-mode:max-relative:True:no_loc_fit-mask_test',
#  'ood_aucpr_gpc-diag-mode:max-relative:True:no_loc_fit-95conf_val',
#  'ood_aucpr_logit-energy_loc-no-edges_test',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:True:no_normal_fit-95conf_test',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:False:no_loc_fit-mask_test',
#  'ood_aucpr_gpc-eye-mode:max-relative:True:no_loc_fit-95conf_val',
#  'ood_auroc_gpc-iso-mode:max-relative:True:no_normal_fit-95conf_test',
#  'accuracy_ber-val_ber-no-edges_val',
#  'ood_auroc_logit-energy_ber-no-edges_val',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:True:no_ber_fit-95conf_val',
#  'ood_aucpr_max-score_ber-no-edges_val',
#  'misclassification_aucpr_gpc-full-mode:max-relative:False:no_ber_fit-mask_val',
#  'misclassification_auroc_gpc-full-mode:max-relative:False:no_ber_fit-mask_test',
#  'ood_aucpr_max-score_normal-no-edges_test',
#  'ood_aucpr_gpc-full-mode:max-relative:True:no_ber_fit-mask_test',
#  'ood_auroc_gpc-diag-mode:max-relative:True:no_ber_fit-mask_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:False:no_normal_fit-mask_val',
#  'misclassification_auroc_feature-distance_ber_fit-mask_val',
#  'misclassification_auroc_feature-distance_normal_fit-mask_val',
#  'ood_auroc_gpc-eye-mode:max-relative:True:no_normal_fit-95conf_val',
#  'ood_auroc_logit-energy_normal_val',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:True:no_ber_fit-95conf_test',
#  'ood_auroc_gpc-full-mode:max-relative:False:no_ber_fit-95conf_val',
#  'misclassification_auroc_gpc-iso-mode:max-relative:True:no_ber_fit-95conf_val',
#  'ood_auroc_gpc-diag-mode:weighted-relative:True:no_ber_fit-mask_val',
#  'ood_auroc_gpc-eye-mode:weighted-relative:True:no_ber_fit-mask_val',
#  'misclassification_auroc_gpc-iso-mode:max-relative:True:no_ber_fit-mask_val',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:True:no_normal_fit-mask_val',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:True:no_normal_fit-mask_val',
#  'ood_aucpr_gpc-iso-mode:max-relative:False:no_normal_fit-mask_val',
#  'ood_aucpr_gpc-eye-mode:max-relative:False:no_normal_fit-95conf_val',
#  'ood_auroc_gpc-eye-mode:max-relative:True:no_loc_fit-mask_val',
#  'ood_aucpr_gpc-diag-mode:max-relative:True:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:True:no_loc_fit-mask_val',
#  'ood_aucpr_gpc-full-mode:max-relative:True:no_ber_fit-95conf_val',
#  'ood_aucpr_gpc-iso-mode:max-relative:False:no_ber_fit-95conf_val',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:True:no_ber_fit-mask_val',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:True:no_loc_fit-95conf_test',
#  'ood_auroc_gpc-full-mode:max-relative:True:no_loc_fit-95conf_test',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:True:no_ber_fit-95conf_val',
#  'accuracy_id_test_test',
#  'ood_auroc_logit-energy_loc-no-edges_test',
#  'ood_aucpr_gpc-diag-mode:max-relative:False:no_loc_fit-mask_test',
#  'accuracy_normal-val_normal_val',
#  'ood_aucpr_gpc-full-mode:max-relative:True:no_loc_fit-mask_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:False:no_normal_fit-mask_test',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'misclassification_aucpr_feature-distance_loc_fit-mask_val',
#  'misclassification_auroc_gpc-iso-mode:max-relative:False:no_ber_fit-mask_val',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:True:no_normal_fit-95conf_val',
#  'misclassification_auroc_feature-distance_loc_fit-95conf_test',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:True:no_ber_fit-95conf_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:False:no_normal_fit-95conf_val',
#  'ood_aucpr_max-score_loc_test',
#  'accuracy_id_ber-test_ber_test',
#  'ood_auroc_gpc-iso-mode:weighted-relative:True:no_ber_fit-95conf_test',
#  'ood_auroc_gpc-eye-mode:weighted-relative:True:no_loc_fit-mask_val',
#  'empirical_lipschitz_test_slope_min_perturbation_noise_test',
#  'ood_aucpr_feature-distance_loc_fit-95conf_test',
#  'ood_aucpr_gpc-eye-mode:max-relative:True:no_ber_fit-95conf_val',
#  'ood_aucpr_gpc-eye-mode:max-relative:False:no_normal_fit-mask_test',
#  'ood_aucpr_gpc-iso-mode:max-relative:False:no_loc_fit-95conf_test',
#  'empirical_lipschitz_test_slope_median_perturbation_noise_test',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:False:no_normal_fit-mask_val',
#  'ood_auroc_gpc-full-mode:max-relative:True:no_ber_fit-95conf_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:True:no_normal_fit-mask_test',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:False:no_ber_fit-95conf_val',
#  'ood_auroc_gpc-eye-mode:max-relative:False:no_loc_fit-mask_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:True:no_normal_fit-95conf_val',
#  'misclassification_auroc_gpc-diag-mode:max-relative:False:no_ber_fit-95conf_test',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:False:no_normal_fit-mask_test',
#  'ood_auroc_gpc-full-mode:max-relative:False:no_loc_fit-mask_test',
#  'ood_auroc_gpc-iso-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'ood_aucpr_gpc-iso-mode:max-relative:True:no_loc_fit-95conf_test',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:False:no_ber_fit-mask_val',
#  'misclassification_auroc_gpc-iso-mode:max-relative:False:no_normal_fit-95conf_val',
#  'misclassification_auroc_gpc-full-mode:max-relative:True:no_loc_fit-95conf_val',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:True:no_ber_fit-mask_val',
#  'ood_aucpr_gpc-iso-mode:max-relative:False:no_ber_fit-95conf_test',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'misclassification_auroc_gpc-eye-mode:max-relative:False:no_ber_fit-95conf_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:True:no_ber_fit-mask_test',
#  'ood_aucpr_gpc-full-mode:max-relative:False:no_normal_fit-95conf_val',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:True:no_normal_fit-95conf_test',
#  'misclassification_aucpr_feature-distance_loc_fit-mask_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:True:no_ber_fit-mask_test',
#  'misclassification_aucpr_max-score_normal-no-edges_test',
#  'ood_auroc_gpc-diag-mode:weighted-relative:True:no_loc_fit-95conf_val',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:True:no_loc_fit-mask_test',
#  'accuracy_id_ber-val_ber-no-edges_val',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:True:no_ber_fit-mask_test',
#  'ood_auroc_gpc-iso-mode:weighted-relative:False:no_normal_fit-mask_val',
#  'ood_auroc_gpc-diag-mode:max-relative:True:no_loc_fit-95conf_test',
#  'ood_aucpr_total-predictive-entropy_loc_test',
#  'ood_aucpr_gpc-full-mode:max-relative:False:no_ber_fit-mask_val',
#  'misclassification_aucpr_logit-energy_normal_val',
#  'ood_auroc_gpc-eye-mode:max-relative:True:no_loc_fit-95conf_val',
#  'ood_auroc_gpc-diag-mode:weighted-relative:True:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:True:no_loc_fit-95conf_val',
#  'misclassification_auroc_gpc-eye-mode:max-relative:False:no_normal_fit-mask_test',
#  'ood_aucpr_gpc-full-mode:weighted-relative:False:no_ber_fit-mask_val',
#  'misclassification_auroc_gpc-full-mode:max-relative:True:no_normal_fit-mask_test',
#  'misclassification_auroc_gpc-full-mode:max-relative:False:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-full-mode:max-relative:False:no_normal_fit-mask_test',
#  'ood_auroc_gpc-eye-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:True:no_loc_fit-95conf_test',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:True:no_loc_fit-mask_test',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:True:no_loc_fit-95conf_val',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'ood_aucpr_gpc-iso-mode:max-relative:False:no_ber_fit-mask_val',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:False:no_loc_fit-95conf_test',
#  'misclassification_aucpr_gpc-full-mode:max-relative:True:no_loc_fit-95conf_val',
#  'accuracy_ood_ood-test_loc_test',
#  'misclassification_auroc_logit-energy_normal-no-edges_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:True:no_ber_fit-mask_test',
#  'ood_auroc_max-score_normal-no-edges_val',
#  'accuracy_ood_normal-test_normal_test',
#  'misclassification_auroc_gpc-eye-mode:max-relative:False:no_normal_fit-95conf_val',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:False:no_normal_fit-95conf_val',
#  'empirical_lipschitz_test_slope_mean_perturbation_noise_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:False:no_loc_fit-95conf_test',
#  'accuracy_ood_val_no-edges_val',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'misclassification_auroc_gpc-full-mode:max-relative:True:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:True:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'misclassification_auroc_total-predictive-entropy_ber_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:True:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'ood_aucpr_gpc-full-mode:weighted-relative:False:no_normal_fit-mask_test',
#  'accuracy_id_ber-val_ber_val',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:True:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:False:no_normal_fit-mask_val',
#  'ood_auroc_gpc-diag-mode:max-relative:False:no_loc_fit-mask_test',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:True:no_ber_fit-95conf_test',
#  'misclassification_auroc_feature-distance_loc_fit-mask_val',
#  'misclassification_aucpr_max-score_loc-no-edges_val',
#  'ood_aucpr_total-predictive-entropy_ber-no-edges_val',
#  'accuracy_ood_ood-val_loc_val',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:False:no_loc_fit-mask_test',
#  'ood_aucpr_gpc-diag-mode:max-relative:False:no_ber_fit-95conf_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'ood_aucpr_gpc-full-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:False:no_normal_fit-mask_val',
#  'misclassification_aucpr_total-predictive-entropy_ber-no-edges_test',
#  'misclassification_aucpr_logit-energy_ber-no-edges_test',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:False:no_ber_fit-mask_val',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:True:no_normal_fit-95conf_val',
#  'ood_auroc_gpc-full-mode:max-relative:False:no_normal_fit-95conf_val',
#  'misclassification_aucpr_max-score_ber_test',
#  'ood_aucpr_gpc-diag-mode:max-relative:False:no_normal_fit-95conf_test',
#  'misclassification_aucpr_feature-distance_ber_fit-mask_test',
#  'ood_auroc_gpc-full-mode:weighted-relative:True:no_normal_fit-mask_val',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:True:no_normal_fit-mask_val',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'misclassification_aucpr_gpc-full-mode:max-relative:True:no_ber_fit-mask_test',
#  'accuracy_ood-val_loc-no-edges_val',
#  'misclassification_auroc_total-predictive-entropy_normal-no-edges_test',
#  'accuracy_id_ber-test_ber-no-edges_test',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:True:no_normal_fit-mask_test',
#  'ood_aucpr_gpc-full-mode:weighted-relative:True:no_normal_fit-95conf_val',
#  'ood_aucpr_total-predictive-entropy_normal-no-edges_val',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:True:no_ber_fit-95conf_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:True:no_loc_fit-95conf_val',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:True:no_normal_fit-mask_val',
#  'misclassification_aucpr_total-predictive-entropy_ber-no-edges_val',
#  'ood_auroc_gpc-iso-mode:max-relative:True:no_normal_fit-mask_test',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-iso-mode:max-relative:False:no_ber_fit-95conf_test',
#  'ood_aucpr_logit-energy_ber-no-edges_val',
#  'misclassification_auroc_logit-energy_loc-no-edges_val',
#  'misclassification_auroc_max-score_loc_test',
#  'ood_aucpr_gpc-full-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'misclassification_aucpr_total-predictive-entropy_normal_val',
#  'ood_auroc_total-predictive-entropy_normal-no-edges_val',
#  'misclassification_auroc_gpc-full-mode:max-relative:True:no_ber_fit-95conf_test',
#  'accuracy_id_ood-test_loc_test',
#  'misclassification_aucpr_max-score_ber-no-edges_test',
#  'misclassification_auroc_total-predictive-entropy_normal_val',
#  'accuracy_ood_ber-test_ber_test',
#  'ood_auroc_gpc-full-mode:max-relative:True:no_ber_fit-mask_val',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:False:no_ber_fit-mask_val',
#  'misclassification_auroc_gpc-iso-mode:max-relative:True:no_loc_fit-95conf_val',
#  'misclassification_aucpr_total-predictive-entropy_ber_test',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:True:no_loc_fit-mask_val',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:True:no_ber_fit-95conf_val',
#  'ood_auroc_gpc-eye-mode:weighted-relative:False:no_loc_fit-95conf_val',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:True:no_normal_fit-95conf_val',
#  'misclassification_aucpr_logit-energy_loc_test',
#  'empirical_lipschitz_val_slope_min_perturbation_noise_val',
#  'ood_aucpr_gpc-iso-mode:max-relative:False:no_loc_fit-95conf_val',
#  'misclassification_aucpr_max-score_normal-no-edges_val',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:False:no_loc_fit-95conf_val',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'ood_auroc_gpc-eye-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'misclassification_auroc_gpc-eye-mode:max-relative:True:no_ber_fit-95conf_val',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:True:no_ber_fit-mask_test',
#  'ood_aucpr_gpc-full-mode:weighted-relative:True:no_loc_fit-95conf_test',
#  'misclassification_aucpr_gpc-full-mode:max-relative:False:no_ber_fit-mask_test',
#  'ood_aucpr_gpc-diag-mode:max-relative:True:no_ber_fit-mask_val',
#  'ood_aucpr_gpc-iso-mode:max-relative:True:no_ber_fit-95conf_val',
#  'ood_aucpr_gpc-eye-mode:max-relative:True:no_normal_fit-95conf_val',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:False:no_ber_fit-mask_val',
#  'ood_auroc_logit-energy_normal-no-edges_test',
#  'ood_aucpr_feature-distance_loc_fit-mask_test',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:True:no_ber_fit-95conf_test',
#  'ood_auroc_max-score_loc-no-edges_val',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'ood_auroc_gpc-eye-mode:max-relative:False:no_normal_fit-mask_val',
#  'ood_aucpr_feature-distance_ber_fit-mask_test',
#  'ood_aucpr_gpc-diag-mode:max-relative:True:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:True:no_loc_fit-mask_val',
#  'ood_auroc_logit-energy_ber_val',
#  'ood_aucpr_gpc-full-mode:weighted-relative:True:no_ber_fit-95conf_test',
#  'ood_auroc_gpc-iso-mode:max-relative:True:no_normal_fit-95conf_val',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:False:no_loc_fit-95conf_val',
#  'empirical_lipschitz_test_slope_max_perturbation_noise_test',
#  'ood_auroc_gpc-full-mode:weighted-relative:True:no_ber_fit-mask_val',
#  'misclassification_auroc_gpc-iso-mode:max-relative:False:no_loc_fit-mask_val',
#  'ood_auroc_gpc-diag-mode:weighted-relative:False:no_ber_fit-mask_val',
#  'ood_aucpr_gpc-diag-mode:max-relative:True:no_loc_fit-mask_test',
#  'ood_aucpr_feature-distance_normal_fit-95conf_test',
#  'ood_auroc_gpc-iso-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'misclassification_aucpr_feature-distance_normal_fit-95conf_val',
#  'misclassification_auroc_gpc-eye-mode:max-relative:True:no_loc_fit-95conf_test',
#  'accuracy_ood_ber-test_ber-no-edges_test',
#  'ood_auroc_total-predictive-entropy_loc-no-edges_val',
#  'misclassification_auroc_max-score_normal_test',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:False:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:False:no_loc_fit-95conf_test',
#  'misclassification_auroc_gpc-full-mode:max-relative:False:no_normal_fit-mask_test',
#  'ood_aucpr_logit-energy_normal_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:True:no_ber_fit-mask_test',
#  'ood_aucpr_total-predictive-entropy_normal-no-edges_test',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:True:no_normal_fit-95conf_val',
#  'ood_auroc_gpc-iso-mode:weighted-relative:False:no_loc_fit-95conf_val',
#  'ood_aucpr_max-score_loc-no-edges_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:True:no_ber_fit-95conf_val',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:True:no_ber_fit-95conf_test',
#  'empirical_lipschitz_val_slope_mean_perturbation_no-edges_val',
#  'ood_auroc_gpc-iso-mode:max-relative:False:no_loc_fit-mask_val',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'ood_auroc_gpc-eye-mode:weighted-relative:True:no_normal_fit-95conf_test',
#  'misclassification_auroc_max-score_ber-no-edges_test',
#  'ood_auroc_gpc-eye-mode:max-relative:False:no_loc_fit-mask_val',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:True:no_loc_fit-95conf_val',
#  'ood_aucpr_gpc-full-mode:weighted-relative:True:no_ber_fit-mask_val',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'misclassification_auroc_gpc-diag-mode:max-relative:False:no_loc_fit-95conf_val',
#  'ood_auroc_gpc-eye-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'ood_aucpr_total-predictive-entropy_ber_test',
#  'accuracy_ood_normal-val_normal_val',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'ood_aucpr_gpc-full-mode:weighted-relative:True:no_loc_fit-mask_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:True:no_loc_fit-95conf_test',
#  'misclassification_auroc_gpc-eye-mode:max-relative:False:no_ber_fit-mask_val',
#  'misclassification_aucpr_total-predictive-entropy_loc_test',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:True:no_ber_fit-95conf_val',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:True:no_loc_fit-mask_test',
#  'misclassification_auroc_logit-energy_loc-no-edges_test',
#  'ood_aucpr_gpc-full-mode:max-relative:False:no_loc_fit-mask_test',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:True:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:True:no_ber_fit-mask_val',
#  'ood_auroc_feature-distance_loc_fit-95conf_val',
#  'misclassification_aucpr_feature-distance_ber_fit-95conf_val',
#  'ood_auroc_gpc-eye-mode:max-relative:False:no_ber_fit-95conf_val',
#  'ood_aucpr_gpc-iso-mode:max-relative:False:no_loc_fit-mask_test',
#  'misclassification_aucpr_max-score_ber_val',
#  'ood_auroc_gpc-diag-mode:weighted-relative:True:no_loc_fit-mask_val',
#  'ood_auroc_gpc-diag-mode:max-relative:True:no_loc_fit-mask_val',
#  'misclassification_auroc_logit-energy_normal-no-edges_test',
#  'misclassification_aucpr_gpc-full-mode:max-relative:True:no_loc_fit-mask_test',
#  'misclassification_auroc_gpc-eye-mode:max-relative:False:no_loc_fit-95conf_val',
#  'ood_aucpr_total-predictive-entropy_normal_val',
#  'misclassification_auroc_gpc-diag-mode:max-relative:False:no_loc_fit-mask_test',
#  'ood_auroc_gpc-eye-mode:weighted-relative:True:no_loc_fit-mask_test',
#  'ood_aucpr_total-predictive-entropy_normal_test',
#  'misclassification_auroc_gpc-diag-mode:max-relative:False:no_loc_fit-95conf_test',
#  'accuracy_ood_ood-test_loc-no-edges_test',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:True:no_loc_fit-95conf_test',
#  'ood_auroc_gpc-iso-mode:max-relative:True:no_loc_fit-95conf_test',
#  'ood_aucpr_gpc-iso-mode:max-relative:False:no_ber_fit-mask_test',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:True:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:True:no_loc_fit-95conf_test',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:False:no_loc_fit-mask_test',
#  'ood_auroc_gpc-iso-mode:max-relative:True:no_loc_fit-mask_test',
#  'misclassification_auroc_total-predictive-entropy_normal-no-edges_val',
#  'ood_auroc_gpc-diag-mode:max-relative:True:no_normal_fit-mask_val',
#  'ood_auroc_feature-distance_ber_fit-mask_test',
#  'ood_auroc_gpc-eye-mode:weighted-relative:False:no_normal_fit-mask_val',
#  'misclassification_aucpr_gpc-full-mode:max-relative:False:no_ber_fit-95conf_val',
#  'ood_auroc_feature-distance_loc_fit-mask_val',
#  'ood_auroc_gpc-iso-mode:max-relative:False:no_loc_fit-mask_test',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:True:no_ber_fit-95conf_test',
#  'misclassification_aucpr_feature-distance_loc_fit-95conf_test',
#  'empirical_lipschitz_test_slope_min_perturbation_no-edges_test',
#  'misclassification_auroc_total-predictive-entropy_ber-no-edges_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:True:no_loc_fit-95conf_test',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:True:no_ber_fit-mask_val',
#  'misclassification_auroc_gpc-eye-mode:max-relative:True:no_loc_fit-95conf_val',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:False:no_ber_fit-mask_val',
#  'ood_aucpr_gpc-eye-mode:max-relative:False:no_normal_fit-mask_val',
#  'misclassification_auroc_gpc-diag-mode:max-relative:True:no_loc_fit-95conf_val',
#  'misclassification_aucpr_logit-energy_normal-no-edges_val',
#  'ood_auroc_gpc-iso-mode:max-relative:False:no_normal_fit-mask_test',
#  'ood_aucpr_gpc-full-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'ood_auroc_gpc-eye-mode:max-relative:False:no_normal_fit-95conf_val',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:False:no_ber_fit-mask_test',
#  'ood_aucpr_gpc-full-mode:max-relative:True:no_loc_fit-95conf_test',
#  'misclassification_aucpr_max-score_ber-no-edges_val',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:False:no_ber_fit-95conf_val',
#  'ood_aucpr_gpc-diag-mode:max-relative:True:no_ber_fit-mask_test',
#  'ood_auroc_gpc-diag-mode:max-relative:True:no_loc_fit-95conf_val',
#  'misclassification_aucpr_total-predictive-entropy_normal_test',
#  'ood_auroc_gpc-diag-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'misclassification_auroc_gpc-eye-mode:max-relative:True:no_ber_fit-95conf_test',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:True:no_normal_fit-95conf_test',
#  'ood_auroc_gpc-eye-mode:max-relative:False:no_ber_fit-mask_test',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:True:no_ber_fit-mask_test',
#  'ood_auroc_gpc-iso-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:True:no_normal_fit-95conf_val',
#  'ood_auroc_gpc-eye-mode:weighted-relative:True:no_normal_fit-mask_val',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:True:no_loc_fit-mask_val',
#  'misclassification_auroc_gpc-diag-mode:max-relative:True:no_loc_fit-mask_val',
#  'accuracy_ood-val_loc_val',
#  'misclassification_auroc_gpc-full-mode:max-relative:True:no_normal_fit-95conf_val',
#  'misclassification_aucpr_gpc-full-mode:max-relative:False:no_loc_fit-95conf_test',
#  'ood_auroc_feature-distance_normal_fit-mask_test',
#  'misclassification_aucpr_max-score_loc-no-edges_test',
#  'misclassification_auroc_gpc-iso-mode:max-relative:True:no_ber_fit-95conf_test',
#  'ood_auroc_max-score_ber-no-edges_val',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:False:no_ber_fit-95conf_test',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:True:no_normal_fit-mask_val',
#  'ood_aucpr_feature-distance_loc_fit-95conf_val',
#  'ood_aucpr_logit-energy_ber_val',
#  'ood_auroc_gpc-eye-mode:max-relative:True:no_normal_fit-mask_test',
#  'ood_auroc_gpc-full-mode:max-relative:False:no_loc_fit-95conf_val',
#  'misclassification_auroc_gpc-iso-mode:max-relative:False:no_normal_fit-mask_test',
#  'ood_aucpr_feature-distance_ber_fit-95conf_test',
#  'misclassification_auroc_gpc-iso-mode:max-relative:True:no_normal_fit-95conf_val',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:True:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-full-mode:max-relative:True:no_ber_fit-95conf_test',
#  'ece_val_no-edges_val',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:False:no_loc_fit-mask_test',
#  'ood_aucpr_feature-distance_loc_fit-mask_val',
#  'ood_aucpr_feature-distance_normal_fit-mask_test',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:True:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:False:no_loc_fit-mask_test',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:False:no_loc_fit-mask_val',
#  'ood_auroc_max-score_normal-no-edges_test',
#  'accuracy_ood_test_test',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:True:no_normal_fit-mask_val',
#  'misclassification_aucpr_total-predictive-entropy_normal-no-edges_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:False:no_normal_fit-mask_test',
#  'ood_auroc_gpc-full-mode:weighted-relative:True:no_normal_fit-95conf_val',
#  'ood_auroc_gpc-eye-mode:max-relative:False:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-full-mode:max-relative:False:no_loc_fit-mask_test',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'ood_auroc_logit-energy_ber-no-edges_test',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:False:no_ber_fit-95conf_val',
#  'ood_auroc_gpc-diag-mode:weighted-relative:False:no_loc_fit-mask_test',
#  'misclassification_auroc_gpc-eye-mode:max-relative:True:no_normal_fit-mask_test',
#  'misclassification_auroc_max-score_ber_val',
#  'ood_auroc_gpc-iso-mode:max-relative:True:no_loc_fit-mask_val',
#  'misclassification_auroc_feature-distance_normal_fit-mask_test',
# ...
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:True:no_loc_fit-mask_val',
#  'empirical_lipschitz_test_slope_mean_perturbation_no-edges_test',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:False:no_normal_fit-mask_val',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:True:no_normal_fit-mask_val',
#  'ood_aucpr_gpc-full-mode:weighted-relative:True:no_ber_fit-mask_test',
#  'ood_aucpr_max-score_normal_val',
#  'misclassification_auroc_gpc-diag-mode:max-relative:False:no_ber_fit-mask_val',
#  'misclassification_auroc_gpc-iso-mode:max-relative:True:no_loc_fit-mask_test',
#  'misclassification_auroc_gpc-full-mode:max-relative:False:no_ber_fit-mask_val',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'misclassification_auroc_total-predictive-entropy_loc_val',
#  'misclassification_auroc_gpc-diag-mode:max-relative:True:no_loc_fit-95conf_test',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:True:no_normal_fit-mask_val',
#  'misclassification_auroc_gpc-eye-mode:max-relative:True:no_normal_fit-mask_val',
#  'misclassification_auroc_gpc-eye-mode:max-relative:True:no_loc_fit-mask_test',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:True:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:True:no_loc_fit-95conf_val',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'ood_aucpr_gpc-iso-mode:max-relative:True:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:True:no_loc_fit-mask_val',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:True:no_ber_fit-95conf_test',
#  'ood_auroc_gpc-eye-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'ood_aucpr_gpc-full-mode:weighted-relative:True:no_loc_fit-95conf_val',
#  'misclassification_auroc_gpc-iso-mode:max-relative:True:no_loc_fit-mask_val',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'ood_auroc_gpc-eye-mode:weighted-relative:True:no_ber_fit-95conf_val',
#  'misclassification_auroc_gpc-full-mode:max-relative:False:no_ber_fit-95conf_val',
#  'misclassification_auroc_gpc-diag-mode:max-relative:False:no_normal_fit-mask_test',
#  'ood_aucpr_total-predictive-entropy_ber_val',
#  'ood_auroc_gpc-full-mode:max-relative:False:no_normal_fit-95conf_test',
#  'ood_auroc_gpc-iso-mode:max-relative:False:no_ber_fit-95conf_val',
#  'ood_aucpr_gpc-full-mode:max-relative:True:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:True:no_loc_fit-95conf_val',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:True:no_loc_fit-mask_val',
#  'ood_aucpr_gpc-diag-mode:max-relative:False:no_normal_fit-mask_val',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:False:no_ber_fit-mask_val',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:True:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:False:no_normal_fit-mask_val',
#  'ood_auroc_gpc-full-mode:max-relative:True:no_normal_fit-95conf_val',
#  'ood_auroc_gpc-eye-mode:max-relative:False:no_ber_fit-95conf_test',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'ood_auroc_gpc-diag-mode:weighted-relative:True:no_ber_fit-95conf_val',
#  'ood_aucpr_gpc-iso-mode:max-relative:True:no_normal_fit-mask_test',
#  'ood_auroc_feature-distance_ber_fit-mask_val',
#  'misclassification_auroc_gpc-eye-mode:max-relative:True:no_ber_fit-mask_val',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:True:no_ber_fit-mask_val',
#  'misclassification_aucpr_gpc-full-mode:max-relative:True:no_loc_fit-mask_val',
#  'empirical_lipschitz_val_slope_median_perturbation_noise_val',
#  'ood_auroc_max-score_normal_test',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'misclassification_auroc_gpc-eye-mode:max-relative:True:no_loc_fit-mask_val',
#  'misclassification_auroc_gpc-diag-mode:weighted-relative:False:no_ber_fit-mask_val',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:False:no_loc_fit-mask_test',
#  'misclassification_auroc_gpc-full-mode:max-relative:False:no_loc_fit-mask_test',
#  'ood_aucpr_gpc-full-mode:weighted-relative:False:no_normal_fit-mask_val',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'ood_aucpr_gpc-iso-mode:max-relative:True:no_ber_fit-95conf_test',
#  'ood_auroc_gpc-iso-mode:max-relative:False:no_ber_fit-mask_test',
#  'ood_auroc_gpc-full-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'misclassification_auroc_gpc-diag-mode:max-relative:True:no_normal_fit-95conf_val',
#  'ood_aucpr_gpc-eye-mode:max-relative:True:no_ber_fit-mask_test',
#  'ood_auroc_gpc-iso-mode:max-relative:False:no_normal_fit-95conf_test',
#  'ood_aucpr_gpc-full-mode:max-relative:False:no_ber_fit-95conf_test',
#  'ood_aucpr_gpc-full-mode:max-relative:False:no_ber_fit-95conf_val',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:True:no_normal_fit-95conf_test',
#  'ood_auroc_max-score_normal_val',
#  'misclassification_auroc_max-score_normal-no-edges_val',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:False:no_loc_fit-mask_test',
#  'misclassification_auroc_gpc-eye-mode:max-relative:True:no_normal_fit-95conf_val',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:False:no_ber_fit-mask_val',
#  'ood_aucpr_gpc-eye-mode:max-relative:False:no_ber_fit-mask_test',
#  'ood_auroc_gpc-full-mode:max-relative:True:no_loc_fit-95conf_val',
#  'ood_auroc_gpc-iso-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'ood_auroc_logit-energy_loc_val',
#  'misclassification_aucpr_feature-distance_normal_fit-mask_val',
#  'misclassification_auroc_gpc-diag-mode:max-relative:True:no_ber_fit-mask_test',
#  'ood_auroc_gpc-diag-mode:max-relative:False:no_loc_fit-95conf_test',
#  'ood_auroc_total-predictive-entropy_loc_val',
#  'ood_aucpr_gpc-diag-mode:max-relative:False:no_loc_fit-95conf_val',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:False:no_loc_fit-mask_val',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:False:no_ber_fit-95conf_val',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:False:no_loc_fit-mask_test',
#  'accuracy_id_val_no-edges_val',
#  'ood_aucpr_max-score_ber_val',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:True:no_loc_fit-mask_test',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:True:no_ber_fit-95conf_val',
#  'misclassification_auroc_gpc-full-mode:max-relative:True:no_normal_fit-mask_val',
#  'misclassification_auroc_feature-distance_loc_fit-mask_test',
#  'ood_aucpr_logit-energy_loc-no-edges_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:False:no_ber_fit-95conf_val',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:True:no_loc_fit-mask_val',
#  'ood_aucpr_feature-distance_ber_fit-mask_val',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'ood_aucpr_gpc-eye-mode:max-relative:True:no_normal_fit-mask_val',
#  'ood_aucpr_gpc-eye-mode:max-relative:True:no_loc_fit-95conf_test',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:False:no_ber_fit-95conf_val',
#  'accuracy_ber-val_ber_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:False:no_ber_fit-mask_val',
#  'ood_aucpr_feature-distance_normal_fit-mask_val',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:True:no_loc_fit-95conf_val',
#  'accuracy_ood_val_val',
#  'ood_aucpr_feature-distance_ber_fit-95conf_val',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:False:no_loc_fit-mask_test',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:True:no_normal_fit-95conf_val',
#  'ood_auroc_gpc-iso-mode:max-relative:True:no_ber_fit-mask_test',
#  'ood_aucpr_gpc-diag-mode:max-relative:True:no_ber_fit-95conf_val',
#  'ood_auroc_gpc-diag-mode:max-relative:False:no_normal_fit-95conf_val',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:True:no_loc_fit-95conf_val',
#  'ood_auroc_gpc-full-mode:max-relative:False:no_loc_fit-mask_val',
#  'ood_auroc_max-score_loc-no-edges_test',
#  'misclassification_auroc_gpc-diag-mode:max-relative:False:no_loc_fit-mask_val',
#  'ood_auroc_gpc-eye-mode:weighted-relative:True:no_normal_fit-mask_test',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:True:no_loc_fit-mask_test',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:True:no_normal_fit-mask_val',
#  'misclassification_aucpr_feature-distance_ber_fit-95conf_test',
#  'ood_auroc_gpc-diag-mode:max-relative:True:no_normal_fit-95conf_test',
#  'misclassification_auroc_gpc-full-mode:max-relative:True:no_ber_fit-mask_val',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:False:no_loc_fit-mask_val',
#  'ood_auroc_gpc-diag-mode:max-relative:True:no_ber_fit-95conf_test',
#  'misclassification_auroc_gpc-iso-mode:weighted-relative:False:no_normal_fit-mask_val',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:False:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:True:no_ber_fit-mask_val',
#  'ood_aucpr_max-score_loc_val',
#  'ood_auroc_gpc-eye-mode:weighted-relative:False:no_ber_fit-mask_val',
#  'ood_aucpr_gpc-iso-mode:max-relative:True:no_loc_fit-mask_test',
#  'ood_aucpr_gpc-full-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'ood_aucpr_gpc-eye-mode:weighted-relative:False:no_normal_fit-mask_val',
#  'misclassification_auroc_gpc-eye-mode:max-relative:False:no_loc_fit-mask_test',
#  'ood_aucpr_max-score_ber-no-edges_test',
#  'ood_aucpr_gpc-eye-mode:max-relative:False:no_loc_fit-95conf_test',
#  'ood_aucpr_gpc-iso-mode:max-relative:True:no_ber_fit-mask_val',
#  'ood_aucpr_gpc-full-mode:max-relative:True:no_normal_fit-95conf_val',
#  'misclassification_auroc_total-predictive-entropy_normal_test',
#  'misclassification_auroc_gpc-iso-mode:max-relative:False:no_loc_fit-95conf_val',
#  'ood_auroc_gpc-eye-mode:weighted-relative:True:no_loc_fit-95conf_test',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:True:no_normal_fit-95conf_val',
#  'ood_auroc_gpc-eye-mode:max-relative:False:no_normal_fit-95conf_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:False:no_loc_fit-mask_val',
#  'misclassification_auroc_max-score_normal_val',
#  'ood_aucpr_gpc-iso-mode:max-relative:True:no_ber_fit-mask_test',
#  'misclassification_aucpr_gpc-full-mode:max-relative:False:no_normal_fit-mask_val',
#  'misclassification_aucpr_gpc-eye-mode:weighted-relative:True:no_normal_fit-mask_val',
#  'ood_auroc_gpc-eye-mode:max-relative:False:no_loc_fit-95conf_test',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:True:no_loc_fit-mask_val',
#  'ood_aucpr_gpc-full-mode:weighted-relative:True:no_normal_fit-mask_test',
#  'ood_auroc_gpc-eye-mode:weighted-relative:False:no_normal_fit-mask_test',
#  'ood_auroc_gpc-eye-mode:weighted-relative:True:no_ber_fit-95conf_test',
#  'misclassification_aucpr_gpc-diag-mode:weighted-relative:True:no_loc_fit-95conf_val',
#  'ood_auroc_gpc-full-mode:max-relative:True:no_normal_fit-mask_val',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:False:no_normal_fit-mask_val',
#  'ood_auroc_gpc-diag-mode:max-relative:False:no_normal_fit-mask_test',
#  'misclassification_auroc_gpc-full-mode:max-relative:False:no_loc_fit-95conf_test',
#  'ood_auroc_gpc-diag-mode:max-relative:True:no_normal_fit-95conf_val',
#  'ood_auroc_gpc-diag-mode:weighted-relative:False:no_ber_fit-95conf_test',
#  'misclassification_auroc_gpc-eye-mode:max-relative:False:no_normal_fit-95conf_test',
#  'ood_auroc_gpc-iso-mode:max-relative:False:no_loc_fit-95conf_test',
#  'ood_aucpr_gpc-iso-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:False:no_ber_fit-mask_test',
#  'ood_auroc_gpc-iso-mode:weighted-relative:False:no_normal_fit-mask_test',
#  'ood_auroc_gpc-iso-mode:max-relative:False:no_normal_fit-mask_val',
#  'misclassification_auroc_feature-distance_loc_fit-95conf_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:False:no_ber_fit-mask_test',
#  'ood_auroc_gpc-full-mode:max-relative:False:no_normal_fit-mask_val',
#  'ood_aucpr_gpc-diag-mode:max-relative:False:no_ber_fit-95conf_val',
#  'ood_auroc_gpc-iso-mode:weighted-relative:True:no_loc_fit-95conf_test',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:True:no_ber_fit-95conf_val',
#  'accuracy_normal-val_normal-no-edges_val',
#  'ood_auroc_total-predictive-entropy_ber_val',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:True:no_normal_fit-95conf_test',
#  'misclassification_auroc_gpc-diag-mode:max-relative:True:no_normal_fit-mask_test',
#  'ood_aucpr_gpc-iso-mode:max-relative:False:no_normal_fit-95conf_val',
#  'ood_auroc_gpc-eye-mode:max-relative:False:no_ber_fit-mask_val',
#  'ood_auroc_gpc-eye-mode:weighted-relative:True:no_ber_fit-mask_test',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:True:no_loc_fit-mask_val',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:True:no_loc_fit-95conf_test',
#  'ood_auroc_gpc-diag-mode:max-relative:False:no_ber_fit-mask_test',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'ood_aucpr_gpc-diag-mode:weighted-relative:True:no_loc_fit-95conf_val',
#  'ood_auroc_gpc-full-mode:weighted-relative:False:no_loc_fit-95conf_test',
#  'empirical_lipschitz_val_slope_max_perturbation_noise_val',
#  'misclassification_aucpr_feature-distance_ber_fit-mask_val',
#  'ood_auroc_gpc-iso-mode:max-relative:False:no_ber_fit-95conf_test',
#  'empirical_lipschitz_test_slope_max_perturbation_no-edges_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:True:no_normal_fit-95conf_test',
#  'ood_aucpr_gpc-full-mode:max-relative:True:no_ber_fit-mask_val',
#  'ood_auroc_gpc-diag-mode:max-relative:False:no_loc_fit-95conf_val',
#  'misclassification_aucpr_gpc-iso-mode:max-relative:False:no_ber_fit-mask_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:False:no_normal_fit-95conf_val',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:True:no_ber_fit-95conf_test',
#  'misclassification_aucpr_gpc-diag-mode:max-relative:False:no_ber_fit-95conf_test',
#  'ood_aucpr_gpc-eye-mode:max-relative:False:no_loc_fit-mask_test',
#  'misclassification_aucpr_gpc-eye-mode:max-relative:True:no_normal_fit-95conf_test',
#  'ood_aucpr_gpc-full-mode:max-relative:True:no_ber_fit-95conf_test',
#  'accuracy_id_ood-test_loc-no-edges_test',
#  'ood_auroc_gpc-full-mode:max-relative:False:no_ber_fit-95conf_test',
#  'misclassification_aucpr_gpc-full-mode:max-relative:True:no_normal_fit-mask_val',
#  'misclassification_auroc_logit-energy_ber_val',
#  'misclassification_aucpr_logit-energy_normal-no-edges_test',
#  'ood_aucpr_feature-distance_normal_fit-95conf_val',
#  'misclassification_auroc_gpc-eye-mode:weighted-relative:False:no_ber_fit-95conf_val',
#  'accuracy_id_normal-val_normal-no-edges_val',
#  'misclassification_aucpr_gpc-full-mode:weighted-relative:False:no_normal_fit-mask_test',
#  'ood_aucpr_gpc-eye-mode:max-relative:False:no_normal_fit-95conf_test',
#  'misclassification_auroc_max-score_normal-no-edges_test',
#  'misclassification_auroc_gpc-eye-mode:max-relative:True:no_ber_fit-mask_test',
#  'misclassification_aucpr_gpc-iso-mode:weighted-relative:False:no_normal_fit-mask_test',
#  'ood_auroc_gpc-full-mode:max-relative:True:no_ber_fit-95conf_val',
#  'ood_aucpr_logit-energy_loc_test',
#  'misclassification_auroc_gpc-full-mode:max-relative:True:no_loc_fit-95conf_test',
#  'misclassification_aucpr_feature-distance_normal_fit-mask_test',
#  'ood_aucpr_gpc-full-mode:weighted-relative:True:no_normal_fit-95conf_test',
#  'ood_auroc_gpc-diag-mode:weighted-relative:False:no_normal_fit-mask_test',
#  'misclassification_aucpr_max-score_normal_val',
#  'misclassification_auroc_logit-energy_loc_test',
#  'misclassification_auroc_gpc-full-mode:weighted-relative:False:no_loc_fit-mask_test',
#  ...]

# %%
METRIC = 'Metric'
AUROC = 'AUC-ROC'
AUCPR = 'AUC-PR'

SETTING = 'Setting'
HYBRID = 'Inductive'
TRANSDUCTIVE = 'Transductive'
LOC = 'Leave Out Classes'
NORMAL = 'Normal'
BERNOULLI = 'Bernoulli'
NO_EDGES = 'No Edges'
PROXY = 'Proxy'
EXPERIMENT = 'Experiment'
DATASET = 'Dataset'


RESIDUAL = 'Residual'
SPECTRAL_NORM = 'Spectral Norm'
SPECTRAL_OUTPUT_NORM = 'Spectral Norm on Last Layer'
WEIGHT_SCALE = 'Weight Scale'
LOWER_LIPSCHITZ = 'Empirical Lower Lipschitz Bound'
UPPER_LIPSCHITZ = 'Empirical Upper Lipschitz Bound'



EPISTEMIC = 'Epistemic'
ALEATORIC = 'Aleatoric'

ACCURACY = 'Accuracy'
ECE = 'Expected Calibration Error'

# %%
mode = 'val'

# %%
ex['config']['model']
# Out:
# {'activation': 'leaky_relu',
#  'hidden_sizes': [64],
#  'leaky_relu_slope': 0.01,
#  'model_type': 'gcn',
#  'residual': False,
#  'use_bias': True,
#  'use_spectral_norm': True,
#  'use_spectral_norm_on_last_layer': True,
#  'weight_scale': 200.0}

# %%
epistemic_proxy = 'ood_gpc-diag-mode:weighted-relative:False:no_fit-95conf'
aleatoric_proxy = 'ood_max-score'
# metric = 'auroc'
# METRIC = 'AUC-ROC'
metric = 'auroc'
METRIC = 'AUROC'

# %%
Counter(ex['config']['model']['use_spectral_norm_on_last_layer'] for ex in experiments)
# Out:
# Counter({False: 2430, True: 2189})

# %%
data_proxy, data_acc_ece = [], []

unrecognized = set()

for ex in experiments:
    cfg = ex['config']
    base = {
        SETTING : {dc.HYBRID : HYBRID, dc.TRANSDUCTIVE : TRANSDUCTIVE}[cfg['data']['setting']],
        RESIDUAL : cfg['model']['residual'],
        SPECTRAL_NORM : cfg['model']['use_spectral_norm'],
        WEIGHT_SCALE : cfg['model']['weight_scale'],
        SPECTRAL_OUTPUT_NORM : cfg['model']['use_spectral_norm_on_last_layer'],
        DATASET :  cfg['data']['dataset'],
        LOWER_LIPSCHITZ : ex['metrics'][f'empirical_lipschitz_{mode}_slope_min_perturbation_noise_{mode}'][0]['value'],
        UPPER_LIPSCHITZ : ex['metrics'][f'empirical_lipschitz_{mode}_slope_max_perturbation_noise_{mode}'][0]['value'],
    }
    data_acc_ece.append(base | {
        ACCURACY : ex['metrics'][f'accuracy_{mode}_{mode}'][0],
        ECE : ex['metrics'][f'ece_{mode}_{mode}'][0]['value'],
    })
    for k, vs in ex['metrics'].items():
        if metric in k and k.endswith('_' + mode):
            k = k.replace(metric + '_', '').replace('_' + mode, '')
            if '-no-edges' in k:
                no_edges = True
                k = k.replace('-no-edges', '')
            else:
                no_edges = False
                
            if '_loc' in k or '-loc' in k:
                exp = LOC
                k = k.replace('_loc', '').replace('-loc', '')
            elif '_ber' in k or '-ber' in k:
                exp = BERNOULLI
                k = k.replace('_ber', '').replace('-ber', '')
            elif '_normal' in k or '-normal' in k:
                exp = NORMAL
                k = k.replace('_normal', '').replace('-normal', '')
            else:
                raise ValueError(k)
            
            metric_cfg = {}
            
            if k == aleatoric_proxy:
                metric_cfg[PROXY] = ALEATORIC
            elif k == epistemic_proxy:
                metric_cfg[PROXY] = EPISTEMIC
            else:
                unrecognized.add(k)
                continue
            
            for v in vs:
                v = v['value']
                data_proxy.append({
                    METRIC : v,
                    NO_EDGES : no_edges,
                    EXPERIMENT : exp,
                } | metric_cfg | base | {
                    ACCURACY : ex['metrics'][f'accuracy_{mode}_{mode}'][0],
                    ECE : ex['metrics'][f'ece_{mode}_{mode}'][0]['value'],
                }
                )

# %%
list(unrecognized)
# Out:
# ['misclassification_gpc-iso-mode:max-relative:True:no_fit-mask',
#  'ood_gpc-full-mode:weighted-relative:True:no_fit-mask',
#  'ood_gpc-iso-mode:max-relative:False:no_fit-mask',
#  'ood_feature-distance_fit-95conf',
#  'ood_gpc-iso-mode:weighted-relative:True:no_fit-95conf',
#  'misclassification_gpc-iso-mode:max-relative:False:no_fit-mask',
#  'misclassification_max-score',
#  'ood_gpc-eye-mode:weighted-relative:True:no_fit-95conf',
#  'misclassification_gpc-diag-mode:weighted-relative:True:no_fit-95conf',
#  'misclassification_gpc-eye-mode:max-relative:False:no_fit-mask',
#  'ood_gpc-eye-mode:weighted-relative:True:no_fit-mask',
#  'ood_gpc-full-mode:weighted-relative:True:no_fit-95conf',
#  'ood_gpc-eye-mode:max-relative:False:no_fit-mask',
#  'ood_gpc-full-mode:max-relative:False:no_fit-95conf',
#  'misclassification_feature-distance_fit-mask',
#  'misclassification_gpc-full-mode:weighted-relative:False:no_fit-mask',
#  'misclassification_gpc-full-mode:weighted-relative:False:no_fit-95conf',
#  'ood_gpc-diag-mode:max-relative:False:no_fit-95conf',
#  'misclassification_gpc-iso-mode:max-relative:False:no_fit-95conf',
#  'ood_gpc-eye-mode:max-relative:True:no_fit-95conf',
#  'misclassification_gpc-full-mode:max-relative:True:no_fit-95conf',
#  'misclassification_gpc-iso-mode:weighted-relative:False:no_fit-95conf',
#  'misclassification_gpc-diag-mode:weighted-relative:False:no_fit-mask',
#  'misclassification_gpc-diag-mode:weighted-relative:False:no_fit-95conf',
#  'misclassification_logit-energy',
#  'misclassification_gpc-full-mode:weighted-relative:True:no_fit-95conf',
#  'misclassification_gpc-eye-mode:max-relative:False:no_fit-95conf',
#  'misclassification_gpc-full-mode:max-relative:False:no_fit-mask',
#  'misclassification_gpc-full-mode:max-relative:False:no_fit-95conf',
#  'ood_gpc-iso-mode:weighted-relative:False:no_fit-mask',
#  'ood_gpc-full-mode:max-relative:True:no_fit-95conf',
#  'misclassification_gpc-iso-mode:weighted-relative:True:no_fit-95conf',
#  'misclassification_gpc-eye-mode:weighted-relative:True:no_fit-95conf',
#  'misclassification_gpc-full-mode:weighted-relative:True:no_fit-mask',
#  'misclassification_feature-distance_fit-95conf',
#  'misclassification_gpc-eye-mode:max-relative:True:no_fit-mask',
#  'ood_logit-energy',
#  'ood_gpc-full-mode:weighted-relative:False:no_fit-mask',
#  'misclassification_gpc-diag-mode:max-relative:True:no_fit-95conf',
#  'ood_gpc-eye-mode:weighted-relative:False:no_fit-mask',
#  'misclassification_gpc-iso-mode:weighted-relative:True:no_fit-mask',
#  'misclassification_total-predictive-entropy',
#  'ood_gpc-iso-mode:max-relative:True:no_fit-mask',
#  'ood_gpc-eye-mode:weighted-relative:False:no_fit-95conf',
#  'misclassification_gpc-diag-mode:max-relative:True:no_fit-mask',
#  'ood_gpc-iso-mode:max-relative:False:no_fit-95conf',
#  'ood_gpc-diag-mode:weighted-relative:True:no_fit-95conf',
#  'misclassification_gpc-diag-mode:max-relative:False:no_fit-95conf',
#  'ood_gpc-diag-mode:max-relative:False:no_fit-mask',
#  'ood_gpc-full-mode:max-relative:True:no_fit-mask',
#  'ood_gpc-diag-mode:weighted-relative:True:no_fit-mask',
#  'misclassification_gpc-eye-mode:max-relative:True:no_fit-95conf',
#  'ood_gpc-iso-mode:weighted-relative:False:no_fit-95conf',
#  'ood_gpc-full-mode:max-relative:False:no_fit-mask',
#  'ood_gpc-diag-mode:max-relative:True:no_fit-mask',
#  'misclassification_gpc-diag-mode:weighted-relative:True:no_fit-mask',
#  'ood_gpc-iso-mode:weighted-relative:True:no_fit-mask',
#  'ood_gpc-iso-mode:max-relative:True:no_fit-95conf',
#  'misclassification_gpc-iso-mode:max-relative:True:no_fit-95conf',
#  'ood_gpc-diag-mode:weighted-relative:False:no_fit-mask',
#  'misclassification_gpc-eye-mode:weighted-relative:False:no_fit-mask',
#  'misclassification_gpc-diag-mode:max-relative:False:no_fit-mask',
#  'ood_gpc-eye-mode:max-relative:True:no_fit-mask',
#  'misclassification_gpc-eye-mode:weighted-relative:False:no_fit-95conf',
#  'ood_gpc-diag-mode:max-relative:True:no_fit-95conf',
#  'ood_gpc-eye-mode:max-relative:False:no_fit-95conf',
#  'misclassification_gpc-full-mode:max-relative:True:no_fit-mask',
#  'misclassification_gpc-iso-mode:weighted-relative:False:no_fit-mask',
#  'misclassification_gpc-eye-mode:weighted-relative:True:no_fit-mask',
#  'ood_total-predictive-entropy',
#  'ood_gpc-full-mode:weighted-relative:False:no_fit-95conf',
#  'ood_feature-distance_fit-mask']

# %%
df_proxy = pd.DataFrame(data_proxy)
df_acc_ece = pd.DataFrame(data_acc_ece)

# %%
set(df_proxy[WEIGHT_SCALE])
# Out:
# {0.5, 0.9, 1.0, 1.1, 1.5, 2.0, 5.0, 10.0, 15.0, 20.0, 100.0, 200.0}

# %%
def plot_facet_lines_with_uncertainty_and_no_spectral_norm_as_point(df, x=None, y=None, row=None, col=None, hue=None, style=None, 
                                      ci=95, 
                                      facet_kws = {'margin_titles' : True, 'height' : 4, }, log_x = True, binned=True):
    
    g = sns.FacetGrid(df, row = row, col = col, hue = hue, **facet_kws)
    
    styles = ['solid', 'dotted', 'dashed']
    markers = ['o', 'x', '+']
    label_to_color = {}
    style_to_linestyle = {}
    style_to_marker = {}
    style_name = style
    
    def plot_lines(x, y, style, sn, color=None, label=None, ci=ci):
        label_to_color[label] = color
        
        for style_idx, st in enumerate(sorted(np.unique(style).tolist())):
            style_to_linestyle[st] = styles[style_idx]
            style_to_marker[st] = markers[style_idx]
            # Bin the ones with spectral norm according to lipschitz constant
            
            x_style, y_style = x[(style == st) & (sn == True)], y[(style == st) & (sn == True)]
            if log_x:
                x_style = np.log(x_style)
            
            if binned:
                if x_style.shape[0] == 0:
                    continue
                else:
                    print(x_style.shape)
                mean, bin_edges, bin_idx = binned_statistic(x_style[np.isfinite(y_style)], y_style[np.isfinite(y_style)], statistic='mean', bins=10)
                std, _, _ = binned_statistic(x_style[np.isfinite(y_style)], y_style[np.isfinite(y_style)], bins=bin_edges, statistic='std')
                bin_centers = (0.5 * (bin_edges[:-1] + bin_edges[1:]))
                if log_x:
                    bin_centers = np.exp(bin_centers)
                
            else:
                bin_centers = np.sort(np.unique(x_style))
                mean = np.array([(y_style[x_style == center]).mean() for center in bin_centers])
                std = np.array([(y_style[x_style == center]).std() for center in bin_centers])
               
            plot_mask = np.isfinite(mean) & np.isfinite(std)

            plt.plot(bin_centers[plot_mask], mean[plot_mask], color=color, label=f'{label}, {st}', linestyle=styles[style_idx])
            plt.fill_between(bin_centers[plot_mask],( mean - std)[plot_mask], (mean + std)[plot_mask], alpha = 0.2, color=color)
             
            # Put the ones without spectral norm into one bin put as a point
            x_style, y_style = x[(style == st) & (sn == False)], y[(style == st) & (sn == False)]
            x_std, y_std = x_style.std(), y_style.std()
            _x, _y = np.array([x_style.mean()]), np.array([y_style.mean()])
            if (np.isfinite(_x) & np.isfinite(_y)).all():
                plt.errorbar(_x, _y, yerr=y_style.std(), xerr = x_style.std(), ecolor='gray', capsize=2, fmt=markers[style_idx], color=color)
        
    g.map(plot_lines, x, y, style, SPECTRAL_NORM, ci=ci)
    
    # Create a legend (extremely hacky)
    
    lines, line_labels = [], []
    for label, color in label_to_color.items():
        lines.append(Line2D([0], [0], color=color))
        line_labels.append(label)
    l1 = plt.legend(lines, line_labels, title=hue, loc='center left', bbox_to_anchor=(1.1, 1.25), frameon=False)
    
    lines, line_labels = [], []
    for style, ls in style_to_linestyle.items():
        lines.append(Line2D([0], [0], color='black', ls=ls))
        line_labels.append(style)
    l2 = plt.legend(lines, line_labels, title=f'{style_name}', loc='center left', bbox_to_anchor=(1.1, 0.99), frameon=False)
    
    
    lines, line_labels = [], []
    for style, marker in style_to_marker.items():
        lines.append(plt.errorbar([], [], xerr=[], yerr=[], color='black', ecolor='gray', capsize=10, fmt=marker))
        line_labels.append(style)
    l3 = plt.legend(lines, line_labels, title=f'{style_name},\nNo Spectral Norm', loc='center left', frameon=False, bbox_to_anchor=(1.1, 0.7))
    
    g.axes.flatten()[-1].add_artist(l1)
    g.axes.flatten()[-1].add_artist(l2)
    
    
    if log_x:
        g.set(xscale='log')
    return g

# %%
sns.set(context='notebook', font_scale=1.0)
sns.set_style("whitegrid")

g = plot_facet_lines_with_uncertainty_and_no_spectral_norm_as_point(
    df_proxy[
        (df_proxy[NO_EDGES] == False) & 
        (df_proxy[DATASET] == dc.CORA_FULL) &
        (df_proxy[SETTING] == HYBRID)
    ],
    x = LOWER_LIPSCHITZ, y = METRIC, col = EXPERIMENT, row = SPECTRAL_OUTPUT_NORM, hue = RESIDUAL, style = PROXY)
for ax in g.axes.flatten():
    ax.xaxis.grid(True, which='minor')
g.set_titles(row_template = '{row_name}', col_template = '{col_name}')
# Out:
# (107,)
# (107,)
# (104,)
# (104,)
# (90,)
# (90,)
# (89,)
# (89,)
# (90,)
# (90,)
# (89,)
# (89,)
# (98,)
# (98,)
# (99,)
# (99,)
# (89,)
# (89,)
# (89,)
# (89,)
# (89,)
# (89,)
# (89,)
# (89,)

# %%
sns.set(context='notebook', font_scale=1.0)
sns.set_style("whitegrid")

g = plot_facet_lines_with_uncertainty_and_no_spectral_norm_as_point(
    df_proxy[
        (df_proxy[NO_EDGES] == False) & 
        (df_proxy[DATASET] == dc.CORA_FULL) &
        (df_proxy[SETTING] == HYBRID)
    ],
    x = WEIGHT_SCALE, y = METRIC, col = EXPERIMENT, row = SPECTRAL_OUTPUT_NORM, hue = RESIDUAL, style = PROXY)
for ax in g.axes.flatten():
    ax.xaxis.grid(True, which='minor')
g.set_titles(row_template = '{row_name}', col_template = '{col_name}')
# Out:
# (107,)
# (107,)
# (104,)
# (104,)
# (90,)
# (90,)
# (89,)
# (89,)
# (90,)
# (90,)
# (89,)
# (89,)
# (98,)
# (98,)
# (99,)
# (99,)
# (89,)
# (89,)
# (89,)
# (89,)
# (89,)
# (89,)
# (89,)
# (89,)

# %%
df_proxy[(df_proxy[SPECTRAL_OUTPUT_NORM]) == False]
# Out:
#           AUROC  No Edges         Experiment      Proxy       Setting  \
# 0      0.919820      True  Leave Out Classes  Aleatoric  Transductive
# 1      0.975601     False  Leave Out Classes  Aleatoric  Transductive
# 2      0.897549     False  Leave Out Classes  Epistemic  Transductive
# 3      0.921930      True  Leave Out Classes  Aleatoric  Transductive
# 4      0.985227     False  Leave Out Classes  Aleatoric  Transductive
# ...         ...       ...                ...        ...           ...
# 20632  0.883952     False  Leave Out Classes  Aleatoric     Inductive
# 20633  0.739369     False  Leave Out Classes  Epistemic     Inductive
# 20634  0.672343      True  Leave Out Classes  Aleatoric     Inductive
# 20635  0.789755     False  Leave Out Classes  Aleatoric     Inductive
# 20636  0.673627     False  Leave Out Classes  Epistemic     Inductive
#
#        Residual  Spectral Norm  Weight Scale  Spectral Norm on Last Layer  \
# 0         False          False           1.0                        False
# 1         False          False           1.0                        False
# 2         False          False           1.0                        False
# 3         False          False           1.0                        False
# 4         False          False           1.0                        False
# ...         ...            ...           ...                          ...
# 20632      True           True         200.0                        False
# 20633      True           True         200.0                        False
# 20634      True           True         200.0                        False
# 20635      True           True         200.0                        False
# 20636      True           True         200.0                        False
#
#          Dataset  Empirical Lower Lipschitz Bound  \
# 0      cora_full                         0.004784
# 1      cora_full                         0.004784
# 2      cora_full                         0.004784
# 3      cora_full                         0.005137
# 4      cora_full                         0.005137
# ...          ...                              ...
# 20632  cora_full                         6.728300
# 20633  cora_full                         6.728300
# 20634  cora_full                         9.468613
# 20635  cora_full                         9.468613
# 20636  cora_full                         9.468613
#
#        Empirical Upper Lipschitz Bound  Accuracy  Expected Calibration Error
# 0                             0.764188  0.814286                    0.156444
# 1                             0.764188  0.814286                    0.156444
# 2                             0.764188  0.814286                    0.156444
# 3                             0.728910  0.785714                    0.096689
# 4                             0.728910  0.785714                    0.096689
# ...                                ...       ...                         ...
# 20632                        69.656641  0.842857                    0.057633
# 20633                        69.656641  0.842857                    0.057633
# 20634                       102.849854  0.721429                    0.048753
# 20635                       102.849854  0.721429                    0.048753
# 20636                       102.849854  0.721429                    0.048753
#
# [10851 rows x 14 columns]

# %%
np.unique(df_proxy[SPECTRAL_OUTPUT_NORM], return_counts=True)
# Out:
# (array([False,  True]), array([ 489, 4857]))
