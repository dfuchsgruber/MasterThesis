# %%
import matplotlib.pyplot as plt
import numpy as np
import seml
import pandas as pd
import json
from collections import defaultdict
# Out:
# /nfs/homedirs/fuchsgru/miniconda3/lib/python3.9/site-packages/seml/database.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
collection_name = 'week5_density_feature_space_grid'
collection = seml.database.get_collection(collection_name)
results = [{'config' : r['config'], 'result' : r['result'], 'id' : r['_id']} for r in collection.find() if r['status'] in ('COMPLETED',)]

# %%
len(results)
# Out:
# 4

# %%
def flatten_dict(d):
    new = dict()
    for k, v in d.items():
        if isinstance(v, dict):
            for kk, vv in flatten_dict(v).items():
                new[k + '.' + kk] = vv
        else:
            new[k] = v
    return new

# %%
# Collect everything into a data frame
df = defaultdict(list)
metrics_list = []
for result in results:
    for k, v in flatten_dict(result['config']).items():
        df[k].append(v)
    with open(result['result']) as f:
        metrics = json.load(f)
        metrics_dict = dict()
        for metric, values in metrics.items():
            metrics_dict[metric + '.mean'] = (np.array(values).mean())
            metrics_dict[metric + '.std'] = (np.array(values).std())
        metrics_list.append(metrics_dict)

metric_names = set()
for metrics_dict in metrics_list:
    metric_names.update(metrics_dict.keys())
for metrics_dict in metrics_list:
    for metric in metric_names:
        df[metric].append(metrics_dict.get(metric, np.nan))
        
df = pd.DataFrame(df)
df.index = [f"removeOOD:{str(df.loc[i]['data.train_labels_remove_other'])[0]}-residual:{str(df.loc[i]['model.residual'])[0]}" for i in df.index]

# %%
def get_hyperparams(name):
    name = name.split('.')[0].replace('auroc_', '')
    tokens = name.split('-')
    density_type = re.match('([a-zA-Z]+)[0-9]*', tokens[0]).groups()[0]
    if density_type == 'mog':
        num_components = int(tokens[0].replace('mog', ''))
    elif density_type == 'gpc':
        num_components = np.nan
    else:
        raise RuntimeError(f'Dont understand density {density_type}')
    if tokens[1] == 'no':
        dim_red = None
        dim_red_dim = np.nan
        per_class = np.nan
        diagonal_covariance = np.nan
    else:
        dim_red_dim, dim_red = re.match('([0-9]+)([a-zA-Z]+)', tokens[1]).groups()
        dim_red_dim = int(dim_red_dim)
        if density_type == 'gpc':
            per_class = tokens[2][2:] == 'T'
            diagonal_covariance = tokens[3][1:] == 'T'
            tokens = tokens[:2] + tokens[4:]
        else:
            per_class = np.nan
            diagonal_covariance = np.nan
        
    fit_to = re.match('.*\[(.*)\].*', '-'.join(tokens[2:])).groups()[0]
    return {
      'density' : density_type, 'num-components' : num_components,
        'dimensionality-reduction' : dim_red, 'dimensionality' : dim_red_dim,
        'per-class' : per_class, 'diagonal-covariance' : diagonal_covariance,
        'fit-to' : fit_to
    }


df_auroc = df[[metric for metric in df.columns if 'auroc' in metric]].T.reset_index()
N, _ = df_auroc.shape
auroc_dict = df_auroc.to_dict()
by_index = defaultdict(lambda: defaultdict(dict))
for i in range(N):
    index, type_ = auroc_dict['index'][i].split('.')
    for col in auroc_dict.keys():
        by_index[index][type_][col] = auroc_dict[col][i]

new_dict = defaultdict(list)
for hps, m in by_index.items():
    for k in m['std'].keys():
        if k == 'index': continue
        new_dict[k + '.mean'].append(m['mean'][k])
        new_dict[k + '.std'].append(m['std'][k])
    for hp, value in get_hyperparams(hps).items():
        new_dict[hp].append(value)
df_auroc = pd.DataFrame(dict(new_dict))   

df_auroc['auroc_mean'] = df_auroc[[col for col in df_auroc.columns if '.mean' in col]].mean(axis=1)
df_auroc = df_auroc.sort_values(by=['auroc_mean'], ascending=False).drop('auroc_mean', axis=1)

df_auroc = df_auroc.round(2)
for exp in set(col.replace('.mean', '') for col in df_auroc.columns if '.mean' in col):
    df_auroc[exp] = df_auroc[exp + '.mean'].astype(str) + ' ± ' + df_auroc[exp + '.std'].astype(str)
    df_auroc = df_auroc.drop(exp + '.mean', axis=1)
    df_auroc = df_auroc.drop(exp + '.std', axis=1)

# %%
df_auroc
# Out:
#     density  num-components dimensionality-reduction  dimensionality  \
# 230     gpc             NaN                   isomap            32.0
# 190     gpc             NaN                   isomap             8.0
# 268     gpc             NaN                   isomap            10.0
# 107     gpc             NaN                      pca             6.0
# 213     gpc             NaN                   isomap             6.0
# ..      ...             ...                      ...             ...
# 73      gpc             NaN                      pca            10.0
# 156     gpc             NaN                      pca             8.0
# 234     gpc             NaN                      pca             8.0
# 280     gpc             NaN                      pca             6.0
# 173     gpc             NaN                      pca             6.0
#
#     per-class diagonal-covariance                          fit-to  \
# 230     False               False                           train
# 190     False               False                           train
# 268     False               False                           train
# 107     False                True                           train
# 213     False               False                           train
# ..        ...                 ...                             ...
# 73       True                True  train-val-reduced-test-reduced
# 156      True               False  train-val-reduced-test-reduced
# 234      True                True  train-val-reduced-test-reduced
# 280      True               False  train-val-reduced-test-reduced
# 173      True                True  train-val-reduced-test-reduced
#
#     removeOOD:F-residual:F removeOOD:T-residual:F removeOOD:T-residual:T  \
# 230              0.7 ± 0.1            0.73 ± 0.06            0.76 ± 0.09
# 190              0.7 ± 0.1            0.71 ± 0.08            0.76 ± 0.09
# 268            0.71 ± 0.11            0.71 ± 0.08             0.75 ± 0.1
# 107            0.73 ± 0.08            0.66 ± 0.08            0.73 ± 0.09
# 213             0.69 ± 0.1            0.69 ± 0.09            0.76 ± 0.09
# ..                     ...                    ...                    ...
# 73               nan ± nan            0.13 ± 0.05            0.13 ± 0.04
# 156              nan ± nan            0.12 ± 0.05            0.13 ± 0.04
# 234              nan ± nan            0.11 ± 0.04            0.12 ± 0.03
# 280              nan ± nan             0.1 ± 0.04            0.12 ± 0.04
# 173              nan ± nan            0.11 ± 0.04            0.12 ± 0.03
#
#     removeOOD:F-residual:T
# 230            0.73 ± 0.11
# 190            0.72 ± 0.13
# 268            0.72 ± 0.13
# 107            0.75 ± 0.07
# 213            0.73 ± 0.11
# ..                     ...
# 73               nan ± nan
# 156              nan ± nan
# 234              nan ± nan
# 280              nan ± nan
# 173              nan ± nan
#
# [320 rows x 11 columns]

# %%
data = df.to_dict()
data['']
# Out:
# dict_keys(['overwrite', 'db_collection', 'data.dataset', 'data.num_dataset_splits', 'data.split_type', 'data.test_portion', 'data.test_portion_fixed', 'data.train_labels', 'data.train_labels_remove_other', 'data.train_portion', 'data.val_labels', 'data.val_portion', 'evaluation.pipeline', 'model.activation', 'model.freeze_residual_projection', 'model.hidden_sizes', 'model.leaky_relu_slope', 'model.model_type', 'model.num_initializations', 'model.residual', 'model.use_bias', 'model.use_spectral_norm', 'model.weight_scale', 'run.args', 'run.name', 'training.early_stopping.min_delta', 'training.early_stopping.mode', 'training.early_stopping.monitor', 'training.early_stopping.patience', 'training.gpus', 'training.learning_rate', 'training.max_epochs', 'seed', 'auroc_mog6-8isomap-ft[train].std', 'auroc_gpc-16isomap-pcT-dF-f[train-val-reduced-test-reduced].std', 'auroc_gpc-2isomap-pcF-dT-f[train-val-reduced-test-reduced].mean', 'auroc_mog3-32pca-ft[train].std', 'auroc_mog6-32pca-ft[train].std', 'auroc_gpc-16isomap-pcF-dT-f[train-val-reduced-test-reduced].std', 'auroc_gpc-2isomap-pcT-dF-f[train-val-reduced-test-reduced].std', 'auroc_mog2-16pca-ft[train-val-reduced-test-reduced].std', 'auroc_mog3-4isomap-ft[train].mean', 'auroc_mog5-no-ft[train].std', 'auroc_mog6-2pca-ft[train-val-reduced-test-reduced].mean', 'auroc_mog6-32pca-ft[train].mean', 'auroc_mog3-8isomap-ft[train].std', 'auroc_mog7-10isomap-ft[train].std', 'auroc_gpc-6pca-pcT-dT-f[train].mean', 'auroc_gpc-8pca-pcT-dF-f[train].std', 'auroc_gpc-8isomap-pcF-dT-f[train-val-reduced-test-reduced].std', 'auroc_mog10-4pca-ft[train-val-reduced-test-reduced].mean', 'val_loss-val-train-labels.std', 'auroc_mog4-16pca-ft[train-val-reduced-test-reduced].std', 'auroc_mog4-16pca-ft[train].std', 'auroc_gpc-16pca-pcT-dF-f[train-val-reduced-test-reduced].std', 'auroc_mog7-4isomap-ft[train].std', 'auroc_gpc-16pca-pcT-dF-f[train].std', 'auroc_gpc-6isomap-pcT-dT-f[train].std', 'auroc_mog6-16pca-ft[train-val-reduced-test-reduced].mean', 'auroc_mog4-32isomap-ft[train-val-reduced-test-reduced].mean', 'auroc_mog5-16isomap-ft[train].std', 'auroc_mog10-no-ft[train].mean', 'auroc_mog3-10isomap-ft[train].mean', 'auroc_gpc-2isomap-pcF-dT-f[train-val-reduced-test-reduced].std', 'auroc_mog2-10pca-ft[train].mean', 'auroc_mog3-10pca-ft[train].std', 'auroc_gpc-8pca-pcF-dF-f[train].mean', 'auroc_mog3-2pca-ft[train].mean', 'auroc_mog7-4pca-ft[train].std', 'auroc_mog2-32pca-ft[train].mean', 'auroc_mog5-32pca-ft[train].std', 'auroc_mog2-no-ft[train-val-reduced-test-reduced].std', 'auroc_gpc-16pca-pcF-dF-f[train].std', 'auroc_gpc-10isomap-pcT-dT-f[train-val-reduced-test-reduced].std', 'auroc_gpc-16pca-pcT-dF-f[train-val-reduced-test-reduced].mean', 'auroc_mog10-4isomap-ft[train].mean', 'auroc_mog7-no-ft[train].std', 'auroc_gpc-32isomap-pcT-dT-f[train-val-reduced-test-reduced].mean', 'auroc_mog10-10pca-ft[train].std', 'auroc_mog10-4pca-ft[train].std', 'auroc_gpc-no-dT-f[train].std', 'auroc_mog3-6isomap-ft[train].mean', 'auroc_gpc-4pca-pcT-dF-f[train-val-reduced-test-reduced].mean', 'auroc_mog10-8isomap-ft[train].std', 'auroc_mog3-16isomap-ft[train-val-reduced-test-reduced].std', 'auroc_mog4-2isomap-ft[train].std', 'auroc_mog4-16pca-ft[train-val-reduced-test-reduced].mean', 'auroc_mog4-6pca-ft[train].std', 'val_loss-val-reduced.std', 'auroc_mog5-32pca-ft[train-val-reduced-test-reduced].mean', 'auroc_mog3-8isomap-ft[train].mean', 'auroc_mog4-no-ft[train-val-reduced-test-reduced].mean', 'auroc_gpc-8isomap-pcT-dF-f[train-val-reduced-test-reduced].mean', 'auroc_mog5-4pca-ft[train-val-reduced-test-reduced].std', 'auroc_mog2-no-ft[train].std', 'auroc_mog3-8isomap-ft[train-val-reduced-test-reduced].std', 'auroc_gpc-no-dT-f[train-val-reduced-test-reduced].mean', 'auroc_mog10-2pca-ft[train].mean', 'auroc_gpc-4isomap-pcF-dF-f[train].std', 'auroc_gpc-32pca-pcT-dT-f[train-val-reduced-test-reduced].std', 'auroc_mog6-8isomap-ft[train].mean', 'auroc_gpc-8pca-pcF-dF-f[train].std', 'auroc_mog4-2pca-ft[train-val-reduced-test-reduced].m ...

# %%
#mean_auroc = 
# df_auroc = df_auroc.round(2).sort_values(by=[col for col in df_auroc.columns if '.mean' in col], key=lambda row: row.mean(), ascending=False)

# %%
pd.set_option('display.max_rows', None)
df_auroc
# Out:
#     density  num-components dimensionality-reduction  dimensionality  \
# 230     gpc             NaN                   isomap            32.0
# 190     gpc             NaN                   isomap             8.0
# 268     gpc             NaN                   isomap            10.0
# 107     gpc             NaN                      pca             6.0
# 213     gpc             NaN                   isomap             6.0
# 111     gpc             NaN                   isomap            16.0
# 138     gpc             NaN                   isomap            32.0
# 0       mog             6.0                   isomap             8.0
# 68      mog             2.0                   isomap            32.0
# 145     mog             7.0                   isomap             8.0
# 291     mog             5.0                   isomap            10.0
# 233     mog             5.0                   isomap             6.0
# 249     mog             5.0                   isomap             8.0
# 307     mog            10.0                   isomap             6.0
# 297     mog             7.0                   isomap             6.0
# 43      gpc             NaN                     None             NaN
# 160     mog             3.0                   isomap            32.0
# 155     mog             6.0                   isomap             6.0
# 208     mog             6.0                   isomap            10.0
# 309     mog            10.0                   isomap            32.0
# 46      mog            10.0                   isomap             8.0
# 266     mog             6.0                   isomap            16.0
# 12      mog             7.0                   isomap            10.0
# 253     mog             7.0                   isomap            32.0
# 186     mog             7.0                   isomap            16.0
# 220     mog             5.0                   isomap            32.0
# 260     mog             4.0                   isomap             6.0
# 146     mog             4.0                   isomap            16.0
# 98      gpc             NaN                   isomap            16.0
# 181     mog            10.0                   isomap            16.0
# 289     mog             4.0                   isomap             8.0
# 38      mog            10.0                   isomap             4.0
# 303     mog             6.0                   isomap            32.0
# 25      mog             5.0                   isomap            16.0
# 241     mog            10.0                     None             NaN
# 203     mog             4.0                   isomap            32.0
# 103     mog            10.0                   isomap            10.0
# 312     mog             4.0                   isomap            10.0
# 292     mog             3.0                   isomap            16.0
# 58      gpc             NaN                   isomap             4.0
# 20      mog             7.0                   isomap             4.0
# 248     mog             6.0                   isomap             4.0
# 178     gpc             NaN                      pca             4.0
# 179     gpc             NaN                      pca             4.0
# 187     mog            10.0                   isomap            32.0
# 278     gpc             NaN                   isomap             6.0
# 236     gpc             NaN                   isomap            10.0
# 192     gpc             NaN                   isomap             8.0
# 27      mog             3.0                   isomap            10.0
# 100     mog             5.0                   isomap             4.0
# 11      mog             3.0                   isomap             8.0
# 150     mog             4.0                   isomap             4.0
# 157     mog             2.0                   isomap            16.0
# 44      mog             3.0                   isomap             6.0
# 198     gpc             NaN                   isomap             4.0
# 139     gpc             NaN                      pca             6.0
# 184     gpc             NaN                      pca             6.0
# 13      gpc             NaN                      pca             6.0
# 99      mog            10.0                      pca            32.0
# 110     gpc             NaN                      pca             8.0
# 164     mog             7.0                     None             NaN
# 79      mog            10.0                   isomap             2.0
# 304     mog             5.0                      pca             6.0
# 8       mog             3.0                   isomap             4.0
# 232     gpc             NaN                      pca             4.0
# 191     gpc             NaN                     None             NaN
# 270     mog             7.0                   isomap             2.0
# 264     mog             7.0                      pca             6.0
# 158     gpc             NaN                      pca             2.0
# 247     gpc             NaN                      pca             2.0
# 62      mog             6.0                      pca             6.0
# 209     gpc             NaN                      pca            32.0
# 49      mog             4.0                      pca             6.0
# 261     mog             7.0                   isomap            32.0
# 154     mog             6.0                   isomap             2.0
# 254     mog             2.0                   isomap            10.0
# 305     mog             6.0                     None             NaN
# 106     gpc             NaN                      pca             4.0
# 256     gpc             NaN                   isomap             2.0
# 238     mog             5.0                   isomap             2.0
# 163     mog             2.0                   isomap             8.0
# 112     mog            10.0                      pca             6.0
# 42      mog            10.0                      pca             4.0
# 275     gpc             NaN                      pca            10.0
# 240     gpc             NaN                      pca            10.0
# 237     mog            10.0                   isomap            16.0
# 257     mog             7.0                      pca            32.0
# 276     mog             6.0                   isomap            32.0
# 21      gpc             NaN                      pca            16.0
# 263     gpc             NaN                      pca            16.0
# 32      mog             7.0                      pca             4.0
# 295     gpc             NaN                      pca             8.0
# 14      gpc             NaN                      pca             8.0
# 48      mog             4.0                   isomap             2.0
# 129     mog             6.0                      pca             4.0
# 196     mog             3.0                      pca             6.0
# 199     mog             5.0                      pca             4.0
# 118     mog             2.0                   isomap             6.0
# 65      gpc             NaN                   isomap             2.0
# 113     mog             5.0                     None             NaN
# 134     mog             6.0                      pca            32.0
# 30      gpc             NaN                      pca             8.0
# 207     gpc             NaN                      pca            10.0
# 143     gpc             NaN                      pca            10.0
# 210     mog             4.0                      pca             4.0
# 222     mog             3.0                   isomap             2.0
# 308     mog             5.0                   isomap            32.0
# 87      mog            10.0                   isomap             6.0
# 212     mog            10.0                      pca            16.0
# 102     mog            10.0                   isomap             8.0
# 51      mog             4.0                     None             NaN
# 314     mog             5.0                      pca             8.0
# 298     mog            10.0                   isomap            10.0
# 183     mog             4.0                      pca             8.0
# 288     mog             6.0                      pca             8.0
# 50      mog             5.0                      pca            32.0
# 316     mog             7.0                   isomap            16.0
# 200     mog            10.0                   isomap             4.0
# 24      mog             4.0                   isomap            32.0
# 170     gpc             NaN                      pca            16.0
# 39      mog             7.0                     None             NaN
# 133     mog             2.0                   isomap             4.0
# 36      gpc             NaN                      pca            16.0
# 152     mog             7.0                   isomap             6.0
# 66      mog             7.0                      pca             8.0
# 177     mog             4.0                      pca            32.0
# 147     mog             3.0                     None             NaN
# 75      gpc             NaN                   isomap             2.0
# 281     gpc             NaN                   isomap             2.0
# 244     mog             7.0                      pca            10.0
# 167     mog             3.0                      pca             8.0
# 205     mog             3.0                      pca             4.0
# 26      mog            10.0                     None             NaN
# 171     mog            10.0                      pca            10.0
# 101     mog             7.0                      pca            16.0
# 204     mog            10.0                      pca             8.0
# 180     gpc             NaN                   isomap             4.0
# 315     gpc             NaN                   isomap             4.0
# 317     mog             7.0                   isomap            10.0
# 22      gpc             NaN                   isomap             6.0
# 283     gpc             NaN                   isomap             6.0
# 96      mog             6.0                   isomap            16.0
# 219     mog             5.0                      pca            10.0
# 119     mog             6.0                      pca            10.0
# 258     mog            10.0                      pca            32.0
# 151     mog             6.0                     None             NaN
# 78      gpc             NaN                      pca            32.0
# 299     mog             7.0                      pca            32.0
# 9       mog             5.0                     None             NaN
# 201     mog             7.0                   isomap             8.0
# 117     mog             6.0                   isomap             6.0
# 23      mog             6.0                      pca            16.0
# 274     mog             3.0                     None             NaN
# 128     mog             7.0                   isomap             4.0
# 246     mog             2.0                   isomap             2.0
# 92      mog            10.0                      pca             8.0
# 105     mog             4.0                     None             NaN
# 41      mog            10.0                      pca            10.0
# 67      mog             5.0                   isomap            16.0
# 4       mog             6.0                      pca            32.0
# 85      gpc             NaN                     None             NaN
# 94      mog             7.0                      pca            16.0
# 242     mog             3.0                      pca            32.0
# 290     gpc             NaN                   isomap             8.0
# 141     gpc             NaN                   isomap             8.0
# 148     mog             4.0                      pca            10.0
# 90      mog            10.0                      pca            16.0
# 57      mog            10.0                      pca             2.0
# 228     mog            10.0                      pca             6.0
# 215     mog             7.0                      pca             2.0
# 311     mog             6.0                   isomap            10.0
# 226     mog             5.0                      pca            16.0
# 35      mog             2.0                     None             NaN
# 217     mog             6.0                      pca            16.0
# 76      mog             7.0                      pca            10.0
# 54      mog             2.0                     None             NaN
# 120     mog             6.0                      pca             2.0
# 64      mog             5.0                      pca             2.0
# 224     mog             6.0                   isomap             4.0
# 29      mog             3.0                      pca            10.0
# 70      mog             6.0                   isomap             8.0
# 126     mog             4.0                      pca            32.0
# 251     mog             5.0                   isomap             6.0
# 172     mog             3.0                   isomap            32.0
# 34      mog             5.0                      pca            32.0
# 114     mog             5.0                      pca            16.0
# 18      mog             4.0                      pca            16.0
# 267     mog             4.0                      pca             2.0
# 218     gpc             NaN                      pca             2.0
# 3       mog             3.0                      pca            32.0
# 287     mog             4.0                   isomap            16.0
# 31      mog             3.0                      pca             2.0
# 195     mog             7.0                      pca             8.0
# 16      mog            10.0                      pca             4.0
# 202     mog             5.0                   isomap            10.0
# 83      gpc             NaN                   isomap            10.0
# 271     gpc             NaN                   isomap            10.0
# 136     mog             6.0                      pca            10.0
# 149     mog             7.0                      pca             6.0
# 221     gpc             NaN                      pca             2.0
# 131     mog             3.0                      pca            16.0
# 82      mog             5.0                   isomap             8.0
# 194     mog             5.0                   isomap             4.0
# 301     mog             2.0                      pca             6.0
# 313     mog             2.0                      pca            32.0
# 130     mog             6.0                      pca             8.0
# 231     mog             6.0                      pca             6.0
# 33      mog             2.0                      pca            32.0
# 235     mog             5.0                      pca             6.0
# 17      mog             4.0                      pca            16.0
# 277     mog             7.0                      pca             4.0
# 144     mog             4.0                   isomap             6.0
# 225     mog             5.0                      pca            10.0
# 168     mog             4.0                   isomap             8.0
# 161     mog             6.0                      pca             4.0
# 185     mog             4.0                   isomap            10.0
# 86      mog             5.0                      pca             8.0
# 91      gpc             NaN                      pca            32.0
# 239     mog             4.0                   isomap             4.0
# 216     mog            10.0                      pca             2.0
# 77      mog             2.0                      pca             2.0
# 47      mog             3.0                   isomap            16.0
# 227     mog             7.0                      pca             2.0
# 243     mog            10.0                   isomap             2.0
# 135     mog             2.0                      pca             4.0
# 10      mog             6.0                      pca             2.0
# 53      mog             5.0                      pca             4.0
# 310     mog             7.0                   isomap             2.0
# 262     mog             4.0                      pca             6.0
# 71      gpc             NaN                      pca            32.0
# 165     mog             3.0                      pca            16.0
# 265     mog             4.0                      pca            10.0
# 142     mog             5.0                      pca             2.0
# 223     mog             2.0                   isomap            32.0
# 214     mog             4.0                      pca             8.0
# 60      mog             4.0                      pca             2.0
# 197     mog             6.0                   isomap             2.0
# 306     gpc             NaN                      pca            32.0
# 89      mog             2.0                      pca            16.0
# 182     mog             2.0                      pca             8.0
# 97      mog             5.0                   isomap             2.0
# 255     mog             4.0                      pca             4.0
# 166     mog             3.0                      pca             2.0
# 229     mog             3.0                   isomap             6.0
# 84      mog             3.0                   isomap            10.0
# 132     mog             4.0                   isomap             2.0
# 55      mog             3.0                   isomap             8.0
# 162     mog             3.0                   isomap             4.0
# 28      mog             2.0                      pca            10.0
# 293     mog             3.0                      pca            10.0
# 206     mog             3.0                   isomap             2.0
# 7       mog             2.0                      pca            16.0
# 125     mog             2.0                      pca             2.0
# 81      mog             3.0                      pca             4.0
# 259     mog             3.0                      pca             8.0
# 108     gpc             NaN                   isomap            32.0
# 296     mog             2.0                   isomap            16.0
# 74      mog             3.0                      pca             6.0
# 59      gpc             NaN                      pca            32.0
# 279     mog             2.0                   isomap             2.0
# 109     mog             2.0                      pca            10.0
# 116     mog             2.0                   isomap             4.0
# 159     mog             2.0                   isomap             6.0
# 286     gpc             NaN                   isomap            32.0
# 88      mog             2.0                      pca             4.0
# 123     mog             2.0                      pca             6.0
# 93      mog             2.0                      pca             8.0
# 115     mog             2.0                   isomap             8.0
# 122     mog             2.0                   isomap            10.0
# 95      gpc             NaN                      pca             2.0
# 124     gpc             NaN                      pca             2.0
# 285     gpc             NaN                      pca             2.0
# 189     gpc             NaN                      pca             2.0
# 269     gpc             NaN                      pca            16.0
# 2       gpc             NaN                   isomap             2.0
# 250     gpc             NaN                      pca            16.0
# 176     gpc             NaN                   isomap             2.0
# 174     gpc             NaN                   isomap            32.0
# 193     gpc             NaN                   isomap            16.0
# 40      gpc             NaN                   isomap            32.0
# 5       gpc             NaN                   isomap            16.0
# 6       gpc             NaN                   isomap             2.0
# 282     gpc             NaN                   isomap             2.0
# 19      gpc             NaN                      pca            16.0
# 1       gpc             NaN                   isomap            16.0
# 300     gpc             NaN                   isomap            10.0
# 175     gpc             NaN                   isomap            10.0
# 15      gpc             NaN                   isomap             8.0
# 104     gpc             NaN                   isomap            10.0
# 137     gpc             NaN                   isomap             8.0
# 80      gpc             NaN                      pca            10.0
# 63      gpc             NaN                   isomap            16.0
# 52      gpc             NaN                   isomap             8.0
# 61      gpc             NaN                   isomap             4.0
# 153     gpc             NaN                      pca            10.0
# 188     gpc             NaN                   isomap             4.0
# 302     gpc             NaN                   isomap             4.0
# 319     gpc             NaN                   isomap             6.0
# 56      gpc             NaN                     None             NaN
# 245     gpc             NaN                   isomap             4.0
# 127     gpc             NaN                   isomap             6.0
# 121     gpc             NaN                   isomap             6.0
# 37      gpc             NaN                   isomap            10.0
# 72      gpc             NaN                   isomap             6.0
# 272     gpc             NaN                   isomap             8.0
# 284     gpc             NaN                      pca            16.0
# 318     gpc             NaN                      pca             4.0
# 294     gpc             NaN                      pca             4.0
# 140     gpc             NaN                      pca             8.0
# 169     gpc             NaN                      pca            10.0
# 273     gpc             NaN                      pca             8.0
# 211     gpc             NaN                      pca             4.0
# 45      gpc             NaN                      pca             4.0
# 252     gpc             NaN                      pca             6.0
# 69      gpc             NaN                      pca             6.0
# 73      gpc             NaN                      pca            10.0
# 156     gpc             NaN                      pca             8.0
# 234     gpc             NaN                      pca             8.0
# 280     gpc             NaN                      pca             6.0
# 173     gpc             NaN                      pca             6.0
#
#     per-class diagonal-covariance                          fit-to  \
# 230     False               False                           train
# 190     False               False                           train
# 268     False               False                           train
# 107     False                True                           train
# 213     False               False                           train
# 111     False               False                           train
# 138     False                True                           train
# 0         NaN                 NaN                           train
# 68        NaN                 NaN                           train
# 145       NaN                 NaN                           train
# 291       NaN                 NaN                           train
# 233       NaN                 NaN                           train
# 249       NaN                 NaN                           train
# 307       NaN                 NaN                           train
# 297       NaN                 NaN                           train
# 43        NaN                 NaN                           train
# 160       NaN                 NaN                           train
# 155       NaN                 NaN                           train
# 208       NaN                 NaN                           train
# 309       NaN                 NaN                           train
# 46        NaN                 NaN                           train
# 266       NaN                 NaN                           train
# 12        NaN                 NaN                           train
# 253       NaN                 NaN                           train
# 186       NaN                 NaN                           train
# 220       NaN                 NaN                           train
# 260       NaN                 NaN                           train
# 146       NaN                 NaN                           train
# 98      False                True                           train
# 181       NaN                 NaN                           train
# 289       NaN                 NaN                           train
# 38        NaN                 NaN                           train
# 303       NaN                 NaN                           train
# 25        NaN                 NaN                           train
# 241       NaN                 NaN  train-val-reduced-test-reduced
# 203       NaN                 NaN                           train
# 103       NaN                 NaN                           train
# 312       NaN                 NaN                           train
# 292       NaN                 NaN                           train
# 58      False               False                           train
# 20        NaN                 NaN                           train
# 248       NaN                 NaN                           train
# 178      True               False                           train
# 179      True                True                           train
# 187       NaN                 NaN  train-val-reduced-test-reduced
# 278     False                True                           train
# 236     False                True                           train
# 192     False                True                           train
# 27        NaN                 NaN                           train
# 100       NaN                 NaN                           train
# 11        NaN                 NaN                           train
# 150       NaN                 NaN                           train
# 157       NaN                 NaN                           train
# 44        NaN                 NaN                           train
# 198     False                True                           train
# 139     False               False                           train
# 184      True               False                           train
# 13       True                True                           train
# 99        NaN                 NaN  train-val-reduced-test-reduced
# 110     False                True                           train
# 164       NaN                 NaN  train-val-reduced-test-reduced
# 79        NaN                 NaN                           train
# 304       NaN                 NaN                           train
# 8         NaN                 NaN                           train
# 232     False               False                           train
# 191       NaN                 NaN                           train
# 270       NaN                 NaN                           train
# 264       NaN                 NaN                           train
# 158      True                True                           train
# 247      True               False                           train
# 62        NaN                 NaN                           train
# 209     False               False                           train
# 49        NaN                 NaN                           train
# 261       NaN                 NaN  train-val-reduced-test-reduced
# 154       NaN                 NaN                           train
# 254       NaN                 NaN                           train
# 305       NaN                 NaN  train-val-reduced-test-reduced
# 106     False                True                           train
# 256     False               False                           train
# 238       NaN                 NaN                           train
# 163       NaN                 NaN                           train
# 112       NaN                 NaN                           train
# 42        NaN                 NaN                           train
# 275      True                True                           train
# 240      True               False                           train
# 237       NaN                 NaN  train-val-reduced-test-reduced
# 257       NaN                 NaN  train-val-reduced-test-reduced
# 276       NaN                 NaN  train-val-reduced-test-reduced
# 21       True               False                           train
# 263      True                True                           train
# 32        NaN                 NaN                           train
# 295      True                True                           train
# 14       True               False                           train
# 48        NaN                 NaN                           train
# 129       NaN                 NaN                           train
# 196       NaN                 NaN                           train
# 199       NaN                 NaN                           train
# 118       NaN                 NaN                           train
# 65      False                True                           train
# 113       NaN                 NaN  train-val-reduced-test-reduced
# 134       NaN                 NaN  train-val-reduced-test-reduced
# 30      False               False                           train
# 207     False               False                           train
# 143     False                True                           train
# 210       NaN                 NaN                           train
# 222       NaN                 NaN                           train
# 308       NaN                 NaN  train-val-reduced-test-reduced
# 87        NaN                 NaN  train-val-reduced-test-reduced
# 212       NaN                 NaN  train-val-reduced-test-reduced
# 102       NaN                 NaN  train-val-reduced-test-reduced
# 51        NaN                 NaN  train-val-reduced-test-reduced
# 314       NaN                 NaN                           train
# 298       NaN                 NaN  train-val-reduced-test-reduced
# 183       NaN                 NaN                           train
# 288       NaN                 NaN                           train
# 50        NaN                 NaN  train-val-reduced-test-reduced
# 316       NaN                 NaN  train-val-reduced-test-reduced
# 200       NaN                 NaN  train-val-reduced-test-reduced
# 24        NaN                 NaN  train-val-reduced-test-reduced
# 170     False                True                           train
# 39        NaN                 NaN                           train
# 133       NaN                 NaN                           train
# 36      False               False                           train
# 152       NaN                 NaN  train-val-reduced-test-reduced
# 66        NaN                 NaN                           train
# 177       NaN                 NaN  train-val-reduced-test-reduced
# 147       NaN                 NaN  train-val-reduced-test-reduced
# 75       True                True                           train
# 281      True               False                           train
# 244       NaN                 NaN                           train
# 167       NaN                 NaN                           train
# 205       NaN                 NaN                           train
# 26        NaN                 NaN                           train
# 171       NaN                 NaN  train-val-reduced-test-reduced
# 101       NaN                 NaN  train-val-reduced-test-reduced
# 204       NaN                 NaN                           train
# 180      True                True                           train
# 315      True               False                           train
# 317       NaN                 NaN  train-val-reduced-test-reduced
# 22       True                True                           train
# 283      True               False                           train
# 96        NaN                 NaN  train-val-reduced-test-reduced
# 219       NaN                 NaN                           train
# 119       NaN                 NaN                           train
# 258       NaN                 NaN                           train
# 151       NaN                 NaN                           train
# 78      False                True                           train
# 299       NaN                 NaN                           train
# 9         NaN                 NaN                           train
# 201       NaN                 NaN  train-val-reduced-test-reduced
# 117       NaN                 NaN  train-val-reduced-test-reduced
# 23        NaN                 NaN  train-val-reduced-test-reduced
# 274       NaN                 NaN                           train
# 128       NaN                 NaN  train-val-reduced-test-reduced
# 246       NaN                 NaN                           train
# 92        NaN                 NaN  train-val-reduced-test-reduced
# 105       NaN                 NaN                           train
# 41        NaN                 NaN                           train
# 67        NaN                 NaN  train-val-reduced-test-reduced
# 4         NaN                 NaN                           train
# 85        NaN                 NaN  train-val-reduced-test-reduced
# 94        NaN                 NaN                           train
# 242       NaN                 NaN  train-val-reduced-test-reduced
# 290      True                True                           train
# 141      True               False                           train
# 148       NaN                 NaN                           train
# 90        NaN                 NaN                           train
# 57        NaN                 NaN                           train
# 228       NaN                 NaN  train-val-reduced-test-reduced
# 215       NaN                 NaN                           train
# 311       NaN                 NaN  train-val-reduced-test-reduced
# 226       NaN                 NaN                           train
# 35        NaN                 NaN  train-val-reduced-test-reduced
# 217       NaN                 NaN                           train
# 76        NaN                 NaN  train-val-reduced-test-reduced
# 54        NaN                 NaN                           train
# 120       NaN                 NaN                           train
# 64        NaN                 NaN                           train
# 224       NaN                 NaN  train-val-reduced-test-reduced
# 29        NaN                 NaN                           train
# 70        NaN                 NaN  train-val-reduced-test-reduced
# 126       NaN                 NaN                           train
# 251       NaN                 NaN  train-val-reduced-test-reduced
# 172       NaN                 NaN  train-val-reduced-test-reduced
# 34        NaN                 NaN                           train
# 114       NaN                 NaN  train-val-reduced-test-reduced
# 18        NaN                 NaN                           train
# 267       NaN                 NaN                           train
# 218     False               False                           train
# 3         NaN                 NaN                           train
# 287       NaN                 NaN  train-val-reduced-test-reduced
# 31        NaN                 NaN                           train
# 195       NaN                 NaN  train-val-reduced-test-reduced
# 16        NaN                 NaN  train-val-reduced-test-reduced
# 202       NaN                 NaN  train-val-reduced-test-reduced
# 83       True                True                           train
# 271      True               False                           train
# 136       NaN                 NaN  train-val-reduced-test-reduced
# 149       NaN                 NaN  train-val-reduced-test-reduced
# 221     False                True                           train
# 131       NaN                 NaN                           train
# 82        NaN                 NaN  train-val-reduced-test-reduced
# 194       NaN                 NaN  train-val-reduced-test-reduced
# 301       NaN                 NaN                           train
# 313       NaN                 NaN  train-val-reduced-test-reduced
# 130       NaN                 NaN  train-val-reduced-test-reduced
# 231       NaN                 NaN  train-val-reduced-test-reduced
# 33        NaN                 NaN                           train
# 235       NaN                 NaN  train-val-reduced-test-reduced
# 17        NaN                 NaN  train-val-reduced-test-reduced
# 277       NaN                 NaN  train-val-reduced-test-reduced
# 144       NaN                 NaN  train-val-reduced-test-reduced
# 225       NaN                 NaN  train-val-reduced-test-reduced
# 168       NaN                 NaN  train-val-reduced-test-reduced
# 161       NaN                 NaN  train-val-reduced-test-reduced
# 185       NaN                 NaN  train-val-reduced-test-reduced
# 86        NaN                 NaN  train-val-reduced-test-reduced
# 91      False               False  train-val-reduced-test-reduced
# 239       NaN                 NaN  train-val-reduced-test-reduced
# 216       NaN                 NaN  train-val-reduced-test-reduced
# 77        NaN                 NaN                           train
# 47        NaN                 NaN  train-val-reduced-test-reduced
# 227       NaN                 NaN  train-val-reduced-test-reduced
# 243       NaN                 NaN  train-val-reduced-test-reduced
# 135       NaN                 NaN                           train
# 10        NaN                 NaN  train-val-reduced-test-reduced
# 53        NaN                 NaN  train-val-reduced-test-reduced
# 310       NaN                 NaN  train-val-reduced-test-reduced
# 262       NaN                 NaN  train-val-reduced-test-reduced
# 71      False                True  train-val-reduced-test-reduced
# 165       NaN                 NaN  train-val-reduced-test-reduced
# 265       NaN                 NaN  train-val-reduced-test-reduced
# 142       NaN                 NaN  train-val-reduced-test-reduced
# 223       NaN                 NaN  train-val-reduced-test-reduced
# 214       NaN                 NaN  train-val-reduced-test-reduced
# 60        NaN                 NaN  train-val-reduced-test-reduced
# 197       NaN                 NaN  train-val-reduced-test-reduced
# 306      True               False  train-val-reduced-test-reduced
# 89        NaN                 NaN                           train
# 182       NaN                 NaN                           train
# 97        NaN                 NaN  train-val-reduced-test-reduced
# 255       NaN                 NaN  train-val-reduced-test-reduced
# 166       NaN                 NaN  train-val-reduced-test-reduced
# 229       NaN                 NaN  train-val-reduced-test-reduced
# 84        NaN                 NaN  train-val-reduced-test-reduced
# 132       NaN                 NaN  train-val-reduced-test-reduced
# 55        NaN                 NaN  train-val-reduced-test-reduced
# 162       NaN                 NaN  train-val-reduced-test-reduced
# 28        NaN                 NaN                           train
# 293       NaN                 NaN  train-val-reduced-test-reduced
# 206       NaN                 NaN  train-val-reduced-test-reduced
# 7         NaN                 NaN  train-val-reduced-test-reduced
# 125       NaN                 NaN  train-val-reduced-test-reduced
# 81        NaN                 NaN  train-val-reduced-test-reduced
# 259       NaN                 NaN  train-val-reduced-test-reduced
# 108     False               False  train-val-reduced-test-reduced
# 296       NaN                 NaN  train-val-reduced-test-reduced
# 74        NaN                 NaN  train-val-reduced-test-reduced
# 59       True                True  train-val-reduced-test-reduced
# 279       NaN                 NaN  train-val-reduced-test-reduced
# 109       NaN                 NaN  train-val-reduced-test-reduced
# 116       NaN                 NaN  train-val-reduced-test-reduced
# 159       NaN                 NaN  train-val-reduced-test-reduced
# 286     False                True  train-val-reduced-test-reduced
# 88        NaN                 NaN  train-val-reduced-test-reduced
# 123       NaN                 NaN  train-val-reduced-test-reduced
# 93        NaN                 NaN  train-val-reduced-test-reduced
# 115       NaN                 NaN  train-val-reduced-test-reduced
# 122       NaN                 NaN  train-val-reduced-test-reduced
# 95      False                True  train-val-reduced-test-reduced
# 124     False               False  train-val-reduced-test-reduced
# 285      True               False  train-val-reduced-test-reduced
# 189      True                True  train-val-reduced-test-reduced
# 269     False               False  train-val-reduced-test-reduced
# 2       False                True  train-val-reduced-test-reduced
# 250     False                True  train-val-reduced-test-reduced
# 176     False               False  train-val-reduced-test-reduced
# 174      True               False  train-val-reduced-test-reduced
# 193     False               False  train-val-reduced-test-reduced
# 40       True                True  train-val-reduced-test-reduced
# 5       False                True  train-val-reduced-test-reduced
# 6        True               False  train-val-reduced-test-reduced
# 282      True                True  train-val-reduced-test-reduced
# 19       True               False  train-val-reduced-test-reduced
# 1        True               False  train-val-reduced-test-reduced
# 300     False                True  train-val-reduced-test-reduced
# 175     False               False  train-val-reduced-test-reduced
# 15      False                True  train-val-reduced-test-reduced
# 104      True               False  train-val-reduced-test-reduced
# 137     False               False  train-val-reduced-test-reduced
# 80      False               False  train-val-reduced-test-reduced
# 63       True                True  train-val-reduced-test-reduced
# 52       True               False  train-val-reduced-test-reduced
# 61      False                True  train-val-reduced-test-reduced
# 153     False                True  train-val-reduced-test-reduced
# 188      True               False  train-val-reduced-test-reduced
# 302     False               False  train-val-reduced-test-reduced
# 319      True               False  train-val-reduced-test-reduced
# 56        NaN                 NaN  train-val-reduced-test-reduced
# 245      True                True  train-val-reduced-test-reduced
# 127     False                True  train-val-reduced-test-reduced
# 121     False               False  train-val-reduced-test-reduced
# 37       True                True  train-val-reduced-test-reduced
# 72       True                True  train-val-reduced-test-reduced
# 272      True                True  train-val-reduced-test-reduced
# 284      True                True  train-val-reduced-test-reduced
# 318     False                True  train-val-reduced-test-reduced
# 294     False               False  train-val-reduced-test-reduced
# 140     False               False  train-val-reduced-test-reduced
# 169      True               False  train-val-reduced-test-reduced
# 273     False                True  train-val-reduced-test-reduced
# 211      True                True  train-val-reduced-test-reduced
# 45       True               False  train-val-reduced-test-reduced
# 252     False               False  train-val-reduced-test-reduced
# 69      False                True  train-val-reduced-test-reduced
# 73       True                True  train-val-reduced-test-reduced
# 156      True               False  train-val-reduced-test-reduced
# 234      True                True  train-val-reduced-test-reduced
# 280      True               False  train-val-reduced-test-reduced
# 173      True                True  train-val-reduced-test-reduced
#
#     removeOOD:F-residual:F removeOOD:T-residual:F removeOOD:T-residual:T  \
# 230              0.7 ± 0.1            0.73 ± 0.06            0.76 ± 0.09
# 190              0.7 ± 0.1            0.71 ± 0.08            0.76 ± 0.09
# 268            0.71 ± 0.11            0.71 ± 0.08             0.75 ± 0.1
# 107            0.73 ± 0.08            0.66 ± 0.08            0.73 ± 0.09
# 213             0.69 ± 0.1            0.69 ± 0.09            0.76 ± 0.09
# 111             0.7 ± 0.09             0.69 ± 0.1            0.76 ± 0.08
# 138            0.67 ± 0.11            0.68 ± 0.07            0.75 ± 0.08
# 0              0.63 ± 0.14            0.69 ± 0.09            0.76 ± 0.09
# 68             0.66 ± 0.14             0.68 ± 0.1            0.74 ± 0.09
# 145            0.64 ± 0.13            0.68 ± 0.08            0.75 ± 0.09
# 291            0.63 ± 0.14            0.68 ± 0.09            0.76 ± 0.08
# 233            0.65 ± 0.14            0.68 ± 0.09            0.75 ± 0.07
# 249            0.63 ± 0.14            0.69 ± 0.09            0.75 ± 0.09
# 307            0.66 ± 0.11            0.67 ± 0.09            0.73 ± 0.09
# 297            0.65 ± 0.14            0.67 ± 0.08            0.75 ± 0.09
# 43             0.58 ± 0.09            0.67 ± 0.14            0.76 ± 0.11
# 160            0.65 ± 0.12             0.66 ± 0.1             0.74 ± 0.1
# 155            0.64 ± 0.14            0.67 ± 0.08            0.74 ± 0.09
# 208            0.62 ± 0.13            0.67 ± 0.12            0.75 ± 0.09
# 309            0.62 ± 0.13            0.67 ± 0.08            0.75 ± 0.09
# 46             0.64 ± 0.11            0.67 ± 0.08             0.75 ± 0.1
# 266            0.62 ± 0.12            0.64 ± 0.12            0.76 ± 0.08
# 12             0.63 ± 0.15             0.65 ± 0.1            0.75 ± 0.09
# 253            0.62 ± 0.12             0.65 ± 0.1            0.75 ± 0.09
# 186            0.62 ± 0.13            0.65 ± 0.12            0.76 ± 0.08
# 220            0.63 ± 0.12             0.64 ± 0.1            0.76 ± 0.09
# 260            0.63 ± 0.16            0.67 ± 0.09            0.74 ± 0.08
# 146            0.63 ± 0.14            0.65 ± 0.09            0.74 ± 0.09
# 98             0.64 ± 0.13            0.63 ± 0.09            0.76 ± 0.09
# 181            0.61 ± 0.13            0.66 ± 0.11            0.75 ± 0.09
# 289            0.62 ± 0.15             0.66 ± 0.1             0.74 ± 0.1
# 38             0.65 ± 0.12            0.65 ± 0.09            0.73 ± 0.09
# 303            0.61 ± 0.14             0.65 ± 0.1            0.75 ± 0.08
# 25             0.62 ± 0.13            0.63 ± 0.11            0.76 ± 0.08
# 241             0.8 ± 0.06            0.86 ± 0.03            0.52 ± 0.08
# ...
# 142            0.41 ± 0.08             0.4 ± 0.07            0.38 ± 0.09
# 223            0.37 ± 0.05            0.48 ± 0.11            0.42 ± 0.07
# 214            0.44 ± 0.08            0.42 ± 0.08            0.33 ± 0.08
# 60              0.4 ± 0.09             0.4 ± 0.07            0.38 ± 0.09
# 197             0.42 ± 0.1             0.39 ± 0.1            0.37 ± 0.07
# 306              nan ± nan            0.48 ± 0.06            0.31 ± 0.08
# 89             0.42 ± 0.11            0.45 ± 0.11             0.3 ± 0.12
# 182            0.32 ± 0.14            0.45 ± 0.13             0.4 ± 0.12
# 97              0.41 ± 0.1             0.38 ± 0.1            0.36 ± 0.07
# 255             0.45 ± 0.1             0.39 ± 0.1            0.34 ± 0.09
# 166            0.39 ± 0.09            0.39 ± 0.07            0.37 ± 0.09
# 229            0.36 ± 0.08             0.4 ± 0.09            0.39 ± 0.06
# 84             0.33 ± 0.07            0.46 ± 0.08             0.4 ± 0.07
# 132            0.39 ± 0.08             0.35 ± 0.1            0.35 ± 0.06
# 55             0.33 ± 0.07            0.43 ± 0.15            0.38 ± 0.07
# 162            0.38 ± 0.11            0.36 ± 0.11            0.34 ± 0.07
# 28             0.35 ± 0.13            0.42 ± 0.14            0.31 ± 0.12
# 293            0.38 ± 0.09            0.42 ± 0.09             0.3 ± 0.08
# 206            0.39 ± 0.09             0.33 ± 0.1            0.34 ± 0.06
# 7              0.44 ± 0.12            0.41 ± 0.09            0.29 ± 0.07
# 125            0.36 ± 0.07            0.37 ± 0.06            0.34 ± 0.09
# 81              0.4 ± 0.12            0.36 ± 0.11             0.32 ± 0.1
# 259            0.35 ± 0.09            0.37 ± 0.09             0.3 ± 0.09
# 108            0.35 ± 0.05            0.39 ± 0.09            0.35 ± 0.08
# 296            0.33 ± 0.06              0.4 ± 0.1            0.37 ± 0.07
# 74             0.37 ± 0.09            0.36 ± 0.11              0.3 ± 0.1
# 59               nan ± nan             0.4 ± 0.07            0.27 ± 0.07
# 279            0.37 ± 0.09            0.27 ± 0.09            0.32 ± 0.08
# 109            0.36 ± 0.12             0.35 ± 0.1            0.27 ± 0.07
# 116            0.35 ± 0.11             0.3 ± 0.11            0.27 ± 0.05
# 159            0.28 ± 0.09            0.32 ± 0.08            0.33 ± 0.06
# 286            0.34 ± 0.05            0.34 ± 0.08            0.31 ± 0.07
# 88             0.35 ± 0.12             0.33 ± 0.1            0.28 ± 0.08
# 123            0.38 ± 0.05            0.33 ± 0.09            0.27 ± 0.07
# 93             0.35 ± 0.11             0.32 ± 0.1            0.26 ± 0.07
# 115            0.28 ± 0.07             0.36 ± 0.1            0.33 ± 0.06
# 122            0.29 ± 0.05            0.35 ± 0.08            0.33 ± 0.05
# 95             0.31 ± 0.08            0.33 ± 0.09            0.27 ± 0.08
# 124            0.31 ± 0.08            0.32 ± 0.09            0.27 ± 0.08
# 285              nan ± nan             0.3 ± 0.08             0.3 ± 0.09
# 189              nan ± nan            0.31 ± 0.08            0.29 ± 0.09
# 269            0.35 ± 0.11            0.33 ± 0.08            0.22 ± 0.06
# 2              0.35 ± 0.08            0.25 ± 0.08            0.21 ± 0.08
# 250             0.33 ± 0.1            0.32 ± 0.08            0.21 ± 0.06
# 176            0.35 ± 0.08            0.25 ± 0.08            0.21 ± 0.08
# 174              nan ± nan             0.3 ± 0.08            0.27 ± 0.06
# 193             0.3 ± 0.06            0.28 ± 0.07            0.26 ± 0.05
# 40               nan ± nan            0.31 ± 0.06            0.24 ± 0.05
# 5              0.29 ± 0.05            0.26 ± 0.06            0.25 ± 0.05
# 6                nan ± nan            0.27 ± 0.08            0.26 ± 0.06
# 282              nan ± nan            0.27 ± 0.08            0.25 ± 0.06
# 19               nan ± nan            0.31 ± 0.07            0.21 ± 0.06
# 1                nan ± nan            0.24 ± 0.07            0.23 ± 0.05
# 300            0.28 ± 0.05            0.21 ± 0.07            0.21 ± 0.06
# 175            0.27 ± 0.05            0.21 ± 0.07            0.21 ± 0.06
# 15             0.27 ± 0.06            0.19 ± 0.07            0.18 ± 0.04
# 104              nan ± nan            0.22 ± 0.06            0.21 ± 0.05
# 137            0.25 ± 0.06            0.19 ± 0.07            0.18 ± 0.04
# 80             0.22 ± 0.09            0.21 ± 0.08            0.17 ± 0.05
# 63               nan ± nan            0.23 ± 0.06            0.19 ± 0.03
# 52               nan ± nan            0.22 ± 0.07             0.2 ± 0.04
# 61             0.25 ± 0.05            0.21 ± 0.05            0.15 ± 0.04
# 153            0.22 ± 0.09            0.21 ± 0.08            0.16 ± 0.05
# 188              nan ± nan            0.23 ± 0.07            0.19 ± 0.05
# 302            0.25 ± 0.05            0.21 ± 0.05            0.15 ± 0.04
# 319              nan ± nan            0.22 ± 0.06            0.19 ± 0.05
# 56             0.24 ± 0.06            0.21 ± 0.07            0.15 ± 0.04
# 245              nan ± nan            0.22 ± 0.07            0.18 ± 0.05
# 127            0.25 ± 0.06            0.18 ± 0.06            0.17 ± 0.04
# 121            0.23 ± 0.05            0.18 ± 0.06            0.17 ± 0.04
# 37               nan ± nan            0.21 ± 0.05            0.18 ± 0.04
# 72               nan ± nan            0.21 ± 0.06            0.18 ± 0.05
# 272              nan ± nan            0.21 ± 0.06            0.18 ± 0.04
# 284              nan ± nan            0.21 ± 0.07            0.17 ± 0.05
# 318            0.18 ± 0.05            0.17 ± 0.05            0.16 ± 0.05
# 294            0.18 ± 0.05            0.17 ± 0.05            0.16 ± 0.04
# 140            0.16 ± 0.07            0.14 ± 0.06            0.14 ± 0.04
# 169              nan ± nan            0.17 ± 0.06            0.16 ± 0.05
# 273            0.15 ± 0.07            0.14 ± 0.06            0.14 ± 0.04
# 211              nan ± nan            0.15 ± 0.05            0.15 ± 0.04
# 45               nan ± nan            0.14 ± 0.05            0.15 ± 0.04
# 252            0.13 ± 0.05             0.1 ± 0.04            0.12 ± 0.04
# 69             0.13 ± 0.05             0.1 ± 0.04            0.12 ± 0.04
# 73               nan ± nan            0.13 ± 0.05            0.13 ± 0.04
# 156              nan ± nan            0.12 ± 0.05            0.13 ± 0.04
# 234              nan ± nan            0.11 ± 0.04            0.12 ± 0.03
# 280              nan ± nan             0.1 ± 0.04            0.12 ± 0.04
# 173              nan ± nan            0.11 ± 0.04            0.12 ± 0.03
#
#     removeOOD:F-residual:T
# 230            0.73 ± 0.11
# 190            0.72 ± 0.13
# 268            0.72 ± 0.13
# 107            0.75 ± 0.07
# 213            0.73 ± 0.11
# 111            0.72 ± 0.13
# 138            0.73 ± 0.11
# 0               0.72 ± 0.1
# 68             0.72 ± 0.13
# 145            0.72 ± 0.12
# 291            0.72 ± 0.11
# 233              0.7 ± 0.1
# 249            0.72 ± 0.11
# 307            0.71 ± 0.12
# 297             0.7 ± 0.13
# 43             0.75 ± 0.07
# 160            0.72 ± 0.11
# 155            0.72 ± 0.11
# 208             0.72 ± 0.1
# 309            0.72 ± 0.11
# 46              0.7 ± 0.11
# 266            0.73 ± 0.09
# 12              0.72 ± 0.1
# 253            0.72 ± 0.11
# 186             0.72 ± 0.1
# 220             0.72 ± 0.1
# 260            0.71 ± 0.11
# 146             0.72 ± 0.1
# 98             0.71 ± 0.13
# 181            0.72 ± 0.11
# 289             0.71 ± 0.1
# 38              0.7 ± 0.12
# 303            0.73 ± 0.11
# 25             0.71 ± 0.09
# 241            0.54 ± 0.07
# 203             0.72 ± 0.1
# 103            0.71 ± 0.11
# 312            0.71 ± 0.12
# 292            0.71 ± 0.12
# 58             0.68 ± 0.13
# 20             0.69 ± 0.12
# 248            0.69 ± 0.12
# 178            0.76 ± 0.08
# 179            0.76 ± 0.08
# 187             0.6 ± 0.09
# 278             0.7 ± 0.12
# 236            0.71 ± 0.12
# 192            0.71 ± 0.12
# 27             0.69 ± 0.13
# 100             0.7 ± 0.12
# 11             0.69 ± 0.12
# 150             0.68 ± 0.1
# 157             0.7 ± 0.14
# 44             0.68 ± 0.13
# 198            0.69 ± 0.13
# 139             0.7 ± 0.05
# 184            0.69 ± 0.06
# 13             0.69 ± 0.06
# 99             0.54 ± 0.07
# 110            0.67 ± 0.09
# 164            0.48 ± 0.06
# 79             0.67 ± 0.12
# 304            0.68 ± 0.09
# 8              0.67 ± 0.11
# 232            0.65 ± 0.14
# 191            0.58 ± 0.09
# 270            0.67 ± 0.13
# 264            0.65 ± 0.07
# 158            0.69 ± 0.09
# 247            0.69 ± 0.09
# 62             0.67 ± 0.07
# 209            0.58 ± 0.09
# 49             0.68 ± 0.09
# 261            0.55 ± 0.08
# 154            0.66 ± 0.12
# 254            0.68 ± 0.14
# 305            0.45 ± 0.07
# 106            0.62 ± 0.16
# 256             0.65 ± 0.1
# 238            0.64 ± 0.13
# 163            0.67 ± 0.14
# 112            0.63 ± 0.06
# 42             0.62 ± 0.14
# 275            0.57 ± 0.12
# 240            0.57 ± 0.12
# 237            0.52 ± 0.08
# 257            0.47 ± 0.06
# 276            0.51 ± 0.07
# 21              0.57 ± 0.1
# 263             0.57 ± 0.1
# 32             0.61 ± 0.14
# 295             0.56 ± 0.1
# 14              0.56 ± 0.1
# 48             0.63 ± 0.14
# 129            0.61 ± 0.14
# 196            0.62 ± 0.11
# 199            0.61 ± 0.12
# 118            0.64 ± 0.14
# 65             0.63 ± 0.13
# 113            0.42 ± 0.06
# 134            0.45 ± 0.06
# 30              0.54 ± 0.1
# 207             0.54 ± 0.1
# 143             0.58 ± 0.1
# 210            0.59 ± 0.15
# 222            0.61 ± 0.12
# 308            0.48 ± 0.09
# 87             0.51 ± 0.06
# 212            0.49 ± 0.08
# 102             0.5 ± 0.06
# 51              0.4 ± 0.07
# 314            0.54 ± 0.09
# 298            0.48 ± 0.06
# 183             0.54 ± 0.1
# 288            0.52 ± 0.07
# 50             0.42 ± 0.07
# 316            0.46 ± 0.08
# 200            0.51 ± 0.06
# 24             0.44 ± 0.09
# 170            0.51 ± 0.07
# 39             0.45 ± 0.09
# 133            0.57 ± 0.14
# 36             0.48 ± 0.09
# 152            0.49 ± 0.05
# 66              0.5 ± 0.09
# 177             0.4 ± 0.07
# 147            0.38 ± 0.08
# 75             0.51 ± 0.08
# 281            0.51 ± 0.08
# 244            0.52 ± 0.08
# 167            0.52 ± 0.14
# 205            0.52 ± 0.16
# 26              0.47 ± 0.1
# 171            0.47 ± 0.06
# 101            0.45 ± 0.09
# 204            0.49 ± 0.11
# 180            0.51 ± 0.07
# 315            0.51 ± 0.07
# 317            0.46 ± 0.06
# 22              0.5 ± 0.09
# 283             0.5 ± 0.09
# 96             0.45 ± 0.08
# 219             0.48 ± 0.1
# 119             0.47 ± 0.1
# 258             0.46 ± 0.1
# 151            0.41 ± 0.08
# 78             0.46 ± 0.07
# 299            0.43 ± 0.08
# 9              0.43 ± 0.07
# 201            0.47 ± 0.06
# 117            0.49 ± 0.05
# 23             0.43 ± 0.09
# 274            0.42 ± 0.09
# 128            0.48 ± 0.06
# 246            0.56 ± 0.12
# 92             0.47 ± 0.06
# 105            0.42 ± 0.07
# 41              0.48 ± 0.1
# 67             0.41 ± 0.07
# 4               0.4 ± 0.07
# 85             0.36 ± 0.07
# 94             0.44 ± 0.09
# 242            0.37 ± 0.08
# 290            0.49 ± 0.09
# 141            0.49 ± 0.09
# 148            0.48 ± 0.13
# 90             0.47 ± 0.13
# 57             0.47 ± 0.07
# 228            0.44 ± 0.02
# 215            0.48 ± 0.06
# 311            0.43 ± 0.07
# 226            0.47 ± 0.07
# 35             0.35 ± 0.09
# 217             0.43 ± 0.1
# 76             0.45 ± 0.07
# 54              0.4 ± 0.08
# 120            0.47 ± 0.06
# 64             0.48 ± 0.06
# 224            0.47 ± 0.06
# 29             0.48 ± 0.08
# 70             0.44 ± 0.07
# 126            0.42 ± 0.07
# 251            0.47 ± 0.05
# 172             0.4 ± 0.09
# 34             0.37 ± 0.07
# 114             0.4 ± 0.09
# 18             0.42 ± 0.09
# 267            0.46 ± 0.06
# 218            0.47 ± 0.09
# 3              0.41 ± 0.07
# 287            0.41 ± 0.07
# 31             0.47 ± 0.07
# 195            0.44 ± 0.06
# 16             0.43 ± 0.07
# 202            0.41 ± 0.07
# 83              0.47 ± 0.1
# 271             0.47 ± 0.1
# 136            0.43 ± 0.07
# 149            0.42 ± 0.04
# 221             0.47 ± 0.1
# 131            0.45 ± 0.08
# 82             0.41 ± 0.06
# 194            0.46 ± 0.07
# 301            0.44 ± 0.16
# 313            0.34 ± 0.09
# 130            0.44 ± 0.07
# 231            0.41 ± 0.04
# 33             0.38 ± 0.06
# 235             0.4 ± 0.04
# 17              0.37 ± 0.1
# 277             0.4 ± 0.07
# 144            0.42 ± 0.06
# 225            0.41 ± 0.07
# 168             0.4 ± 0.08
# 161            0.39 ± 0.08
# 185            0.38 ± 0.07
# 86             0.43 ± 0.06
# 91             0.36 ± 0.07
# 239            0.43 ± 0.06
# 216            0.43 ± 0.06
# 77             0.42 ± 0.07
# 47             0.37 ± 0.07
# 227            0.42 ± 0.06
# 243            0.42 ± 0.08
# 135             0.39 ± 0.1
# 10             0.42 ± 0.06
# 53             0.37 ± 0.08
# 310            0.42 ± 0.08
# 262            0.36 ± 0.06
# 71             0.35 ± 0.07
# 165             0.35 ± 0.1
# 265            0.38 ± 0.08
# 142             0.4 ± 0.06
# 223            0.32 ± 0.08
# 214            0.39 ± 0.09
# 60             0.41 ± 0.06
# 197            0.41 ± 0.08
# 306              nan ± nan
# 89              0.4 ± 0.09
# 182            0.38 ± 0.11
# 97              0.4 ± 0.08
# 255            0.36 ± 0.09
# 166            0.39 ± 0.06
# 229            0.38 ± 0.08
# 84             0.34 ± 0.07
# 132            0.39 ± 0.08
# 55             0.35 ± 0.06
# 162            0.41 ± 0.09
# 28              0.38 ± 0.1
# 293            0.37 ± 0.08
# 206            0.39 ± 0.07
# 7              0.32 ± 0.09
# 125            0.37 ± 0.06
# 81              0.32 ± 0.1
# 259            0.37 ± 0.07
# 108             0.3 ± 0.08
# 296             0.3 ± 0.07
# 74             0.33 ± 0.06
# 59               nan ± nan
# 279            0.36 ± 0.08
# 109            0.33 ± 0.07
# 116            0.37 ± 0.07
# 159            0.35 ± 0.07
# 286            0.29 ± 0.07
# 88             0.32 ± 0.09
# 123             0.3 ± 0.05
# 93             0.34 ± 0.06
# 115            0.29 ± 0.07
# 122            0.28 ± 0.07
# 95             0.33 ± 0.07
# 124            0.33 ± 0.07
# 285              nan ± nan
# 189              nan ± nan
# 269             0.28 ± 0.1
# 2              0.33 ± 0.08
# 250            0.28 ± 0.09
# 176            0.33 ± 0.08
# 174              nan ± nan
# 193            0.27 ± 0.08
# 40               nan ± nan
# 5              0.27 ± 0.06
# 6                nan ± nan
# 282              nan ± nan
# 19               nan ± nan
# 1                nan ± nan
# 300            0.25 ± 0.07
# 175            0.24 ± 0.08
# 15             0.24 ± 0.05
# 104              nan ± nan
# 137            0.23 ± 0.06
# 80             0.25 ± 0.08
# 63               nan ± nan
# 52               nan ± nan
# 61             0.23 ± 0.07
# 153            0.25 ± 0.07
# 188              nan ± nan
# 302            0.23 ± 0.07
# 319              nan ± nan
# 56             0.21 ± 0.07
# 245              nan ± nan
# 127            0.21 ± 0.06
# 121             0.2 ± 0.06
# 37               nan ± nan
# 72               nan ± nan
# 272              nan ± nan
# 284              nan ± nan
# 318            0.21 ± 0.06
# 294            0.21 ± 0.06
# 140            0.23 ± 0.08
# 169              nan ± nan
# 273            0.23 ± 0.08
# 211              nan ± nan
# 45               nan ± nan
# 252            0.16 ± 0.05
# 69             0.16 ± 0.05
# 73               nan ± nan
# 156              nan ± nan
# 234              nan ± nan
# 280              nan ± nan
# 173              nan ± nan
