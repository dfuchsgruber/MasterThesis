# %%
import matplotlib.pyplot as plt
import numpy as np
import seml
import pandas as pd
import json
from collections import defaultdict
from functools import reduce
import seaborn as sns
from itertools import product
from scipy.stats import binned_statistic
from matplotlib.lines import Line2D

# %%
# %cd ..
# Out:
# /nfs/homedirs/fuchsgru/MastersThesis

# %%
import data.constants as dc

# %%
SETTING = 'Setting'
RESIDUAL = 'Residual'
ACCURACY = 'Accuracy'
ECE = 'Expected Calibration Error'
WEIGHT_SCALE = 'Weight Scale'
LIPSCHITZ = 'Median Empirical Lipschitz Constant'
LIPSCHITZ_MAX = 'Empirical Upper Lipschitz Constant'
LIPSCHITZ_MIN = 'Empirical Lower Lipschitz Constant'
OOD = 'Out of Distribution Setting'
PROXY = 'Proxy'
LOC = 'Leave out Classes'
BERNOULLI = 'Bernoulli'
NORMAL = 'Normal'
GPC = 'Feature Density'
MAX_SCORE = 'Max Score'
AUROC = 'AUC-ROC'
TRANSDUCTIVE = 'Transductive'
HYBRID = 'Hybrid'
NO_EDGES = 'Remove Edges'

# %%
# Out:
# Number of finished experiments : 100

# %%
baselines = {} # Aggregate all results here

# %% [markdown]
# ### Ensemble of GCNs

# %%
collection_name_ensemble = 'week15_ensemble'
collection_ensemble = seml.database.get_collection(collection_name_ensemble)
experiments_ensemble = [{'config' : r['config'], 'result' : r['result']['results'], 'id' : r['_id']} for r in collection_ensemble.find() if r['status'] in ('COMPLETED',)]

print(f'Number of finished experiments : {len(experiments_ensemble)}')
# Out:
# Number of finished experiments : 100

# %%
results_ensemble = []
for ex in experiments_ensemble:
    config = ex['config']
    metrics = {}
    for k, vs in ex['result'].items():
        if len(vs) != 1:
            raise RuntimeError(f'{k} : {vs}')
        v = vs[0]
        if isinstance(v, dict):
            v = v['value']
        metrics[k] = v
    
    base = {
        SETTING : {dc.TRANSDUCTIVE : TRANSDUCTIVE, dc.HYBRID : HYBRID}[config['data']['setting']],
        LIPSCHITZ : metrics['empirical_lipschitz_val_slope_median_perturbation_noise'],
        LIPSCHITZ_MAX : metrics['empirical_lipschitz_val_slope_max_perturbation_noise'],
        LIPSCHITZ_MIN : metrics['empirical_lipschitz_val_slope_min_perturbation_noise'],
    }
    results_ensemble.append({
        ECE : metrics['ece_val'],
        ACCURACY : metrics['accuracy_val'],
    } | base)
    for k, v in metrics.items():
        if '-no-edges' in k or '_no-edges' in k:
            k = k.replace('-no-edges', '').replace('_no-edges', '')
            no_edges = True
        else:
            no_edges = False
        
        # AUROCs
        if not 'auroc' in k:
            continue
        
        print(k)
            
        if k.endswith('loc'):
            ood = LOC
        elif k.endswith('ber'):
            ood = BERNOULLI
        elif k.endswith('normal'):
            ood = NORMAL
    break
results_ensemble
# Out:
# auroc_total-predictive-entropy_loc
# auroc_max-score_loc
# auroc_expected-softmax-entropy_loc
# auroc_mutual-information_loc
# auroc_predicted-class-variance_loc
# auroc_logit-energy_loc
# auroc_total-predictive-entropy_loc
# auroc_max-score_loc
# auroc_expected-softmax-entropy_loc
# auroc_mutual-information_loc
# auroc_predicted-class-variance_loc
# auroc_logit-energy_loc
# [{'Expected Calibration Error': 0.14169385348046526,
#   'Accuracy': 0.8357142806053162,
#   'Setting': 'Transductive',
#   'Median Empirical Lipschitz Constant': 0.11281829274418162,
#   'Empirical Upper Lipschitz Constant': 0.755159330368042,
#   'Empirical Lower Lipschitz Constant': 0.0036934067858225205}]

# %%
experiments[0]['result']
# Out:
# {'val_member_0_cross_entropy-val-4': [0.5912452340126038],
#  'val_member_0_accuracy-val-4': [0.8357142806053162],
#  'val_member_0_loss-val-4': [0.5912452340126038],
#  'val_member_1_cross_entropy-val-4': [0.5859426259994507],
#  'val_member_1_accuracy-val-4': [0.8500000238418579],
#  'val_member_1_loss-val-4': [0.5859426259994507],
#  'val_member_2_cross_entropy-val-4': [0.5993340611457825],
#  'val_member_2_accuracy-val-4': [0.8357142806053162],
#  'val_member_2_loss-val-4': [0.5993340611457825],
#  'val_member_3_cross_entropy-val-4': [0.6111315488815308],
#  'val_member_3_accuracy-val-4': [0.8428571224212646],
#  'val_member_3_loss-val-4': [0.6111315488815308],
#  'val_member_4_cross_entropy-val-4': [0.5939404368400574],
#  'val_member_4_accuracy-val-4': [0.8357142806053162],
#  'val_member_4_loss-val-4': [0.5939404368400574],
#  'ensemble_accuracy-val-4': [0.8357142806053162],
#  'accuracy_val': [0.8357142806053162],
#  'accuracy_id_val': [0.8357142806053162],
#  'accuracy_ood_val': [nan],
#  'accuracy_val_no-edges': [0.7928571701049805],
#  'accuracy_id_val_no-edges': [0.7928571701049805],
#  'accuracy_ood_val_no-edges': [nan],
#  'ece_val': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.14169385348046526}],
#  'ece_val_no-edges': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.11633118678415429}],
#  'empirical_lipschitz_val_slope_mean_perturbation_noise': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.13372276449726817}],
#  'empirical_lipschitz_val_slope_median_perturbation_noise': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.11281829274418162}],
#  'empirical_lipschitz_val_slope_max_perturbation_noise': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.755159330368042}],
#  'empirical_lipschitz_val_slope_min_perturbation_noise': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.0036934067858225205}],
#  'empirical_lipschitz_val_slope_mean_perturbation_derangement': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.3452466827152065}],
#  'empirical_lipschitz_val_slope_median_perturbation_derangement': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.28517015380434296}],
#  'empirical_lipschitz_val_slope_max_perturbation_derangement': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 87.06248018357375}],
#  'empirical_lipschitz_val_slope_min_perturbation_derangement': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.0}],
#  'accuracy_ood-val_loc-no-edges': [0.7136563658714294],
#  'accuracy_id_ood-val_loc-no-edges': [0.713004469871521],
#  'accuracy_ood_ood-val_loc-no-edges': [nan],
#  'auroc_total-predictive-entropy_loc-no-edges': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.8897048250586036}],
#  'aucpr_total-predictive-entropy_loc-no-edges': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.7044073737141018}],
#  'auroc_max-score_loc-no-edges': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.8726437335098965}],
#  'aucpr_max-score_loc-no-edges': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.6766305087253938}],
#  'auroc_expected-softmax-entropy_loc-no-edges': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.8901495771511121}],
#  'aucpr_expected-softmax-entropy_loc-no-edges': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.7050945889770527}],
#  'auroc_mutual-information_loc-no-edges': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.6140822557291092}],
#  'aucpr_mutual-information_loc-no-edges': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.4026876094764764}],
#  'auroc_predicted-class-variance_loc-no-edges': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.6233016656467465}],
#  'aucpr_predicted-class-variance_loc-no-edges': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.41993851405138205}],
#  'auroc_logit-energy_loc-no-edges': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.9004156592864572}],
#  'aucpr_logit-energy_loc-no-edges': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.7353752074442071}],
#  'accuracy_ood-val_loc': [0.784140944480896],
#  'accuracy_id_ood-val_loc': [0.7802690863609314],
#  'accuracy_ood_ood-val_loc': [nan],
#  'auroc_total-predictive-entropy_loc': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.9802670518955469}],
#  'aucpr_total-predictive-entropy_loc': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.9291414843655501}],
#  'auroc_max-score_loc': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.9748129867611011}],
#  'aucpr_max-score_loc': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.9173175394386129}],
#  'auroc_expected-softmax-entropy_loc': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.979571499750872}],
#  'aucpr_expected-softmax-entropy_loc': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.9254812325006379}],
#  'auroc_mutual-information_loc': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.2817270425992249}],
#  'aucpr_mutual-information_loc': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.1033574164678837}],
#  'auroc_predicted-class-variance_loc': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.501844216383597}],
#  'aucpr_predicted-class-variance_loc': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.21219193831821845}],
#  'auroc_logit-energy_loc': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.9850991329006196}],
#  'aucpr_logit-energy_loc': [{'py/object': 'numpy.float64',
#    'dtype': 'float64',
#    'value': 0.9343028632929724}]}

# %%
experiments[0]['config']
# Out:
# {'overwrite': 1,
#  'db_collection': 'week15_ensemble',
#  'data': {'base_labels': ['Artificial_Intelligence/Machine_Learning/Case-Based',
#    'Artificial_Intelligence/Machine_Learning/Theory',
#    'Artificial_Intelligence/Machine_Learning/Genetic_Algorithms',
#    'Artificial_Intelligence/Machine_Learning/Probabilistic_Methods',
#    'Artificial_Intelligence/Machine_Learning/Neural_Networks',
#    'Artificial_Intelligence/Machine_Learning/Rule_Learning',
#    'Artificial_Intelligence/Machine_Learning/Reinforcement_Learning',
#    'Operating_Systems/Distributed',
#    'Operating_Systems/Memory_Management',
#    'Operating_Systems/Realtime',
#    'Operating_Systems/Fault_Tolerance'],
#   'corpus_labels': ['Artificial_Intelligence/Machine_Learning/Case-Based',
#    'Artificial_Intelligence/Machine_Learning/Theory',
#    'Artificial_Intelligence/Machine_Learning/Genetic_Algorithms',
#    'Artificial_Intelligence/Machine_Learning/Probabilistic_Methods',
#    'Artificial_Intelligence/Machine_Learning/Neural_Networks',
#    'Artificial_Intelligence/Machine_Learning/Rule_Learning',
#    'Artificial_Intelligence/Machine_Learning/Reinforcement_Learning'],
#   'dataset': 'cora_full',
#   'drop_train_vertices_portion': 0.1,
#   'left_out_class_labels': ['Operating_Systems/Distributed',
#    'Operating_Systems/Memory_Management',
#    'Operating_Systems/Realtime',
#    'Operating_Systems/Fault_Tolerance'],
#   'ood_sampling_strategy': 'all',
#   'ood_type': 'left-out-classes',
#   'preprocessing': 'bag_of_words',
#   'setting': 'transductive',
#   'split_type': 'uniform',
#   'test_portion_fixed': 0.2,
#   'train_labels': ['Artificial_Intelligence/Machine_Learning/Case-Based',
#    'Artificial_Intelligence/Machine_Learning/Theory',
#    'Artificial_Intelligence/Machine_Learning/Genetic_Algorithms',
#    'Artificial_Intelligence/Machine_Learning/Probabilistic_Methods',
#    'Artificial_Intelligence/Machine_Learning/Neural_Networks',
#    'Artificial_Intelligence/Machine_Learning/Rule_Learning',
#    'Artificial_Intelligence/Machine_Learning/Reinforcement_Learning'],
#   'train_portion': 20,
#   'type': 'npz'},
#  'ensemble': {'num_members': 5},
#  'evaluation': {'ignore_exceptions': False,
#   'log_plots': False,
#   'pipeline': [{'evaluate_on': ['val'], 'type': 'EvaluateAccuracy'},
#    {'evaluate_on': ['val'],
#     'model_kwargs': {'remove_edges': True},
#     'name': 'no-edges',
#     'type': 'EvaluateAccuracy'},
#    {'evaluate_on': ['val'], 'type': 'EvaluateCalibration'},
#    {'evaluate_on': ['val'],
#     'model_kwargs': {'remove_edges': True},
#     'name': 'no-edges',
#     'type': 'EvaluateCalibration'},
#    {'max_perturbation': 10.0,
#     'min_perturbation': 0.1,
#     'name': 'noise',
#     'num_perturbations': 20,
#     'num_perturbations_per_sample': 5,
#     'perturbation_type': 'noise',
#     'seed': 1337,
#     'type': 'EvaluateEmpircalLowerLipschitzBounds'},
#    {'max_perturbation': 10.0,
#     'min_perturbation': 0.1,
#     'name': 'derangement',
#     'num_perturbations': 10,
#     'num_perturbations_per_sample': 5,
#     'perturbation_type': 'derangement',
#     'seed': 1337,
#     'type': 'EvaluateEmpircalLowerLipschitzBounds'},
#    {'evaluate_on': ['ood-val'],
#     'model_kwargs_evaluate': {'remove_edges': True},
#     'name': 'loc-no-edges',
#     'separate_distributions_by': 'ood-and-neighbourhood',
#     'separate_distributions_tolerance': 0.1,
#     'type': 'EvaluateAccuracy'},
#    {'evaluate_on': ['ood-val'],
#     'model_kwargs_evaluate': {'remove_edges': True},
#     'name': 'loc-no-edges',
#     'separate_distributions_by': 'ood-and-neighbourhood',
#     'separate_distributions_tolerance': 0.1,
#     'type': 'EvaluateSoftmaxEntropy'},
#    {'evaluate_on': ['ood-val'],
#     'model_kwargs_evaluate': {'remove_edges': True},
#     'name': 'loc-no-edges',
#     'separate_distributions_by': 'ood-and-neighbourhood',
#     'separate_distributions_tolerance': 0.1,
#     'type': 'EvaluateLogitEnergy'},
#    {'evaluate_on': ['ood-val'],
#     'name': 'loc',
#     'separate_distributions_by': 'ood-and-neighbourhood',
#     'separate_distributions_tolerance': 0.1,
#     'type': 'EvaluateAccuracy'},
#    {'evaluate_on': ['ood-val'],
#     'name': 'loc',
#     'separate_distributions_by': 'ood-and-neighbourhood',
#     'separate_distributions_tolerance': 0.1,
#     'type': 'EvaluateSoftmaxEntropy'},
#    {'evaluate_on': ['ood-val'],
#     'name': 'loc',
#     'separate_distributions_by': 'ood-and-neighbourhood',
#     'separate_distributions_tolerance': 0.1,
#     'type': 'EvaluateLogitEnergy'}]},
#  'model': {'activation': 'leaky_relu',
#   'freeze_residual_projection': False,
#   'hidden_sizes': [64],
#   'leaky_relu_slope': 0.01,
#   'model_type': 'gcn',
#   'residual': False,
#   'use_bias': True,
#   'use_spectral_norm': False,
#   'use_spectral_norm_on_last_layer': False,
#   'weight_scale': 1.0},
#  'run': {'args': ['model:residual', 'model:use_spectral_norm', 'data:setting'],
#   'initialization_idx': 0,
#   'name': 'residual:{0}-spectral_norm-{1}-setting:{2}-ood_type:loc',
#   'split_idx': 0},
#  'training': {'early_stopping': {'min_delta': 0.01,
#    'mode': 'min',
#    'monitor': 'val_loss',
#    'patience': 50},
#   'gpus': 1,
#   'learning_rate': 0.001,
#   'max_epochs': 1000},
#  'seed': 803572208}
