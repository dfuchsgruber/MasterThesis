# %%
import matplotlib.pyplot as plt
import numpy as np
import seml
import pandas as pd
import json
from collections import defaultdict
from functools import reduce
import seaborn as sns
from scipy.stats import binned_statistic
from matplotlib.lines import Line2D

# %%
# %cd ..
# Out:
# /nfs/homedirs/fuchsgru/MastersThesis

# %%
import data.constants as dc

# %%
collection_name = 'week18_dropout_all_datasets'
collection = seml.database.get_collection(collection_name)
experiments = [{'config' : r['config'], 'result' : r['result'], 'id' : r['_id']} for r in collection.find() if r['status'] in ('COMPLETED',)]
for ex in experiments:
    # print(ex['result'].keys())
    ex['metrics'] = ex['result']['results']

# %%
experiments_killed = [r for r in collection.find() if r['status'] in ('KILLED',)]

# %%
set(e['config']['data']['dataset'] for e in experiments_killed)
# Out:
# set()

# %%
experiments[0]['metrics'].keys()
# Out:
# dict_keys(['accuracy_val_val', 'accuracy_id_val_val', 'accuracy_ood_val_val', 'accuracy_val_no-edges_val', 'accuracy_id_val_no-edges_val', 'accuracy_ood_val_no-edges_val', 'ece_val_val', 'ece_val_no-edges_val', 'accuracy_ood-val_loc-no-edges_val', 'accuracy_id_ood-val_loc-no-edges_val', 'accuracy_ood_ood-val_loc-no-edges_val', 'ood_auroc_total-predictive-entropy_loc-no-edges_val', 'ood_aucpr_total-predictive-entropy_loc-no-edges_val', 'misclassification_auroc_total-predictive-entropy_loc-no-edges_val', 'misclassification_aucpr_total-predictive-entropy_loc-no-edges_val', 'ood_auroc_max-score_loc-no-edges_val', 'ood_aucpr_max-score_loc-no-edges_val', 'misclassification_auroc_max-score_loc-no-edges_val', 'misclassification_aucpr_max-score_loc-no-edges_val', 'ood_auroc_expected-softmax-entropy_loc-no-edges_val', 'ood_aucpr_expected-softmax-entropy_loc-no-edges_val', 'misclassification_auroc_expected-softmax-entropy_loc-no-edges_val', 'misclassification_aucpr_expected-softmax-entropy_loc-no-edges_val', 'ood_auroc_mutual-information_loc-no-edges_val', 'ood_aucpr_mutual-information_loc-no-edges_val', 'misclassification_auroc_mutual-information_loc-no-edges_val', 'misclassification_aucpr_mutual-information_loc-no-edges_val', 'ood_auroc_predicted-class-variance_loc-no-edges_val', 'ood_aucpr_predicted-class-variance_loc-no-edges_val', 'misclassification_auroc_predicted-class-variance_loc-no-edges_val', 'misclassification_aucpr_predicted-class-variance_loc-no-edges_val', 'ood_auroc_sampled-class-variance_loc-no-edges_val', 'ood_aucpr_sampled-class-variance_loc-no-edges_val', 'misclassification_auroc_sampled-class-variance_loc-no-edges_val', 'misclassification_aucpr_sampled-class-variance_loc-no-edges_val', 'ood_auroc_logit-energy_loc-no-edges_val', 'ood_aucpr_logit-energy_loc-no-edges_val', 'misclassification_auroc_logit-energy_loc-no-edges_val', 'misclassification_aucpr_logit-energy_loc-no-edges_val', 'accuracy_ood-val_loc_val', 'accuracy_id_ood-val_loc_val', 'accuracy_ood_ood-val_loc_val', 'ood_auroc_total-predictive-entropy_loc_val', 'ood_aucpr_total-predictive-entropy_loc_val', 'misclassification_auroc_total-predictive-entropy_loc_val', 'misclassification_aucpr_total-predictive-entropy_loc_val', 'ood_auroc_max-score_loc_val', 'ood_aucpr_max-score_loc_val', 'misclassification_auroc_max-score_loc_val', 'misclassification_aucpr_max-score_loc_val', 'ood_auroc_expected-softmax-entropy_loc_val', 'ood_aucpr_expected-softmax-entropy_loc_val', 'misclassification_auroc_expected-softmax-entropy_loc_val', 'misclassification_aucpr_expected-softmax-entropy_loc_val', 'ood_auroc_mutual-information_loc_val', 'ood_aucpr_mutual-information_loc_val', 'misclassification_auroc_mutual-information_loc_val', 'misclassification_aucpr_mutual-information_loc_val', 'ood_auroc_predicted-class-variance_loc_val', 'ood_aucpr_predicted-class-variance_loc_val', 'misclassification_auroc_predicted-class-variance_loc_val', 'misclassification_aucpr_predicted-class-variance_loc_val', 'ood_auroc_sampled-class-variance_loc_val', 'ood_aucpr_sampled-class-variance_loc_val', 'misclassification_auroc_sampled-class-variance_loc_val', 'misclassification_aucpr_sampled-class-variance_loc_val', 'ood_auroc_logit-energy_loc_val', 'ood_aucpr_logit-energy_loc_val', 'misclassification_auroc_logit-energy_loc_val', 'misclassification_aucpr_logit-energy_loc_val', 'accuracy_test_test', 'accuracy_id_test_test', 'accuracy_ood_test_test', 'accuracy_test_no-edges_test', 'accuracy_id_test_no-edges_test', 'accuracy_ood_test_no-edges_test', 'ece_test_test', 'ece_test_no-edges_test', 'accuracy_ood-test_loc-no-edges_test', 'accuracy_id_ood-test_loc-no-edges_test', 'accuracy_ood_ood-test_loc-no-edges_test', 'ood_auroc_total-predictive-entropy_loc-no-edges_test', 'ood_aucpr_total-predictive-entropy_loc-no-edges_test', 'misclassification_auroc_total-predictive-entropy_loc-no-edges_test', 'misclassification_aucpr_total-predictive-entropy_loc-no-edges_test', 'ood_auroc_max-score_loc-no-edges_test', 'ood_au ...

# %%
METRIC = 'Metric'
OOD_AUROC = 'OOD AUC-ROC'
OOD_AUCPR = 'OOD AUC-PR'
MISCLASSICIFACTION_AUROC = 'Misclassification AUC-ROC'
MISCLASSICIFACTION_AUCPR = 'Misclassification AUC-PR'

DATASET = 'Dataset'

SETTING = 'Setting'
HYBRID = 'Inductive'
TRANSDUCTIVE = 'Transductive'
LOC = 'Leave Out Classes'
NORMAL = 'Normal'
BERNOULLI = 'Bernoulli'
NO_EDGES = 'No Edges'
PROXY = 'Proxy'
EXPERIMENT = 'Experiment'

OOD_TYPE = 'OOD Type'


RESIDUAL = 'Residual'
SPECTRAL_NORM = 'Spectral Norm'
WEIGHT_SCALE = 'Weight Scale'
LOWER_LIPSCHITZ = 'Empirical Lower Lipschitz Bound'
UPPER_LIPSCHITZ = 'Empirical Upper Lipschitz Bound'



EPISTEMIC = 'Epistemic'
ALEATORIC = 'Aleatoric'

ACCURACY = 'Accuracy'
ACCURACY_ID = 'In-distribution Accuracy'
ECE = 'Expected Calibration Error'

MODEL = 'Model'
DROPOUT = 'Dropout'
DROP_EDGE = 'Drop Edge'

# %%
set(ex['config']['model']['residual'] for ex in experiments), \
    set(ex['config']['model']['use_spectral_norm'] for ex in experiments)
# Out:
# ({False}, {False})

# %%
metrics = set()
for ex in experiments:
    for m in [m for m in ex['metrics'].keys() if 'accuracy' in m]:
        metrics.add(m)

list(metrics)
# Out:
# ['accuracy_normal-test_normal-no-edges_test',
#  'accuracy_id_ood-test_loc-no-edges_test',
#  'accuracy_ood_ood-test_loc_test',
#  'accuracy_id_ber-test_ber-no-edges_test',
#  'accuracy_id_ber-val_ber-no-edges_val',
#  'accuracy_id_normal-val_normal-no-edges_val',
#  'accuracy_ood_test_test',
#  'accuracy_ood_ood-val_loc_val',
#  'accuracy_ber-test_ber-no-edges_test',
#  'accuracy_ood_val_no-edges_val',
#  'accuracy_ood_ood-val_loc-no-edges_val',
#  'accuracy_ber-val_ber-no-edges_val',
#  'accuracy_ood_ber-val_ber_val',
#  'accuracy_ood_val_val',
#  'accuracy_id_normal-test_normal_test',
#  'accuracy_ood_normal-val_normal-no-edges_val',
#  'accuracy_ood_ber-val_ber-no-edges_val',
#  'accuracy_id_normal-val_normal_val',
#  'accuracy_ood-val_loc-no-edges_val',
#  'accuracy_ood_test_no-edges_test',
#  'accuracy_ood-val_loc_val',
#  'accuracy_ber-val_ber_val',
#  'accuracy_normal-val_normal-no-edges_val',
#  'accuracy_ber-test_ber_test',
#  'accuracy_ood-test_loc-no-edges_test',
#  'accuracy_normal-test_normal_test',
#  'accuracy_ood_ber-test_ber-no-edges_test',
#  'accuracy_ood-test_loc_test',
#  'accuracy_ood_normal-test_normal-no-edges_test',
#  'accuracy_ood_normal-val_normal_val',
#  'accuracy_normal-val_normal_val',
#  'accuracy_ood_ber-test_ber_test',
#  'accuracy_id_normal-test_normal-no-edges_test',
#  'accuracy_id_ber-val_ber_val',
#  'accuracy_id_ber-test_ber_test',
#  'accuracy_val_no-edges_val',
#  'accuracy_id_val_val',
#  'accuracy_id_ood-val_loc_val',
#  'accuracy_id_ood-test_loc_test',
#  'accuracy_ood_ood-test_loc-no-edges_test',
#  'accuracy_val_val',
#  'accuracy_id_val_no-edges_val',
#  'accuracy_id_test_test',
#  'accuracy_ood_normal-test_normal_test',
#  'accuracy_test_test',
#  'accuracy_test_no-edges_test',
#  'accuracy_id_test_no-edges_test',
#  'accuracy_id_ood-val_loc-no-edges_val']

# %%
mode = 'test'

# %%
data_proxy, data_acc_ece = [], []
for ex in experiments:
    cfg = ex['config']
    if cfg['model']['dropout'] > 0:
        model = DROPOUT
    elif cfg['model']['drop_edge'] > 0:
        model = DROP_EDGE
    else:
        raise RuntimeError
    base = {
        SETTING : {dc.HYBRID : HYBRID, dc.TRANSDUCTIVE : TRANSDUCTIVE}[cfg['data']['setting']],
        DATASET : cfg['data']['dataset'],
        MODEL : model,
    }
    data_acc_ece.append(base | {
        OOD_TYPE : cfg['data']['ood_type'],
        ACCURACY : ex['metrics'][f'accuracy_{mode}_{mode}'][0],
        ECE : ex['metrics'][f'ece_{mode}_{mode}'][0]['value'],
    })
    if cfg['data']['ood_type'] == dc.PERTURBATION:
        ood_types = (
            (BERNOULLI, 'ber'),
            (NORMAL, 'normal'),
        )
    elif cfg['data']['ood_type'] == dc.LEFT_OUT_CLASSES:
        ood_types = (
            (LOC, 'loc'),
        )
    else:
        raise ValueError(cfg['data']['ood_type'])
    
    for no_edge_suffix, no_edges in (('-no-edges', True), ('', False)):
    
        for ood_type, ood_name in ood_types:
            for proxy, proxy_name in ((ALEATORIC, 'expected-softmax-entropy'), (EPISTEMIC, 'mutual-information')):
                data_proxy += [
                    base | {
                        EXPERIMENT : ood_type,
                        PROXY : proxy,
                        OOD_AUROC : ex['metrics'][f'ood_auroc_{proxy_name}_{ood_name}{no_edge_suffix}_{mode}'][0]['value'],
                        OOD_AUCPR : ex['metrics'][f'ood_aucpr_{proxy_name}_{ood_name}{no_edge_suffix}_{mode}'][0]['value'],
                        MISCLASSICIFACTION_AUROC : ex['metrics'][f'misclassification_auroc_{proxy_name}_{ood_name}{no_edge_suffix}_{mode}'][0]['value'],
                        MISCLASSICIFACTION_AUCPR : ex['metrics'][f'misclassification_aucpr_{proxy_name}_{ood_name}{no_edge_suffix}_{mode}'][0]['value'],
                        NO_EDGES : no_edges,
                    }
                ]
    
        
        
    
df_proxy = pd.DataFrame(data_proxy)
df_acc_ece = pd.DataFrame(data_acc_ece)

# %%
def agg_mean_and_std(group):
    mean = group.mean()
    std = group.std()
    return f'{mean:.2f} ± {std:.2f}'
    return mean

df_proxy_agg = df_proxy.groupby([SETTING, MODEL, DATASET, EXPERIMENT, NO_EDGES, PROXY]).agg(agg_mean_and_std)

# %%
df_tmp = df_proxy_agg.reset_index()
df_tmp = df_tmp.melt(id_vars=[MODEL, SETTING, DATASET, EXPERIMENT, NO_EDGES, PROXY], value_vars = [OOD_AUROC, OOD_AUCPR, MISCLASSICIFACTION_AUROC, MISCLASSICIFACTION_AUCPR], var_name='Metric')
df_tmp = df_tmp[(df_tmp[METRIC] == OOD_AUROC) | (df_tmp[METRIC] == OOD_AUCPR)]
df_tmp = df_tmp.pivot(index=[SETTING, DATASET, MODEL, PROXY], columns=[METRIC, EXPERIMENT, NO_EDGES]).T.sort_index().T
df_tmp.to_csv('~/dropout_all_datasets_ood_detection.csv')

# %%
df_tmp
# Out:
#                                                      value               \
# Metric                                          OOD AUC-PR
# Experiment                                       Bernoulli
# No Edges                                             False         True
# Setting      Dataset      Model     Proxy
# Inductive    amazon_photo Drop Edge Aleatoric  0.50 ± 0.02  1.00 ± 0.00
#                                     Epistemic  0.49 ± 0.01  0.30 ± 0.02
#                           Dropout   Aleatoric  0.47 ± 0.03  1.00 ± 0.00
#                                     Epistemic  0.46 ± 0.02  0.30 ± 0.02
#              citeseer     Drop Edge Aleatoric  0.75 ± 0.01  1.00 ± 0.00
#                                     Epistemic  0.67 ± 0.03  0.51 ± 0.02
#                           Dropout   Aleatoric  0.74 ± 0.02  0.99 ± 0.00
#                                     Epistemic  0.68 ± 0.04  0.52 ± 0.02
#              coauthor_cs  Drop Edge Aleatoric  0.55 ± 0.01  1.00 ± 0.00
#                                     Epistemic  0.55 ± 0.02  0.34 ± 0.01
#                           Dropout   Aleatoric  0.55 ± 0.01  0.99 ± 0.00
#                                     Epistemic  0.55 ± 0.03  0.35 ± 0.01
#              cora_full    Drop Edge Aleatoric  0.61 ± 0.03  0.95 ± 0.02
#                                     Epistemic  0.57 ± 0.04  0.38 ± 0.04
#                           Dropout   Aleatoric  0.59 ± 0.05  0.88 ± 0.02
#                                     Epistemic  0.60 ± 0.03  0.55 ± 0.06
#              cora_ml      Drop Edge Aleatoric  0.61 ± 0.03  0.89 ± 0.05
#                                     Epistemic  0.57 ± 0.04  0.44 ± 0.08
#                           Dropout   Aleatoric  0.60 ± 0.04  0.82 ± 0.03
#                                     Epistemic  0.63 ± 0.03  0.71 ± 0.07
#              ogbn_arxiv   Drop Edge Aleatoric  0.50 ± 0.00  0.80 ± 0.07
#                                     Epistemic  0.48 ± 0.00  0.33 ± 0.01
#                           Dropout   Aleatoric  0.50 ± 0.00  0.76 ± 0.03
#                                     Epistemic  0.47 ± 0.00  0.34 ± 0.01
#              pubmed       Drop Edge Aleatoric  0.61 ± 0.07  0.58 ± 0.10
#                                     Epistemic  0.68 ± 0.02  0.72 ± 0.11
#                           Dropout   Aleatoric  0.62 ± 0.05  0.57 ± 0.09
#                                     Epistemic  0.72 ± 0.03  0.92 ± 0.02
# Transductive amazon_photo Drop Edge Aleatoric  0.49 ± 0.03  1.00 ± 0.00
#                                     Epistemic  0.48 ± 0.02  0.29 ± 0.02
#                           Dropout   Aleatoric  0.47 ± 0.03  1.00 ± 0.00
#                                     Epistemic  0.44 ± 0.03  0.29 ± 0.02
#              citeseer     Drop Edge Aleatoric  0.70 ± 0.06  1.00 ± 0.00
#                                     Epistemic  0.49 ± 0.05  0.32 ± 0.02
#                           Dropout   Aleatoric  0.68 ± 0.05  1.00 ± 0.00
#                                     Epistemic  0.40 ± 0.04  0.32 ± 0.02
#              coauthor_cs  Drop Edge Aleatoric  0.54 ± 0.01  1.00 ± 0.00
#                                     Epistemic  0.52 ± 0.02  0.30 ± 0.01
#                           Dropout   Aleatoric  0.52 ± 0.01  1.00 ± 0.00
#                                     Epistemic  0.44 ± 0.02  0.30 ± 0.01
#              cora_full    Drop Edge Aleatoric  0.58 ± 0.03  0.94 ± 0.03
#                                     Epistemic  0.51 ± 0.03  0.30 ± 0.03
#                           Dropout   Aleatoric  0.56 ± 0.06  0.89 ± 0.03
#                                     Epistemic  0.44 ± 0.02  0.39 ± 0.03
#              cora_ml      Drop Edge Aleatoric  0.57 ± 0.03  0.85 ± 0.07
#                                     Epistemic  0.52 ± 0.04  0.33 ± 0.05
#                           Dropout   Aleatoric  0.57 ± 0.06  0.83 ± 0.03
#                                     Epistemic  0.47 ± 0.02  0.55 ± 0.06
#              ogbn_arxiv   Drop Edge Aleatoric  0.49 ± 0.00  0.79 ± 0.07
#                                     Epistemic  0.48 ± 0.00  0.31 ± 0.01
#                           Dropout   Aleatoric  0.49 ± 0.00  0.78 ± 0.03
#                                     Epistemic  0.44 ± 0.00  0.31 ± 0.01
#              pubmed       Drop Edge Aleatoric  0.51 ± 0.06  0.46 ± 0.08
#                                     Epistemic  0.56 ± 0.03  0.51 ± 0.16
#                           Dropout   Aleatoric  0.52 ± 0.05  0.44 ± 0.06
#                                     Epistemic  0.56 ± 0.05  0.86 ± 0.03
#
#                                                                               \
# Metric
# Experiment                                    Leave Out Classes
# No Edges                                                  False         True
# Setting      Dataset      Model     Proxy
# Inductive    amazon_photo Drop Edge Aleatoric       0.61 ± 0.09  0.36 ± 0.04
#                                     Epistemic       0.44 ± 0.07  0.19 ± 0.02
#                           Dropout   Aleatoric       0.48 ± 0.10  0.39 ± 0.06
#                                     Epistemic       0.21 ± 0.04  0.23 ± 0.02
#              citeseer     Drop Edge Aleatoric       0.66 ± 0.11  0.46 ± 0.09
#                                     Epistemic       0.15 ± 0.01  0.19 ± 0.03
#                           Dropout   Aleatoric       0.59 ± 0.08  0.45 ± 0.09
#                                     Epistemic       0.18 ± 0.02  0.20 ± 0.02
#              coauthor_cs  Drop Edge Aleatoric       0.26 ± 0.07  0.27 ± 0.03
#                                     Epistemic       0.18 ± 0.03  0.10 ± 0.01
#                           Dropout   Aleatoric       0.31 ± 0.10  0.31 ± 0.05
#                                     Epistemic       0.12 ± 0.01  0.11 ± 0.01
#              cora_full    Drop Edge Aleatoric       0.89 ± 0.04  0.72 ± 0.04
#                                     Epistemic       0.11 ± 0.01  0.11 ± 0.01
#                           Dropout   Aleatoric       0.75 ± 0.02  0.71 ± 0.04
#                                     Epistemic       0.12 ± 0.01  0.11 ± 0.01
#              cora_ml      Drop Edge Aleatoric       0.89 ± 0.04  0.61 ± 0.04
#                                     Epistemic       0.19 ± 0.02  0.19 ± 0.02
#                           Dropout   Aleatoric       0.81 ± 0.03  0.63 ± 0.04
#                                     Epistemic       0.18 ± 0.01  0.21 ± 0.02
#              ogbn_arxiv   Drop Edge Aleatoric       0.58 ± 0.01  0.06 ± 0.00
#                                     Epistemic       0.05 ± 0.00  0.02 ± 0.00
#                           Dropout   Aleatoric       0.61 ± 0.01  0.07 ± 0.00
#                                     Epistemic       0.02 ± 0.00  0.03 ± 0.00
#              pubmed       Drop Edge Aleatoric       0.33 ± 0.06  0.33 ± 0.04
#                                     Epistemic       0.17 ± 0.03  0.19 ± 0.05
#                           Dropout   Aleatoric       0.31 ± 0.06  0.34 ± 0.05
#                                     Epistemic       0.21 ± 0.04  0.21 ± 0.04
# Transductive amazon_photo Drop Edge Aleatoric       0.58 ± 0.14  0.35 ± 0.06
#                                     Epistemic       0.42 ± 0.09  0.19 ± 0.02
#                           Dropout   Aleatoric       0.50 ± 0.13  0.38 ± 0.06
#                                     Epistemic       0.19 ± 0.03  0.23 ± 0.02
#              citeseer     Drop Edge Aleatoric       0.56 ± 0.16  0.40 ± 0.14
#                                     Epistemic       0.10 ± 0.02  0.12 ± 0.05
#                           Dropout   Aleatoric       0.57 ± 0.15  0.41 ± 0.16
#                                     Epistemic       0.09 ± 0.01  0.13 ± 0.05
#              coauthor_cs  Drop Edge Aleatoric       0.32 ± 0.12  0.25 ± 0.05
#                                     Epistemic       0.23 ± 0.07  0.09 ± 0.01
#                           Dropout   Aleatoric       0.30 ± 0.13  0.24 ± 0.05
#                                     Epistemic       0.09 ± 0.01  0.10 ± 0.01
#              cora_full    Drop Edge Aleatoric       0.94 ± 0.02  0.76 ± 0.06
#                                     Epistemic       0.08 ± 0.01  0.08 ± 0.01
#                           Dropout   Aleatoric       0.78 ± 0.02  0.76 ± 0.06
#                                     Epistemic       0.08 ± 0.01  0.08 ± 0.01
#              cora_ml      Drop Edge Aleatoric       0.89 ± 0.03  0.58 ± 0.06
#                                     Epistemic       0.16 ± 0.02  0.15 ± 0.02
#                           Dropout   Aleatoric       0.83 ± 0.05  0.61 ± 0.05
#                                     Epistemic       0.14 ± 0.02  0.16 ± 0.02
#              ogbn_arxiv   Drop Edge Aleatoric       0.54 ± 0.01  0.05 ± 0.00
#                                     Epistemic       0.04 ± 0.00  0.02 ± 0.00
#                           Dropout   Aleatoric       0.53 ± 0.02  0.05 ± 0.00
#                                     Epistemic       0.02 ± 0.00  0.02 ± 0.00
#              pubmed       Drop Edge Aleatoric       0.34 ± 0.17  0.26 ± 0.09
#                                     Epistemic       0.16 ± 0.03  0.16 ± 0.05
#                           Dropout   Aleatoric       0.31 ± 0.14  0.29 ± 0.09
#                                     Epistemic       0.14 ± 0.03  0.14 ± 0.03
#
#                                                                          \
# Metric
# Experiment                                          Normal
# No Edges                                             False         True
# Setting      Dataset      Model     Proxy
# Inductive    amazon_photo Drop Edge Aleatoric  0.49 ± 0.02  0.66 ± 0.04
#                                     Epistemic  0.49 ± 0.02  0.37 ± 0.04
#                           Dropout   Aleatoric  0.49 ± 0.04  0.52 ± 0.05
#                                     Epistemic  0.49 ± 0.03  0.62 ± 0.06
#              citeseer     Drop Edge Aleatoric  0.59 ± 0.02  0.53 ± 0.03
#                                     Epistemic  0.90 ± 0.03  0.97 ± 0.01
#                           Dropout   Aleatoric  0.62 ± 0.03  0.52 ± 0.02
#                                     Epistemic  0.79 ± 0.06  0.98 ± 0.01
#              coauthor_cs  Drop Edge Aleatoric  0.55 ± 0.01  0.67 ± 0.02
#                                     Epistemic  0.57 ± 0.01  0.51 ± 0.02
#                           Dropout   Aleatoric  0.55 ± 0.02  0.49 ± 0.02
#                                     Epistemic  0.54 ± 0.03  0.75 ± 0.02
#              cora_full    Drop Edge Aleatoric  0.43 ± 0.03  0.41 ± 0.04
#                                     Epistemic  0.73 ± 0.03  0.91 ± 0.03
#                           Dropout   Aleatoric  0.41 ± 0.04  0.36 ± 0.03
#                                     Epistemic  0.86 ± 0.03  0.99 ± 0.00
#              cora_ml      Drop Edge Aleatoric  0.41 ± 0.03  0.40 ± 0.04
#                                     Epistemic  0.71 ± 0.05  0.93 ± 0.02
#                           Dropout   Aleatoric  0.41 ± 0.04  0.36 ± 0.03
#                                     Epistemic  0.85 ± 0.03  0.99 ± 0.03
#              ogbn_arxiv   Drop Edge Aleatoric  0.49 ± 0.00  0.42 ± 0.00
#                                     Epistemic  0.51 ± 0.00  0.69 ± 0.00
#                           Dropout   Aleatoric  0.49 ± 0.00  0.31 ± 0.00
#                                     Epistemic  0.52 ± 0.00  0.92 ± 0.00
#              pubmed       Drop Edge Aleatoric  0.45 ± 0.01  0.45 ± 0.01
#                                     Epistemic  0.74 ± 0.02  0.94 ± 0.02
#                           Dropout   Aleatoric  0.47 ± 0.01  0.43 ± 0.01
#                                     Epistemic  0.88 ± 0.01  0.94 ± 0.01
# Transductive amazon_photo Drop Edge Aleatoric  0.49 ± 0.03  0.67 ± 0.03
#                                     Epistemic  0.49 ± 0.02  0.35 ± 0.03
#                           Dropout   Aleatoric  0.49 ± 0.05  0.54 ± 0.06
#                                     Epistemic  0.46 ± 0.04  0.59 ± 0.05
#              citeseer     Drop Edge Aleatoric  0.54 ± 0.07  0.41 ± 0.04
#                                     Epistemic  0.75 ± 0.05  0.77 ± 0.06
#                           Dropout   Aleatoric  0.54 ± 0.07  0.35 ± 0.03
#                                     Epistemic  0.51 ± 0.07  0.87 ± 0.07
#              coauthor_cs  Drop Edge Aleatoric  0.54 ± 0.01  0.65 ± 0.02
#                                     Epistemic  0.54 ± 0.02  0.42 ± 0.02
#                           Dropout   Aleatoric  0.52 ± 0.01  0.47 ± 0.02
#                                     Epistemic  0.43 ± 0.01  0.66 ± 0.03
#              cora_full    Drop Edge Aleatoric  0.37 ± 0.03  0.33 ± 0.03
#                                     Epistemic  0.69 ± 0.05  0.83 ± 0.05
#                           Dropout   Aleatoric  0.31 ± 0.03  0.27 ± 0.02
#                                     Epistemic  0.78 ± 0.04  0.98 ± 0.01
#              cora_ml      Drop Edge Aleatoric  0.35 ± 0.03  0.32 ± 0.03
#                                     Epistemic  0.65 ± 0.07  0.85 ± 0.04
#                           Dropout   Aleatoric  0.30 ± 0.03  0.27 ± 0.02
#                                     Epistemic  0.79 ± 0.05  0.96 ± 0.05
#              ogbn_arxiv   Drop Edge Aleatoric  0.48 ± 0.00  0.40 ± 0.00
#                                     Epistemic  0.50 ± 0.00  0.66 ± 0.00
#                           Dropout   Aleatoric  0.47 ± 0.00  0.30 ± 0.00
#                                     Epistemic  0.49 ± 0.00  0.91 ± 0.00
#              pubmed       Drop Edge Aleatoric  0.32 ± 0.02  0.31 ± 0.01
#                                     Epistemic  0.59 ± 0.02  0.86 ± 0.02
#                           Dropout   Aleatoric  0.31 ± 0.02  0.29 ± 0.01
#                                     Epistemic  0.83 ± 0.02  0.90 ± 0.02
#
#                                                                          \
# Metric                                         OOD AUC-ROC
# Experiment                                       Bernoulli
# No Edges                                             False         True
# Setting      Dataset      Model     Proxy
# Inductive    amazon_photo Drop Edge Aleatoric  0.50 ± 0.01  1.00 ± 0.00
#                                     Epistemic  0.48 ± 0.01  0.00 ± 0.00
#                           Dropout   Aleatoric  0.50 ± 0.02  1.00 ± 0.00
#                                     Epistemic  0.48 ± 0.01  0.00 ± 0.00
#              citeseer     Drop Edge Aleatoric  0.55 ± 0.03  1.00 ± 0.01
#                                     Epistemic  0.45 ± 0.04  0.00 ± 0.00
#                           Dropout   Aleatoric  0.54 ± 0.03  0.98 ± 0.01
#                                     Epistemic  0.44 ± 0.04  0.03 ± 0.01
#              coauthor_cs  Drop Edge Aleatoric  0.51 ± 0.01  1.00 ± 0.00
#                                     Epistemic  0.51 ± 0.02  0.00 ± 0.00
#                           Dropout   Aleatoric  0.50 ± 0.02  0.99 ± 0.00
#                                     Epistemic  0.50 ± 0.02  0.02 ± 0.00
#              cora_full    Drop Edge Aleatoric  0.55 ± 0.04  0.92 ± 0.04
#                                     Epistemic  0.44 ± 0.06  0.07 ± 0.03
#                           Dropout   Aleatoric  0.51 ± 0.02  0.80 ± 0.04
#                                     Epistemic  0.51 ± 0.03  0.38 ± 0.04
#              cora_ml      Drop Edge Aleatoric  0.53 ± 0.04  0.81 ± 0.08
#                                     Epistemic  0.46 ± 0.06  0.18 ± 0.09
#                           Dropout   Aleatoric  0.51 ± 0.02  0.69 ± 0.06
#                                     Epistemic  0.53 ± 0.03  0.58 ± 0.07
#              ogbn_arxiv   Drop Edge Aleatoric  0.51 ± 0.00  0.77 ± 0.07
#                                     Epistemic  0.47 ± 0.00  0.11 ± 0.05
#                           Dropout   Aleatoric  0.51 ± 0.00  0.71 ± 0.03
#                                     Epistemic  0.48 ± 0.00  0.17 ± 0.02
#              pubmed       Drop Edge Aleatoric  0.45 ± 0.10  0.41 ± 0.15
#                                     Epistemic  0.58 ± 0.05  0.61 ± 0.14
#                           Dropout   Aleatoric  0.48 ± 0.07  0.34 ± 0.12
#                                     Epistemic  0.59 ± 0.05  0.87 ± 0.03
# Transductive amazon_photo Drop Edge Aleatoric  0.52 ± 0.03  1.00 ± 0.00
#                                     Epistemic  0.51 ± 0.03  0.00 ± 0.00
#                           Dropout   Aleatoric  0.51 ± 0.03  1.00 ± 0.00
#                                     Epistemic  0.47 ± 0.02  0.00 ± 0.00
#              citeseer     Drop Edge Aleatoric  0.70 ± 0.05  1.00 ± 0.01
#                                     Epistemic  0.45 ± 0.05  0.00 ± 0.01
#                           Dropout   Aleatoric  0.67 ± 0.04  1.00 ± 0.01
#                                     Epistemic  0.32 ± 0.04  0.01 ± 0.01
#              coauthor_cs  Drop Edge Aleatoric  0.58 ± 0.01  1.00 ± 0.00
#                                     Epistemic  0.54 ± 0.02  0.00 ± 0.00
#                           Dropout   Aleatoric  0.56 ± 0.02  0.99 ± 0.00
#                                     Epistemic  0.45 ± 0.02  0.02 ± 0.01
#              cora_full    Drop Edge Aleatoric  0.63 ± 0.02  0.92 ± 0.04
#                                     Epistemic  0.51 ± 0.04  0.08 ± 0.05
#                           Dropout   Aleatoric  0.60 ± 0.02  0.85 ± 0.03
#                                     Epistemic  0.44 ± 0.03  0.29 ± 0.03
#              cora_ml      Drop Edge Aleatoric  0.62 ± 0.03  0.82 ± 0.09
#                                     Epistemic  0.54 ± 0.04  0.16 ± 0.07
#                           Dropout   Aleatoric  0.60 ± 0.02  0.77 ± 0.04
#                                     Epistemic  0.46 ± 0.03  0.49 ± 0.05
#              ogbn_arxiv   Drop Edge Aleatoric  0.53 ± 0.00  0.78 ± 0.07
#                                     Epistemic  0.50 ± 0.00  0.11 ± 0.05
#                           Dropout   Aleatoric  0.52 ± 0.00  0.73 ± 0.04
#                                     Epistemic  0.46 ± 0.00  0.15 ± 0.03
#              pubmed       Drop Edge Aleatoric  0.51 ± 0.08  0.46 ± 0.12
#                                     Epistemic  0.61 ± 0.05  0.50 ± 0.19
#                           Dropout   Aleatoric  0.52 ± 0.06  0.38 ± 0.08
#                                     Epistemic  0.55 ± 0.06  0.86 ± 0.03
#
#                                                                               \
# Metric
# Experiment                                    Leave Out Classes
# No Edges                                                  False         True
# Setting      Dataset      Model     Proxy
# Inductive    amazon_photo Drop Edge Aleatoric       0.74 ± 0.07  0.62 ± 0.03
#                                     Epistemic       0.52 ± 0.05  0.33 ± 0.03
#                           Dropout   Aleatoric       0.69 ± 0.07  0.65 ± 0.04
#                                     Epistemic       0.37 ± 0.06  0.46 ± 0.03
#              citeseer     Drop Edge Aleatoric       0.82 ± 0.06  0.66 ± 0.07
#                                     Epistemic       0.14 ± 0.04  0.32 ± 0.06
#                           Dropout   Aleatoric       0.77 ± 0.05  0.66 ± 0.06
#                                     Epistemic       0.33 ± 0.07  0.37 ± 0.05
#              coauthor_cs  Drop Edge Aleatoric       0.65 ± 0.10  0.71 ± 0.04
#                                     Epistemic       0.41 ± 0.02  0.28 ± 0.04
#                           Dropout   Aleatoric       0.71 ± 0.10  0.73 ± 0.04
#                                     Epistemic       0.36 ± 0.05  0.35 ± 0.02
#              cora_full    Drop Edge Aleatoric       0.96 ± 0.02  0.87 ± 0.02
#                                     Epistemic       0.08 ± 0.01  0.12 ± 0.02
#                           Dropout   Aleatoric       0.88 ± 0.02  0.85 ± 0.02
#                                     Epistemic       0.24 ± 0.02  0.19 ± 0.02
#              cora_ml      Drop Edge Aleatoric       0.94 ± 0.02  0.78 ± 0.02
#                                     Epistemic       0.16 ± 0.03  0.20 ± 0.02
#                           Dropout   Aleatoric       0.89 ± 0.02  0.78 ± 0.02
#                                     Epistemic       0.18 ± 0.02  0.26 ± 0.03
#              ogbn_arxiv   Drop Edge Aleatoric       0.95 ± 0.00  0.64 ± 0.01
#                                     Epistemic       0.20 ± 0.00  0.32 ± 0.01
#                           Dropout   Aleatoric       0.96 ± 0.00  0.67 ± 0.01
#                                     Epistemic       0.06 ± 0.00  0.38 ± 0.01
#              pubmed       Drop Edge Aleatoric       0.60 ± 0.06  0.59 ± 0.05
#                                     Epistemic       0.33 ± 0.07  0.36 ± 0.08
#                           Dropout   Aleatoric       0.58 ± 0.07  0.60 ± 0.06
#                                     Epistemic       0.42 ± 0.06  0.42 ± 0.05
# Transductive amazon_photo Drop Edge Aleatoric       0.72 ± 0.09  0.62 ± 0.04
#                                     Epistemic       0.52 ± 0.06  0.33 ± 0.04
#                           Dropout   Aleatoric       0.71 ± 0.09  0.65 ± 0.03
#                                     Epistemic       0.33 ± 0.08  0.46 ± 0.04
#              citeseer     Drop Edge Aleatoric       0.83 ± 0.08  0.72 ± 0.12
#                                     Epistemic       0.24 ± 0.08  0.26 ± 0.13
#                           Dropout   Aleatoric       0.82 ± 0.08  0.72 ± 0.12
#                                     Epistemic       0.26 ± 0.08  0.34 ± 0.11
#              coauthor_cs  Drop Edge Aleatoric       0.72 ± 0.09  0.70 ± 0.05
#                                     Epistemic       0.49 ± 0.03  0.28 ± 0.04
#                           Dropout   Aleatoric       0.72 ± 0.11  0.70 ± 0.05
#                                     Epistemic       0.29 ± 0.09  0.35 ± 0.04
#              cora_full    Drop Edge Aleatoric       0.98 ± 0.01  0.91 ± 0.04
#                                     Epistemic       0.10 ± 0.02  0.09 ± 0.04
#                           Dropout   Aleatoric       0.92 ± 0.01  0.90 ± 0.04
#                                     Epistemic       0.20 ± 0.01  0.13 ± 0.04
#              cora_ml      Drop Edge Aleatoric       0.95 ± 0.02  0.80 ± 0.02
#                                     Epistemic       0.19 ± 0.04  0.17 ± 0.02
#                           Dropout   Aleatoric       0.91 ± 0.03  0.81 ± 0.02
#                                     Epistemic       0.14 ± 0.02  0.22 ± 0.03
#              ogbn_arxiv   Drop Edge Aleatoric       0.95 ± 0.00  0.63 ± 0.01
#                                     Epistemic       0.23 ± 0.00  0.32 ± 0.01
#                           Dropout   Aleatoric       0.95 ± 0.00  0.63 ± 0.01
#                                     Epistemic       0.04 ± 0.00  0.42 ± 0.01
#              pubmed       Drop Edge Aleatoric       0.67 ± 0.12  0.61 ± 0.09
#                                     Epistemic       0.44 ± 0.09  0.42 ± 0.14
#                           Dropout   Aleatoric       0.65 ± 0.12  0.62 ± 0.09
#                                     Epistemic       0.36 ± 0.11  0.39 ± 0.08
#
#
# Metric
# Experiment                                          Normal
# No Edges                                             False         True
# Setting      Dataset      Model     Proxy
# Inductive    amazon_photo Drop Edge Aleatoric  0.50 ± 0.01  0.68 ± 0.04
#                                     Epistemic  0.49 ± 0.02  0.26 ± 0.04
#                           Dropout   Aleatoric  0.50 ± 0.02  0.51 ± 0.04
#                                     Epistemic  0.50 ± 0.02  0.61 ± 0.04
#              citeseer     Drop Edge Aleatoric  0.21 ± 0.02  0.10 ± 0.03
#                                     Epistemic  0.79 ± 0.04  0.94 ± 0.02
#                           Dropout   Aleatoric  0.31 ± 0.03  0.06 ± 0.02
#                                     Epistemic  0.65 ± 0.06  0.96 ± 0.03
#              coauthor_cs  Drop Edge Aleatoric  0.50 ± 0.01  0.61 ± 0.02
#                                     Epistemic  0.55 ± 0.02  0.39 ± 0.03
#                           Dropout   Aleatoric  0.52 ± 0.02  0.39 ± 0.02
#                                     Epistemic  0.49 ± 0.02  0.74 ± 0.02
#              cora_full    Drop Edge Aleatoric  0.24 ± 0.03  0.19 ± 0.02
#                                     Epistemic  0.70 ± 0.04  0.87 ± 0.03
#                           Dropout   Aleatoric  0.20 ± 0.03  0.02 ± 0.01
#                                     Epistemic  0.82 ± 0.02  0.99 ± 0.01
#              cora_ml      Drop Edge Aleatoric  0.22 ± 0.05  0.18 ± 0.01
#                                     Epistemic  0.68 ± 0.04  0.90 ± 0.03
#                           Dropout   Aleatoric  0.19 ± 0.03  0.02 ± 0.01
#                                     Epistemic  0.82 ± 0.03  0.99 ± 0.01
#              ogbn_arxiv   Drop Edge Aleatoric  0.48 ± 0.00  0.38 ± 0.00
#                                     Epistemic  0.53 ± 0.00  0.70 ± 0.00
#                           Dropout   Aleatoric  0.50 ± 0.00  0.07 ± 0.00
#                                     Epistemic  0.52 ± 0.00  0.94 ± 0.00
#              pubmed       Drop Edge Aleatoric  0.15 ± 0.01  0.14 ± 0.03
#                                     Epistemic  0.67 ± 0.03  0.90 ± 0.03
#                           Dropout   Aleatoric  0.19 ± 0.02  0.05 ± 0.02
#                                     Epistemic  0.83 ± 0.01  0.95 ± 0.01
# Transductive amazon_photo Drop Edge Aleatoric  0.52 ± 0.02  0.70 ± 0.03
#                                     Epistemic  0.52 ± 0.02  0.23 ± 0.03
#                           Dropout   Aleatoric  0.52 ± 0.03  0.55 ± 0.04
#                                     Epistemic  0.49 ± 0.02  0.59 ± 0.04
#              citeseer     Drop Edge Aleatoric  0.44 ± 0.09  0.30 ± 0.08
#                                     Epistemic  0.77 ± 0.04  0.74 ± 0.06
#                           Dropout   Aleatoric  0.49 ± 0.08  0.16 ± 0.04
#                                     Epistemic  0.50 ± 0.08  0.90 ± 0.05
#              coauthor_cs  Drop Edge Aleatoric  0.58 ± 0.01  0.65 ± 0.02
#                                     Epistemic  0.59 ± 0.02  0.34 ± 0.02
#                           Dropout   Aleatoric  0.57 ± 0.02  0.44 ± 0.03
#                                     Epistemic  0.43 ± 0.01  0.70 ± 0.03
#              cora_full    Drop Edge Aleatoric  0.30 ± 0.04  0.24 ± 0.03
#                                     Epistemic  0.74 ± 0.05  0.82 ± 0.06
#                           Dropout   Aleatoric  0.20 ± 0.04  0.03 ± 0.01
#                                     Epistemic  0.81 ± 0.03  0.99 ± 0.01
#              cora_ml      Drop Edge Aleatoric  0.27 ± 0.04  0.23 ± 0.03
#                                     Epistemic  0.72 ± 0.06  0.86 ± 0.04
#                           Dropout   Aleatoric  0.19 ± 0.03  0.03 ± 0.01
#                                     Epistemic  0.83 ± 0.03  0.98 ± 0.02
#              ogbn_arxiv   Drop Edge Aleatoric  0.50 ± 0.00  0.38 ± 0.00
#                                     Epistemic  0.56 ± 0.00  0.70 ± 0.00
#                           Dropout   Aleatoric  0.50 ± 0.00  0.07 ± 0.00
#                                     Epistemic  0.52 ± 0.00  0.93 ± 0.00
#              pubmed       Drop Edge Aleatoric  0.20 ± 0.02  0.17 ± 0.02
#                                     Epistemic  0.67 ± 0.01  0.86 ± 0.02
#                           Dropout   Aleatoric  0.17 ± 0.02  0.07 ± 0.02
#                                     Epistemic  0.86 ± 0.02  0.95 ± 0.01

# %%
df_tmp = df_proxy_agg.reset_index()
df_tmp = df_tmp.melt(id_vars=[MODEL, SETTING, DATASET, EXPERIMENT, NO_EDGES, PROXY], value_vars = [OOD_AUROC, OOD_AUCPR, MISCLASSICIFACTION_AUROC, MISCLASSICIFACTION_AUCPR], var_name='Metric')
df_tmp = df_tmp[(df_tmp[METRIC] == MISCLASSICIFACTION_AUROC) | (df_tmp[METRIC] == MISCLASSICIFACTION_AUCPR)]
df_tmp = df_tmp.pivot(index=[SETTING, DATASET, MODEL, PROXY], columns=[METRIC, EXPERIMENT, NO_EDGES]).T.sort_index().T
df_tmp.to_csv('~/dropout_all_datasets_misclassification_detection.csv')
